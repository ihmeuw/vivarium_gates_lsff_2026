# %%
import pandas as pd

# %%
vehicle = pd.read_excel("./Data Extraction Sheet.xlsx", sheet_name="Vehicle Extraction")
vehicle
# Out:
#     Vehicle                                          Data need  \
# 0      Rice  Iron fortification/consumption effect on hemog...
# 1      Salt  Iron fortification/consumption effect on hemog...
# 2  Bouillon  Iron fortification/consumption effect on hemog...
# 3      Rice  Iron fortification/consumption effect on birth...
# 4  Bouillon  Iron fortification/consumption effect on birth...
#
#    Data point name              Units         Year  \
# 0  Mean difference                g/L  Unpublished
# 1  Mean difference                g/L         2021
# 2  Mean difference                g/L         2012
# 3  Mean difference  g/(mg/person-day)         2013
# 4  Mean difference  g/(mg/person-day)         2013
#
#                                          Data source  Value              CI  \
# 0  Dorbu et al. Nutritional anemia reductions due...   3.25        0.9-5.71
# 1  Can Double Fortification of Salt with Iron and...   4.40         2.3-6.4
# 2  Effect of iron-fortified foods on hematologic ...   4.20         2.8-5.6
# 3  Anaemia, prenatal iron use, and risk of advers...   1.67  0.729 to 2.611
# 4  Anaemia, prenatal iron use, and risk of advers...   1.67  0.729 to 2.611
#
#                                                Notes
# 0  "This comes from a slide deck that Jonathan se...
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 2  https://www.sciencedirect.com/science/article/...
# 3  https://www.bmj.com/content/346/bmj.f3443; stu...
# 4  https://www.bmj.com/content/346/bmj.f3443; stu...

# %%
vehicle["Data need"].unique()
# Out:
# array(['Iron fortification/consumption effect on hemoglobin',
#        'Iron fortification/consumption effect on birthweight'],
#       dtype=object)

# %%
hemoglobin_effects = vehicle[
    vehicle["Data need"] == "Iron fortification/consumption effect on hemoglobin"
].copy()
assert (hemoglobin_effects["Data point name"] == "Mean difference").all()
assert (hemoglobin_effects["Units"] == "g/L").all()
hemoglobin_effects = hemoglobin_effects[["Vehicle", "Value"]].rename(
    columns={"Vehicle": "vehicle_name", "Value": "value"}
)
hemoglobin_effects["vehicle_name"] = hemoglobin_effects.vehicle_name.str.lower()
hemoglobin_effects
# Out:
#   vehicle_name  value
# 0         rice   3.25
# 1         salt   4.40
# 2     bouillon   4.20

# %%
results_dir = "../results"
hemoglobin_effects.to_csv(
    f"{results_dir}/iron/fortification_hemoglobin_effects.csv", index=False
)

# %%
birthweight_effects = vehicle[
    vehicle["Data need"] == "Iron fortification/consumption effect on birthweight"
].copy()
assert (birthweight_effects["Data point name"] == "Mean difference").all()
assert (birthweight_effects["Units"] == "g/(mg/person-day)").all()
birthweight_effects = birthweight_effects[["Vehicle", "Value"]].rename(
    columns={"Vehicle": "vehicle_name", "Value": "value"}
)
birthweight_effects["vehicle_name"] = birthweight_effects.vehicle_name.str.lower()
birthweight_effects
# Out:
#   vehicle_name  value
# 3         rice   1.67
# 4     bouillon   1.67

# %%
birthweight_effects.to_csv(
    f"{results_dir}/iron/fortification_birthweight_effects.csv", index=False
)
