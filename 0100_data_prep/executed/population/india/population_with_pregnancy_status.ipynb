# %%
import vivarium_inputs
from vivarium import gbd_mapping
import pathlib
import pandas as pd, numpy as np

# %%
location = "india"

# %%
# Parameters
location = "india"

# %%
total_population = (
    vivarium_inputs.get_population_structure(location.title())
    .droplevel(["location", "year_start", "year_end"])
    .value
)
total_population
# Out:
# 2026-08-24 16:26:55.217 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.309 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.333 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.388 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.389 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.395 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.403 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.405 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.414 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:55.423 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.424 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.432 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_population'
# 2026-08-24 16:26:55.439 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.439 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.448 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:55.455 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.455 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.464 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:55.479 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.481 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.494 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:55.499 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.500 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.508 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:55.514 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.515 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.524 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:55.535 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.536 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.539 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:55.544 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.546 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.551 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:55.557 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.557 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.560 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:55.572 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.572 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.577 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.588 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.588 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.593 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.606 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.608 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.612 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:55.628 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.629 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.633 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:55.643 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.644 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.650 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.656 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.657 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.660 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.666 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.667 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.673 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# sex     age_start  age_end
# Female  0.000000   0.019178      1.936945e+05
#         0.019178   0.076712      5.766332e+05
#         0.076712   0.500000      4.257480e+06
#         0.500000   1.000000      5.021249e+06
#         1.000000   2.000000      1.024770e+07
#         2.000000   5.000000      3.231858e+07
#         5.000000   10.000000     5.835119e+07
#         10.000000  15.000000     6.286521e+07
#         15.000000  20.000000     6.432311e+07
#         20.000000  25.000000     6.374038e+07
#         25.000000  30.000000     6.159864e+07
#         30.000000  35.000000     5.733795e+07
#         35.000000  40.000000     5.319119e+07
#         40.000000  45.000000     4.683697e+07
#         45.000000  50.000000     3.996526e+07
#         50.000000  55.000000     3.484048e+07
#         55.000000  60.000000     2.993952e+07
#         60.000000  65.000000     2.582036e+07
#         65.000000  70.000000     2.035355e+07
#         70.000000  75.000000     1.511558e+07
#         75.000000  80.000000     9.683317e+06
#         80.000000  85.000000     5.632096e+06
#         85.000000  90.000000     2.700635e+06
#         90.000000  95.000000     8.338075e+05
#         95.000000  125.000000    2.024809e+05
# Male    0.000000   0.019178      2.126282e+05
#         0.019178   0.076712      6.315723e+05
#         0.076712   0.500000      4.661302e+06
#         0.500000   1.000000      5.496262e+06
#         1.000000   2.000000      1.120286e+07
#         2.000000   5.000000      3.521447e+07
#         5.000000   10.000000     6.345063e+07
#         10.000000  15.000000     6.792384e+07
#         15.000000  20.000000     6.960478e+07
#         20.000000  25.000000     6.793476e+07
#         25.000000  30.000000     6.448848e+07
#         30.000000  35.000000     6.061820e+07
#         35.000000  40.000000     5.658866e+07
#         40.000000  45.000000     4.950707e+07
#         45.000000  50.000000     4.184714e+07
#         50.000000  55.000000     3.562267e+07
#         55.000000  60.000000     2.926650e+07
#         60.000000  65.000000     2.467622e+07
#         65.000000  70.000000     1.914904e+07
#         70.000000  75.000000     1.382503e+07
#         75.000000  80.000000     8.592744e+06
#         80.000000  85.000000     4.496315e+06
#         85.000000  90.000000     1.811393e+06
#         90.000000  95.000000     5.116994e+05
#         95.000000  125.000000    1.038020e+05
# Name: value, dtype: float64

# %%
path = pathlib.Path(f"../results/population/total/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
total_population.rename("value").to_csv(path)

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location.title()
).droplevel(["location", "year_start", "year_end"])
asfr = (
    asfr[asfr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
asfr[asfr > 0]
# Out:
# 2026-08-24 16:26:55.818 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.820 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.825 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.833 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.835 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.840 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.850 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.852 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.857 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:55.862 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.865 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.871 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-08-24 16:26:55.878 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.879 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.883 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:55.895 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.896 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.904 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:55.932 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.932 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.935 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:55.940 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.941 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.946 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:55.953 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.954 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.959 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:55.973 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.974 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.977 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:55.982 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.984 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.987 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:55.995 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.997 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.002 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:56.017 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.025 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.030 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.049 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.050 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.055 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.068 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.070 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.075 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:56.089 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.090 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.114 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:56.119 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.120 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.126 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.133 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.137 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.143 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.149 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.151 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.157 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# sex     age_start  age_end
# Female  10.0       15.0       0.000349
#         15.0       20.0       0.008912
#         20.0       25.0       0.094863
#         25.0       30.0       0.124175
#         30.0       35.0       0.079277
#         35.0       40.0       0.033097
#         40.0       45.0       0.011589
#         45.0       50.0       0.003006
#         50.0       55.0       0.000273
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(
    # Renamed from the retired stillbirth_to_live_birth_ratio when GBD split the covariate
    # by gestational-age definition; the sims use the 28-week definition
    # (see data_keys.PREGNANCY.SBR in the maternal package).
    gbd_mapping.covariates.stillbirth_28_weeks_to_live_birth_ratio,
    "estimate",
    location.title(),
)
sbr = (
    sbr[sbr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
assert len(sbr) == 1
sbr = sbr.iloc[0]
sbr
# Out:
# 2026-08-24 16:26:56.429 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.429 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.433 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.453 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.454 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.459 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.478 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.479 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.483 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:56.489 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.490 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.502 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-08-24 16:26:56.514 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.517 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.523 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:56.529 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.530 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.535 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:56.549 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.550 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.553 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:56.563 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.564 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.568 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:56.574 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.574 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.577 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:56.582 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.584 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.591 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:56.605 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.608 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.619 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:56.639 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.642 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.650 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.661 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.664 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.671 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.693 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.700 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.706 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:56.714 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.715 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.721 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.728 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.736 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.741 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.749 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.751 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.755 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 0.0163338791237466

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location.title(),
).droplevel(["location", "year_start", "year_end"])
maternal_abortion_miscarriage_incidence = maternal_abortion_miscarriage_incidence.mean(
    axis=1
)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# 2026-08-24 16:26:56.873 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.874 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.877 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.883 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.884 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.887 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.894 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.894 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.898 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.908 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.909 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.923 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:56.934 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.936 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.949 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 16:26:56.960 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.966 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.970 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:56.979 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.980 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.983 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:56.993 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 16:26:56.999 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.000 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.003 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:57.008 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.009 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.012 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:57.017 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.017 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.020 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:57.026 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 16:26:57.027 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 16:26:57.081 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.082 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.092 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.240 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.241 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.250 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:57.255 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.258 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.261 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:57.270 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.271 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.276 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.295 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.298 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.303 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.312 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.312 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.317 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:57.325 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.326 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.331 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 16:26:57.345 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.360 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.364 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.369 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.371 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.376 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:57.388 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 16:26:57.394 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.396 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.403 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:57.422 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.424 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.427 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:57.434 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.436 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.440 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:57.446 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 16:26:57.448 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 16:26:57.490 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.492 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.495 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.616 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.617 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.620 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:57.625 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.625 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.629 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:57.637 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.638 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.642 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.672 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.673 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.676 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.682 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.683 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.686 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.697 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.698 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.713 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:57.724 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.725 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.729 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:57.734 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.735 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.738 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.746 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.746 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.755 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.763 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.764 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.767 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/abie/projects/2026/vivarium_gates_lsff_2026/.snakemake_envs/artifact/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000091
#         15.0       20.0       0.001445
#         20.0       25.0       0.009951
#         25.0       30.0       0.010996
#         30.0       35.0       0.007060
#         35.0       40.0       0.003508
#         40.0       45.0       0.002148
#         45.0       50.0       0.000981
#         50.0       55.0       0.000181
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy, "incidence_rate", location.title()
).droplevel(["location", "year_start", "year_end"])
ectopic_pregnancy_incidence = ectopic_pregnancy_incidence.mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# 2026-08-24 16:26:57.886 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.887 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.894 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.906 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.907 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.912 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.919 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.920 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.926 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.934 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.937 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.945 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:57.951 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.951 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.956 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 16:26:57.965 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.966 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.969 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.975 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.975 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.978 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:57.988 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 16:26:57.991 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.992 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.995 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:58.004 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.007 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.010 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:58.015 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.016 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.021 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:58.028 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 16:26:58.030 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 16:26:58.052 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.059 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.064 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.136 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.139 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.146 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:58.155 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.156 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.161 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:58.173 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.176 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.181 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.203 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.204 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.209 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.218 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.219 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.222 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:58.231 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.233 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.239 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 16:26:58.257 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.258 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.262 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.270 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.271 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.281 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:58.291 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 16:26:58.295 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.296 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.300 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:58.306 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.308 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.311 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:58.320 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.321 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.325 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:58.331 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 16:26:58.332 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 16:26:58.357 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.358 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.362 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.440 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.443 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.451 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:58.464 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.468 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.477 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:58.497 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.504 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.507 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.525 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.527 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.532 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.541 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.542 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.545 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.557 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.559 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.564 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:58.576 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.578 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.583 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:58.592 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.595 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.600 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.608 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.609 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.614 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.622 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.625 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.638 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/abie/projects/2026/vivarium_gates_lsff_2026/.snakemake_envs/artifact/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000027
#         15.0       20.0       0.000164
#         20.0       25.0       0.001235
#         25.0       30.0       0.001726
#         30.0       35.0       0.001269
#         35.0       40.0       0.000639
#         40.0       45.0       0.000388
#         45.0       50.0       0.000176
#         50.0       55.0       0.000053
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.000473
#         15.0       20.0       0.010666
#         20.0       25.0       0.107598
#         25.0       30.0       0.138925
#         30.0       35.0       0.088901
#         35.0       40.0       0.037785
#         40.0       45.0       0.014314
#         45.0       50.0       0.004212
#         50.0       55.0       0.000512
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/incidence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_incidence.rename("value").to_csv(path)

# %%
# https://github.com/ihmeuw/vivarium_gates_iv_iron/blob/862b057457cea2410e8d24c2c9c38c43419cd8b2/src/vivarium_gates_iv_iron/data/loader.py#L237C5-L240C6
PARTIAL_TERM: float = 24 / 52
FULL_TERM: float = 40 / 52
pregnancy_prevalence = FULL_TERM * (asfr + asfr * sbr) + PARTIAL_TERM * (
    maternal_abortion_miscarriage_incidence + ectopic_pregnancy_incidence
)
pregnancy_prevalence[pregnancy_prevalence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.000327
#         15.0       20.0       0.007710
#         20.0       25.0       0.079326
#         25.0       30.0       0.102951
#         30.0       35.0       0.065823
#         35.0       40.0       0.027789
#         40.0       45.0       0.010230
#         45.0       50.0       0.002884
#         50.0       55.0       0.000321
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/prevalence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_prevalence.rename("value").to_csv(path)

# %%
population_stratified = pd.concat(
    [
        (pregnancy_prevalence * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="pregnant")
        .set_index("pregnant", append=True)
        .value,
        ((1 - pregnancy_prevalence) * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="not_pregnant")
        .set_index("pregnant", append=True)
        .value,
    ]
).sort_index()
population_stratified
# Out:
# sex     age_start  age_end     pregnant
# Female  0.000000   0.019178    not_pregnant    1.936945e+05
#                                pregnant        0.000000e+00
#         0.019178   0.076712    not_pregnant    5.766332e+05
#                                pregnant        0.000000e+00
#         0.076712   0.500000    not_pregnant    4.257480e+06
#                                                    ...
# Male    85.000000  90.000000   pregnant        0.000000e+00
#         90.000000  95.000000   not_pregnant    5.116994e+05
#                                pregnant        0.000000e+00
#         95.000000  125.000000  not_pregnant    1.038020e+05
#                                pregnant        0.000000e+00
# Name: value, Length: 100, dtype: float64

# %%
assert np.isclose(population_stratified.sum(), total_population.sum())

# %%
population_age_groups = (
    total_population.reset_index()[["age_start", "age_end"]]
    .drop_duplicates()
    .sort_values("age_start")
)
population_age_groups
# Out:
#     age_start     age_end
# 0    0.000000    0.019178
# 1    0.019178    0.076712
# 2    0.076712    0.500000
# 3    0.500000    1.000000
# 4    1.000000    2.000000
# 5    2.000000    5.000000
# 6    5.000000   10.000000
# 7   10.000000   15.000000
# 8   15.000000   20.000000
# 9   20.000000   25.000000
# 10  25.000000   30.000000
# 11  30.000000   35.000000
# 12  35.000000   40.000000
# 13  40.000000   45.000000
# 14  45.000000   50.000000
# 15  50.000000   55.000000
# 16  55.000000   60.000000
# 17  60.000000   65.000000
# 18  65.000000   70.000000
# 19  70.000000   75.000000
# 20  75.000000   80.000000
# 21  80.000000   85.000000
# 22  85.000000   90.000000
# 23  90.000000   95.000000
# 24  95.000000  125.000000

# %%
def map_to_population_age_groups(df):
    return (
        population_age_groups.merge(df, how="cross", suffixes=("", "_orig"))
        .pipe(
            lambda df: df[
                (df.age_end <= df.age_end_orig) & (df.age_start >= df.age_start_orig)
            ]
        )
        .drop(columns=["age_start_orig", "age_end_orig"])
    )

# %%
wealth_quintile_probabilities = pd.read_csv(
    f"../results/wealth_quintile_probabilities/{location}.csv"
).set_index(["sex", "age_start", "age_end", "pregnant"])
wealth_quintile_probabilities.columns.name = "wealth_quintile"
wealth_quintile_probabilities = wealth_quintile_probabilities.stack()
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  1                  0.251317
#                                           2                  0.220571
#                                           3                  0.195838
#                                           4                  0.184456
#                                           5                  0.147818
#         5.0        15.0     not_pregnant  1                  0.269038
#                                           2                  0.219459
#                                           3                  0.193766
#                                           4                  0.172569
#                                           5                  0.145167
#         15.0       30.0     not_pregnant  1                  0.177853
#                                           2                  0.202279
#                                           3                  0.211418
#                                           4                  0.210441
#                                           5                  0.198009
#                             pregnant      1                  0.221117
#                                           2                  0.222530
#                                           3                  0.215087
#                                           4                  0.182296
#                                           5                  0.158970
#         30.0       50.0     not_pregnant  1                  0.172597
#                                           2                  0.187138
#                                           3                  0.199031
#                                           4                  0.213495
#                                           5                  0.227738
#                             pregnant      1                  0.316131
#                                           2                  0.181401
#                                           3                  0.129805
#                                           4                  0.169147
#                                           5                  0.203517
#         50.0       125.0    not_pregnant  1                  0.188708
#                                           2                  0.187540
#                                           3                  0.191253
#                                           4                  0.199636
#                                           5                  0.232863
# Male    0.0        5.0      not_pregnant  1                  0.242600
#                                           2                  0.215610
#                                           3                  0.200229
#                                           4                  0.183923
#                                           5                  0.157639
#         5.0        15.0     not_pregnant  1                  0.261604
#                                           2                  0.217675
#                                           3                  0.190718
#                                           4                  0.176545
#                                           5                  0.153458
#         15.0       30.0     not_pregnant  1                  0.169172
#                                           2                  0.205794
#                                           3                  0.214029
#                                           4                  0.208330
#                                           5                  0.202675
#         30.0       50.0     not_pregnant  1                  0.167563
#                                           2                  0.183939
#                                           3                  0.203419
#                                           4                  0.219906
#                                           5                  0.225173
#         50.0       125.0    not_pregnant  1                  0.176575
#                                           2                  0.184392
#                                           3                  0.190461
#                                           4                  0.200876
#                                           5                  0.247696
# dtype: float64

# %%
wealth_quintile_probabilities = (
    map_to_population_age_groups(
        wealth_quintile_probabilities.rename("value").reset_index()
    )
    .set_index(wealth_quintile_probabilities.index.names)
    .value
)
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  0.251317
#                                              2                  0.220571
#                                              3                  0.195838
#                                              4                  0.184456
#                                              5                  0.147818
#                                                                   ...
# Male    95.0       125.000000  not_pregnant  1                  0.176575
#                                              2                  0.184392
#                                              3                  0.190461
#                                              4                  0.200876
#                                              5                  0.247696
# Name: value, Length: 285, dtype: float64

# %%
assert np.allclose(
    wealth_quintile_probabilities.groupby(population_stratified.index.names).sum(), 1.0
)

# %%
population_stratified = population_stratified.mul(
    wealth_quintile_probabilities, axis=0
).dropna()
population_stratified
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  48678.711021
#                                              2                  42723.422230
#                                              3                  37932.716572
#                                              4                  35728.167677
#                                              5                  28631.476092
#                                                                     ...
# Male    95.0       125.000000  not_pregnant  1                  18328.880607
#                                              2                  19140.234171
#                                              3                  19770.250303
#                                              4                  20851.307187
#                                              5                  25711.282133
# Name: value, Length: 285, dtype: float64

# %%
population_stratified.sum()
# Out:
# 1443353354.3961902

# %%
total_population.sum()
# Out:
# 1443385122.4563391

# %%
assert np.isclose(population_stratified.sum(), total_population.sum(), rtol=0.01)

# %%
path = pathlib.Path(f"../results/population/stratified/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
population_stratified.rename("value").to_csv(path)
