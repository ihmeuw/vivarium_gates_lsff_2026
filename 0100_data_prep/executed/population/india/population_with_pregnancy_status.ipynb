{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
total_population.rename("value").to_csv(path)

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location.title()
).droplevel(["location", "year_start", "year_end"])
asfr = (
    asfr[asfr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
asfr[asfr > 0]
# Out:
# 2026-08-28 17:15:49.652 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.653 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.656 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:49.659 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.660 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.663 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:49.666 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.666 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.668 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-28 17:15:49.670 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.670 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.726 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-08-28 17:15:49.757 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.759 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.764 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:49.767 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.768 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.771 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-28 17:15:49.777 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.777 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.780 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:49.782 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.782 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.785 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:49.787 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.787 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.790 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-28 17:15:49.794 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.794 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.796 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:49.798 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.798 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.800 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:49.803 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.804 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.806 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:49.812 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.813 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.815 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:49.818 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.818 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.821 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:49.828 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.828 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.831 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-28 17:15:49.836 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.836 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.839 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-28 17:15:49.841 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.841 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.843 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:49.846 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.847 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.849 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:49.852 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.852 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.854 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# sex     age_start  age_end
# Female  10.0       15.0       0.000349
#         15.0       20.0       0.008912
#         20.0       25.0       0.094863
#         25.0       30.0       0.124175
#         30.0       35.0       0.079277
#         35.0       40.0       0.033097
#         40.0       45.0       0.011589
#         45.0       50.0       0.003006
#         50.0       55.0       0.000273
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.stillbirth_28_weeks_to_live_birth_ratio, "estimate", location.title()
)
sbr = (
    sbr[sbr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
assert len(sbr) == 1
sbr = sbr.iloc[0]
sbr
# Out:
# 2026-08-28 17:15:49.940 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.941 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.944 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:49.947 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.948 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.950 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:49.953 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.954 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.956 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-28 17:15:49.958 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:49.958 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:49.978 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-08-28 17:15:50.003 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.004 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.008 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.012 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.012 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.014 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-28 17:15:50.020 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.020 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.022 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:50.025 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.025 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.027 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:50.030 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.031 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.033 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:50.035 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.035 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.037 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:50.040 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.040 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.042 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.048 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.049 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.051 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.054 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.054 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.057 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.063 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.063 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.065 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-28 17:15:50.068 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.068 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.070 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.073 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.073 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.075 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.078 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.079 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.081 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 0.0163338791237466

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location.title(),
).droplevel(["location", "year_start", "year_end"])
maternal_abortion_miscarriage_incidence = maternal_abortion_miscarriage_incidence.mean(
    axis=1
)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# 2026-08-28 17:15:50.117 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.117 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.120 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.123 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.123 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.126 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.128 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.129 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.131 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.134 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.134 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.136 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-28 17:15:50.138 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.139 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.163 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-28 17:15:50.193 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.194 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.197 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.200 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.201 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.203 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-28 17:15:50.209 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-28 17:15:50.211 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.211 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.213 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:50.215 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.216 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.218 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:50.220 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.220 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.222 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-28 17:15:50.225 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-28 17:15:50.226 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-28 17:15:50.239 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.239 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.241 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.281 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.281 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.283 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:50.285 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.286 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.288 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:50.292 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.292 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.294 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.302 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.302 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.305 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.308 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.308 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.310 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-28 17:15:50.312 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.313 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.315 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-28 17:15:50.319 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.320 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.322 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.324 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.324 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.327 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-28 17:15:50.332 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-28 17:15:50.334 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.334 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.336 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:50.338 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.339 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.341 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:50.343 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.343 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.345 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-28 17:15:50.348 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-28 17:15:50.349 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-28 17:15:50.359 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.359 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.362 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.398 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.399 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.401 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:50.403 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.403 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.405 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:50.409 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.410 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.412 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.420 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.421 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.423 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.426 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.426 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.429 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.435 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.435 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.437 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-28 17:15:50.443 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.443 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.446 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-28 17:15:50.448 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.448 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.450 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.453 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.453 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.456 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.458 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.459 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.461 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/albrja/miniconda3/envs/art/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000091
#         15.0       20.0       0.001445
#         20.0       25.0       0.009951
#         25.0       30.0       0.010996
#         30.0       35.0       0.007060
#         35.0       40.0       0.003508
#         40.0       45.0       0.002148
#         45.0       50.0       0.000981
#         50.0       55.0       0.000181
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy, "incidence_rate", location.title()
).droplevel(["location", "year_start", "year_end"])
ectopic_pregnancy_incidence = ectopic_pregnancy_incidence.mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# 2026-08-28 17:15:50.517 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.518 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.520 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.524 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.525 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.527 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.530 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.530 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.533 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.535 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.536 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.538 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-28 17:15:50.540 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.540 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.560 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-28 17:15:50.596 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.598 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.602 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.605 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.605 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.608 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-28 17:15:50.613 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-28 17:15:50.614 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.615 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.617 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:50.622 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.622 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.624 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:50.627 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.627 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.629 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-28 17:15:50.632 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-28 17:15:50.633 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-28 17:15:50.644 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.644 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.647 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.684 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.684 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.686 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:50.688 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.689 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.691 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:50.695 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.696 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.698 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.705 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.706 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.708 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.711 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.711 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.714 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-28 17:15:50.716 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.717 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.719 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-28 17:15:50.723 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.724 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.726 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.728 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.728 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.730 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-28 17:15:50.736 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-28 17:15:50.737 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.737 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.740 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:50.742 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.742 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.744 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:50.746 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.747 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.749 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-28 17:15:50.752 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-28 17:15:50.752 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-28 17:15:50.762 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.762 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.765 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.804 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.805 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.807 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-28 17:15:50.809 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.810 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.812 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-28 17:15:50.816 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.817 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.819 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-28 17:15:50.827 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.828 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.830 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.833 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.833 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.836 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.841 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.842 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.845 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-28 17:15:50.851 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.851 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.853 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-28 17:15:50.856 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.857 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.859 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.862 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.862 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.864 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-28 17:15:50.867 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-08-28 17:15:50.868 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-08-28 17:15:50.870 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/albrja/miniconda3/envs/art/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000027
#         15.0       20.0       0.000164
#         20.0       25.0       0.001235
#         25.0       30.0       0.001726
#         30.0       35.0       0.001269
#         35.0       40.0       0.000639
#         40.0       45.0       0.000388
#         45.0       50.0       0.000176
#         50.0       55.0       0.000053
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.000473
#         15.0       20.0       0.010666
#         20.0       25.0       0.107598
#         25.0       30.0       0.138925
#         30.0       35.0       0.088901
#         35.0       40.0       0.037785
#         40.0       45.0       0.014314
#         45.0       50.0       0.004212
#         50.0       55.0       0.000512
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/incidence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_incidence.rename("value").to_csv(path)

# %%
# https://github.com/ihmeuw/vivarium_gates_iv_iron/blob/862b057457cea2410e8d24c2c9c38c43419cd8b2/src/vivarium_gates_iv_iron/data/loader.py#L237C5-L240C6
PARTIAL_TERM: float = 24 / 52
FULL_TERM: float = 40 / 52
pregnancy_prevalence = FULL_TERM * (asfr + asfr * sbr) + PARTIAL_TERM * (
    maternal_abortion_miscarriage_incidence + ectopic_pregnancy_incidence
)
pregnancy_prevalence[pregnancy_prevalence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.000327
#         15.0       20.0       0.007710
#         20.0       25.0       0.079326
#         25.0       30.0       0.102951
#         30.0       35.0       0.065823
#         35.0       40.0       0.027789
#         40.0       45.0       0.010230
#         45.0       50.0       0.002884
#         50.0       55.0       0.000321
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/prevalence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_prevalence.rename("value").to_csv(path)

# %%
population_stratified = pd.concat(
    [
        (pregnancy_prevalence * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="pregnant")
        .set_index("pregnant", append=True)
        .value,
        ((1 - pregnancy_prevalence) * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="not_pregnant")
        .set_index("pregnant", append=True)
        .value,
    ]
).sort_index()
population_stratified
# Out:
# sex     age_start  age_end     pregnant
# Female  0.000000   0.019178    not_pregnant    1.936945e+05
#                                pregnant        0.000000e+00
#         0.019178   0.076712    not_pregnant    5.766332e+05
#                                pregnant        0.000000e+00
#         0.076712   0.500000    not_pregnant    4.257480e+06
#                                                    ...
# Male    85.000000  90.000000   pregnant        0.000000e+00
#         90.000000  95.000000   not_pregnant    5.116994e+05
#                                pregnant        0.000000e+00
#         95.000000  125.000000  not_pregnant    1.038020e+05
#                                pregnant        0.000000e+00
# Name: value, Length: 100, dtype: float64

# %%
assert np.isclose(population_stratified.sum(), total_population.sum())

# %%
population_age_groups = (
    total_population.reset_index()[["age_start", "age_end"]]
    .drop_duplicates()
    .sort_values("age_start")
)
population_age_groups
# Out:
#     age_start     age_end
# 0    0.000000    0.019178
# 1    0.019178    0.076712
# 2    0.076712    0.500000
# 3    0.500000    1.000000
# 4    1.000000    2.000000
# 5    2.000000    5.000000
# 6    5.000000   10.000000
# 7   10.000000   15.000000
# 8   15.000000   20.000000
# 9   20.000000   25.000000
# 10  25.000000   30.000000
# 11  30.000000   35.000000
# 12  35.000000   40.000000
# 13  40.000000   45.000000
# 14  45.000000   50.000000
# 15  50.000000   55.000000
# 16  55.000000   60.000000
# 17  60.000000   65.000000
# 18  65.000000   70.000000
# 19  70.000000   75.000000
# 20  75.000000   80.000000
# 21  80.000000   85.000000
# 22  85.000000   90.000000
# 23  90.000000   95.000000
# 24  95.000000  125.000000

# %%
def map_to_population_age_groups(df):
    return (
        population_age_groups.merge(df, how="cross", suffixes=("", "_orig"))
        .pipe(
            lambda df: df[
                (df.age_end <= df.age_end_orig) & (df.age_start >= df.age_start_orig)
            ]
        )
        .drop(columns=["age_start_orig", "age_end_orig"])
    )

# %%
wealth_quintile_probabilities = pd.read_csv(
    f"../results/wealth_quintile_probabilities/{location}.csv"
).set_index(["sex", "age_start", "age_end", "pregnant"])
wealth_quintile_probabilities.columns.name = "wealth_quintile"
wealth_quintile_probabilities = wealth_quintile_probabilities.stack()
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  1                  0.251317
#                                           2                  0.220571
#                                           3                  0.195838
#                                           4                  0.184456
#                                           5                  0.147818
#         5.0        15.0     not_pregnant  1                  0.269038
#                                           2                  0.219459
#                                           3                  0.193766
#                                           4                  0.172569
#                                           5                  0.145167
#         15.0       30.0     not_pregnant  1                  0.177853
#                                           2                  0.202279
#                                           3                  0.211418
#                                           4                  0.210441
#                                           5                  0.198009
#                             pregnant      1                  0.221117
#                                           2                  0.222530
#                                           3                  0.215087
#                                           4                  0.182296
#                                           5                  0.158970
#         30.0       50.0     not_pregnant  1                  0.172597
#                                           2                  0.187138
#                                           3                  0.199031
#                                           4                  0.213495
#                                           5                  0.227738
#                             pregnant      1                  0.316131
#                                           2                  0.181401
#                                           3                  0.129805
#                                           4                  0.169147
#                                           5                  0.203517
#         50.0       125.0    not_pregnant  1                  0.188708
#                                           2                  0.187540
#                                           3                  0.191253
#                                           4                  0.199636
#                                           5                  0.232863
# Male    0.0        5.0      not_pregnant  1                  0.242600
#                                           2                  0.215610
#                                           3                  0.200229
#                                           4                  0.183923
#                                           5                  0.157639
#         5.0        15.0     not_pregnant  1                  0.261604
#                                           2                  0.217675
#                                           3                  0.190718
#                                           4                  0.176545
#                                           5                  0.153458
#         15.0       30.0     not_pregnant  1                  0.169172
#                                           2                  0.205794
#                                           3                  0.214029
#                                           4                  0.208330
#                                           5                  0.202675
#         30.0       50.0     not_pregnant  1                  0.167563
#                                           2                  0.183939
#                                           3                  0.203419
#                                           4                  0.219906
#                                           5                  0.225173
#         50.0       125.0    not_pregnant  1                  0.176575
#                                           2                  0.184392
#                                           3                  0.190461
#                                           4                  0.200876
#                                           5                  0.247696
# dtype: float64

# %%
wealth_quintile_probabilities = (
    map_to_population_age_groups(
        wealth_quintile_probabilities.rename("value").reset_index()
    )
    .set_index(wealth_quintile_probabilities.index.names)
    .value
)
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  0.251317
#                                              2                  0.220571
#                                              3                  0.195838
#                                              4                  0.184456
#                                              5                  0.147818
#                                                                   ...
# Male    95.0       125.000000  not_pregnant  1                  0.176575
#                                              2                  0.184392
#                                              3                  0.190461
#                                              4                  0.200876
#                                              5                  0.247696
# Name: value, Length: 285, dtype: float64

# %%
assert np.allclose(
    wealth_quintile_probabilities.groupby(population_stratified.index.names).sum(), 1.0
)

# %%
population_stratified = population_stratified.mul(
    wealth_quintile_probabilities, axis=0
).dropna()
population_stratified
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  48678.711021
#                                              2                  42723.422230
#                                              3                  37932.716572
#                                              4                  35728.167677
#                                              5                  28631.476092
#                                                                     ...
# Male    95.0       125.000000  not_pregnant  1                  18328.880607
#                                              2                  19140.234171
#                                              3                  19770.250303
#                                              4                  20851.307187
#                                              5                  25711.282133
# Name: value, Length: 285, dtype: float64

# %%
population_stratified.sum()
# Out:
# 1443353354.3961902

# %%
total_population.sum()
# Out:
# 1443385122.4563391

# %%
assert np.isclose(population_stratified.sum(), total_population.sum(), rtol=0.01)

# %%
path = pathlib.Path(f"../results/population/stratified/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
population_stratified.rename("value").to_csv(path)
