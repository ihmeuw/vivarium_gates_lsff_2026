{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
total_population.rename("value").to_csv(path)

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location.title()
).droplevel(["location", "year_start", "year_end"])
asfr = (
    asfr[asfr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
asfr[asfr > 0]
# Out:
# 2026-09-24 17:18:39.372 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.372 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.375 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.381 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.381 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.385 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.390 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.392 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.395 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-24 17:18:39.398 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.399 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.428 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-09-24 17:18:39.454 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.455 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.458 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:39.461 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.462 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.465 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-24 17:18:39.474 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.475 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.478 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:39.481 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.482 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.485 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:39.488 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.490 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.492 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-24 17:18:39.498 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.500 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.502 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:39.505 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.507 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.509 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:39.513 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.514 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.517 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:39.526 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.528 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.531 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.536 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.537 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.540 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.551 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.552 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.555 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-24 17:18:39.563 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.564 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.567 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-24 17:18:39.570 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.572 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.575 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.580 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.582 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.585 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.590 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.592 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.594 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# sex     age_start  age_end
# Female  10.0       15.0       0.005714
#         15.0       20.0       0.070244
#         20.0       25.0       0.194484
#         25.0       30.0       0.208935
#         30.0       35.0       0.194076
#         35.0       40.0       0.127396
#         40.0       45.0       0.067482
#         45.0       50.0       0.031121
#         50.0       55.0       0.002821
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.stillbirth_28_weeks_to_live_birth_ratio, "estimate", location.title()
)
sbr = (
    sbr[sbr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
assert len(sbr) == 1
sbr = sbr.iloc[0]
sbr
# Out:
# 2026-09-24 17:18:39.712 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.712 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.715 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.722 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.722 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.725 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.730 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.731 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.734 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-24 17:18:39.737 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.738 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.762 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-09-24 17:18:39.792 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.793 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.796 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:39.800 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.801 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.804 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-24 17:18:39.812 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.814 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.816 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:39.819 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.821 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.823 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:39.827 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.828 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.831 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:39.834 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.835 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.838 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:39.842 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.843 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.846 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:39.854 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.855 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.858 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.864 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.865 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.868 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.960 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.961 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.964 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-24 17:18:39.967 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.968 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.970 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.975 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.976 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.978 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:39.984 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:39.985 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:39.988 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 0.0263411623194878

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location.title(),
).droplevel(["location", "year_start", "year_end"])
maternal_abortion_miscarriage_incidence = maternal_abortion_miscarriage_incidence.mean(
    axis=1
)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# 2026-09-24 17:18:40.032 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.033 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.035 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.040 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.040 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.042 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.047 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.047 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.050 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.055 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.056 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.058 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-24 17:18:40.061 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.061 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.080 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-24 17:18:40.117 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.120 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.125 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.131 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.133 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.138 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-24 17:18:40.154 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-24 17:18:40.158 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.159 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.165 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:40.169 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.171 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.176 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:40.181 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.183 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.187 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-24 17:18:40.194 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-24 17:18:40.196 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-24 17:18:40.216 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.217 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.222 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.279 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.280 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.283 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:40.285 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.286 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.288 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:40.293 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.294 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.296 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.307 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.308 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.310 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.315 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.315 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.321 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-24 17:18:40.323 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.324 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.326 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-24 17:18:40.331 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.332 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.334 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.336 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.337 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.339 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-24 17:18:40.347 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-24 17:18:40.348 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.349 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.351 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:40.353 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.353 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.355 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:40.358 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.359 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.361 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-24 17:18:40.365 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-24 17:18:40.366 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-24 17:18:40.380 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.381 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.383 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.425 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.425 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.428 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:40.430 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.430 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.432 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:40.437 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.437 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.439 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.450 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.450 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.452 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.457 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.457 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.459 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.467 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.468 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.470 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-24 17:18:40.477 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.478 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.480 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-24 17:18:40.483 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.483 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.485 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.490 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.491 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.493 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.497 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.498 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.500 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/ndbs/miniconda3/envs/vivarium_gates_lsff_2026_artifact/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.006976
#         15.0       20.0       0.074024
#         20.0       25.0       0.177579
#         25.0       30.0       0.164486
#         30.0       35.0       0.146138
#         35.0       40.0       0.103056
#         40.0       45.0       0.063297
#         45.0       50.0       0.035266
#         50.0       55.0       0.003660
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy, "incidence_rate", location.title()
).droplevel(["location", "year_start", "year_end"])
ectopic_pregnancy_incidence = ectopic_pregnancy_incidence.mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# 2026-09-24 17:18:40.568 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.568 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.571 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.576 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.576 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.580 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.585 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.585 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.588 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.593 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.594 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.596 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-24 17:18:40.601 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.602 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.620 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-24 17:18:40.657 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.659 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.665 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.670 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.673 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.677 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-24 17:18:40.692 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-24 17:18:40.696 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.698 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.702 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:40.706 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.708 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.711 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:40.715 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.716 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.718 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-24 17:18:40.725 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-24 17:18:40.725 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-24 17:18:40.744 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.745 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.748 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.805 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.806 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.809 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:40.811 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.811 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.814 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:40.819 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.823 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.825 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.835 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.836 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.840 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:40.845 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.846 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.848 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-24 17:18:40.850 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.851 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.854 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-24 17:18:40.858 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.859 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.862 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.865 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.867 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.869 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-24 17:18:40.877 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-24 17:18:40.879 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.881 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.883 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:40.886 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.887 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.889 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:40.892 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.892 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.894 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-24 17:18:40.898 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-24 17:18:40.899 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-24 17:18:40.912 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.912 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.915 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.958 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.958 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.962 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-24 17:18:40.965 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.966 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.969 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-24 17:18:40.974 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.974 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.977 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-24 17:18:40.987 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:40.991 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:40.994 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:41.000 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:41.001 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:41.004 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:41.014 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:41.015 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:41.019 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-24 17:18:41.028 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:41.029 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:41.032 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-24 17:18:41.035 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:41.037 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:41.040 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:41.045 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:41.046 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:41.049 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-24 17:18:41.054 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-24 17:18:41.055 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/ndbs/cache'
# 2026-09-24 17:18:41.058 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/ndbs/miniconda3/envs/vivarium_gates_lsff_2026_artifact/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000623
#         15.0       20.0       0.002269
#         20.0       25.0       0.003786
#         25.0       30.0       0.003659
#         30.0       35.0       0.003887
#         35.0       40.0       0.003440
#         40.0       45.0       0.003382
#         45.0       50.0       0.002765
#         50.0       55.0       0.000730
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.013464
#         15.0       20.0       0.148388
#         20.0       25.0       0.380972
#         25.0       30.0       0.382582
#         30.0       35.0       0.349213
#         35.0       40.0       0.237248
#         40.0       45.0       0.135939
#         45.0       50.0       0.069972
#         50.0       55.0       0.007286
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/incidence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_incidence.rename("value").to_csv(path)

# %%
# https://github.com/ihmeuw/vivarium_gates_iv_iron/blob/862b057457cea2410e8d24c2c9c38c43419cd8b2/src/vivarium_gates_iv_iron/data/loader.py#L237C5-L240C6
PARTIAL_TERM: float = 24 / 52
FULL_TERM: float = 40 / 52
pregnancy_prevalence = FULL_TERM * (asfr + asfr * sbr) + PARTIAL_TERM * (
    maternal_abortion_miscarriage_incidence + ectopic_pregnancy_incidence
)
pregnancy_prevalence[pregnancy_prevalence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.008019
#         15.0       20.0       0.090669
#         20.0       25.0       0.237251
#         25.0       30.0       0.242557
#         30.0       35.0       0.222464
#         35.0       40.0       0.149730
#         40.0       45.0       0.084052
#         45.0       50.0       0.042123
#         50.0       55.0       0.004254
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/prevalence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_prevalence.rename("value").to_csv(path)

# %%
population_stratified = pd.concat(
    [
        (pregnancy_prevalence * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="pregnant")
        .set_index("pregnant", append=True)
        .value,
        ((1 - pregnancy_prevalence) * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="not_pregnant")
        .set_index("pregnant", append=True)
        .value,
    ]
).sort_index()
population_stratified
# Out:
# sex     age_start  age_end     pregnant
# Female  0.000000   0.019178    not_pregnant    7.907591e+04
#                                pregnant        0.000000e+00
#         0.019178   0.076712    not_pregnant    2.337381e+05
#                                pregnant        0.000000e+00
#         0.076712   0.500000    not_pregnant    1.706685e+06
#                                                    ...
# Male    85.000000  90.000000   pregnant        0.000000e+00
#         90.000000  95.000000   not_pregnant    6.687309e+04
#                                pregnant        0.000000e+00
#         95.000000  125.000000  not_pregnant    2.409231e+04
#                                pregnant        0.000000e+00
# Name: value, Length: 100, dtype: float64

# %%
assert np.isclose(population_stratified.sum(), total_population.sum())

# %%
population_age_groups = (
    total_population.reset_index()[["age_start", "age_end"]]
    .drop_duplicates()
    .sort_values("age_start")
)
population_age_groups
# Out:
#     age_start     age_end
# 0    0.000000    0.019178
# 1    0.019178    0.076712
# 2    0.076712    0.500000
# 3    0.500000    1.000000
# 4    1.000000    2.000000
# 5    2.000000    5.000000
# 6    5.000000   10.000000
# 7   10.000000   15.000000
# 8   15.000000   20.000000
# 9   20.000000   25.000000
# 10  25.000000   30.000000
# 11  30.000000   35.000000
# 12  35.000000   40.000000
# 13  40.000000   45.000000
# 14  45.000000   50.000000
# 15  50.000000   55.000000
# 16  55.000000   60.000000
# 17  60.000000   65.000000
# 18  65.000000   70.000000
# 19  70.000000   75.000000
# 20  75.000000   80.000000
# 21  80.000000   85.000000
# 22  85.000000   90.000000
# 23  90.000000   95.000000
# 24  95.000000  125.000000

# %%
def map_to_population_age_groups(df):
    return (
        population_age_groups.merge(df, how="cross", suffixes=("", "_orig"))
        .pipe(
            lambda df: df[
                (df.age_end <= df.age_end_orig) & (df.age_start >= df.age_start_orig)
            ]
        )
        .drop(columns=["age_start_orig", "age_end_orig"])
    )

# %%
wealth_quintile_probabilities = pd.read_csv(
    f"../results/wealth_quintile_probabilities/{location}.csv"
).set_index(["sex", "age_start", "age_end", "pregnant"])
wealth_quintile_probabilities.columns.name = "wealth_quintile"
wealth_quintile_probabilities = wealth_quintile_probabilities.stack()
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  1                  0.237660
#                                           2                  0.225487
#                                           3                  0.203977
#                                           4                  0.178487
#                                           5                  0.154389
#         5.0        15.0     not_pregnant  1                  0.222657
#                                           2                  0.219831
#                                           3                  0.200573
#                                           4                  0.188057
#                                           5                  0.168882
#         15.0       30.0     not_pregnant  1                  0.165585
#                                           2                  0.191566
#                                           3                  0.209803
#                                           4                  0.226150
#                                           5                  0.206896
#                             pregnant      1                  0.228131
#                                           2                  0.261971
#                                           3                  0.225828
#                                           4                  0.174600
#                                           5                  0.109470
#         30.0       50.0     not_pregnant  1                  0.169298
#                                           2                  0.173463
#                                           3                  0.186056
#                                           4                  0.208814
#                                           5                  0.262369
#                             pregnant      1                  0.231282
#                                           2                  0.190765
#                                           3                  0.171661
#                                           4                  0.205521
#                                           5                  0.200770
#         50.0       125.0    not_pregnant  1                  0.183495
#                                           2                  0.183221
#                                           3                  0.202734
#                                           4                  0.200921
#                                           5                  0.229630
# Male    0.0        5.0      not_pregnant  1                  0.245259
#                                           2                  0.222780
#                                           3                  0.202629
#                                           4                  0.173367
#                                           5                  0.155965
#         5.0        15.0     not_pregnant  1                  0.227679
#                                           2                  0.210604
#                                           3                  0.201929
#                                           4                  0.192289
#                                           5                  0.167499
#         15.0       30.0     not_pregnant  1                  0.171533
#                                           2                  0.196784
#                                           3                  0.207765
#                                           4                  0.218414
#                                           5                  0.205504
#         30.0       50.0     not_pregnant  1                  0.155384
#                                           2                  0.167111
#                                           3                  0.188403
#                                           4                  0.219586
#                                           5                  0.269516
#         50.0       125.0    not_pregnant  1                  0.201294
#                                           2                  0.181435
#                                           3                  0.189684
#                                           4                  0.188895
#                                           5                  0.238693
# dtype: float64

# %%
wealth_quintile_probabilities = (
    map_to_population_age_groups(
        wealth_quintile_probabilities.rename("value").reset_index()
    )
    .set_index(wealth_quintile_probabilities.index.names)
    .value
)
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  0.237660
#                                              2                  0.225487
#                                              3                  0.203977
#                                              4                  0.178487
#                                              5                  0.154389
#                                                                   ...
# Male    95.0       125.000000  not_pregnant  1                  0.201294
#                                              2                  0.181435
#                                              3                  0.189684
#                                              4                  0.188895
#                                              5                  0.238693
# Name: value, Length: 285, dtype: float64

# %%
assert np.allclose(
    wealth_quintile_probabilities.groupby(population_stratified.index.names).sum(), 1.0
)

# %%
population_stratified = population_stratified.mul(
    wealth_quintile_probabilities, axis=0
).dropna()
population_stratified
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  18793.149621
#                                              2                  17830.620200
#                                              3                  16129.662368
#                                              4                  14114.028154
#                                              5                  12208.445301
#                                                                     ...
# Male    95.0       125.000000  not_pregnant  1                   4849.649774
#                                              2                   4371.181536
#                                              3                   4569.918352
#                                              4                   4550.906874
#                                              5                   5750.658068
# Name: value, Length: 285, dtype: float64

# %%
population_stratified.sum()
# Out:
# 244684507.26680964

# %%
total_population.sum()
# Out:
# 244833398.85833606

# %%
assert np.isclose(population_stratified.sum(), total_population.sum(), rtol=0.01)

# %%
path = pathlib.Path(f"../results/population/stratified/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
population_stratified.rename("value").to_csv(path)
