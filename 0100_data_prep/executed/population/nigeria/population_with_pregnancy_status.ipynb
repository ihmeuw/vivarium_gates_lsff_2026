# %%
import vivarium_inputs
import gbd_mapping
import pathlib
import pandas as pd, numpy as np
# Out:
# Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# Cache Dir: '/share/scratch/users/zmbc/cache'

# %%
location = "india"

# %%
# Parameters
location = "nigeria"

# %%
total_population = (
    vivarium_inputs.get_population_structure(location.title())
    .droplevel(["location", "year_start", "year_end"])
    .value
)
total_population
# Out:
# ________________________________________________________________________________
# [Memory] Calling vivarium_gbd_access.gbd.get_population...
# get_population([214], year_id=2021)
# ___________________________________________________get_population - 0.1s, 0.0min
# sex     age_start  age_end
# Female  0.000000   0.019178      7.684611e+04
#         0.019178   0.076712      2.268013e+05
#         0.076712   0.500000      1.653024e+06
#         0.500000   1.000000      1.904590e+06
#         1.000000   2.000000      3.736238e+06
#         2.000000   5.000000      1.079625e+07
#         5.000000   10.000000     1.693204e+07
#         10.000000  15.000000     1.577085e+07
#         15.000000  20.000000     1.379964e+07
#         20.000000  25.000000     1.128166e+07
#         25.000000  30.000000     9.287220e+06
#         30.000000  35.000000     7.471066e+06
#         35.000000  40.000000     6.185237e+06
#         40.000000  45.000000     5.091273e+06
#         45.000000  50.000000     4.304679e+06
#         50.000000  55.000000     3.667141e+06
#         55.000000  60.000000     2.899289e+06
#         60.000000  65.000000     2.110837e+06
#         65.000000  70.000000     1.355318e+06
#         70.000000  75.000000     8.796247e+05
#         75.000000  80.000000     5.566921e+05
#         80.000000  85.000000     3.121727e+05
#         85.000000  90.000000     1.333871e+05
#         90.000000  95.000000     4.391468e+04
#         95.000000  125.000000    1.715151e+04
# Male    0.000000   0.019178      7.992764e+04
#         0.019178   0.076712      2.346944e+05
#         0.076712   0.500000      1.708080e+06
#         0.500000   1.000000      1.966178e+06
#         1.000000   2.000000      3.815137e+06
#         2.000000   5.000000      1.092008e+07
#         5.000000   10.000000     1.684783e+07
#         10.000000  15.000000     1.492050e+07
#         15.000000  20.000000     1.238358e+07
#         20.000000  25.000000     9.784196e+06
#         25.000000  30.000000     7.859696e+06
#         30.000000  35.000000     6.439239e+06
#         35.000000  40.000000     5.447181e+06
#         40.000000  45.000000     4.657036e+06
#         45.000000  50.000000     3.874873e+06
#         50.000000  55.000000     3.041399e+06
#         55.000000  60.000000     2.219552e+06
#         60.000000  65.000000     1.572530e+06
#         65.000000  70.000000     1.099679e+06
#         70.000000  75.000000     7.878240e+05
#         75.000000  80.000000     5.255298e+05
#         80.000000  85.000000     3.022741e+05
#         85.000000  90.000000     1.329814e+05
#         90.000000  95.000000     4.395565e+04
#         95.000000  125.000000    8.800781e+03
# Name: value, dtype: float64

# %%
path = pathlib.Path(f"../results/population/total/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
total_population.rename("value").to_csv(path)

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location.title()
).droplevel(["location", "year_start", "year_end"])
asfr = (
    asfr[asfr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
asfr[asfr > 0]
# Out:
# ________________________________________________________________________________
# [Memory] Calling vivarium_gbd_access.gbd.get_covariate_estimate...
# get_covariate_estimate(13, [214], year_id=2021)
# ___________________________________________get_covariate_estimate - 0.2s, 0.0min
# sex     age_start  age_end
# Female  10.0       15.0       0.003104
#         15.0       20.0       0.077594
#         20.0       25.0       0.202959
#         25.0       30.0       0.221416
#         30.0       35.0       0.202088
#         35.0       40.0       0.135730
#         40.0       45.0       0.070925
#         45.0       50.0       0.033819
#         50.0       55.0       0.003135
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.stillbirth_to_live_birth_ratio, "estimate", location.title()
)
sbr = (
    sbr[sbr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
assert len(sbr) == 1
sbr = sbr.iloc[0]
sbr
# Out:
# ________________________________________________________________________________
# [Memory] Calling vivarium_gbd_access.gbd.get_covariate_estimate...
# get_covariate_estimate(2267, [214], year_id=2021)
# ___________________________________________get_covariate_estimate - 0.2s, 0.0min
# 0.0386836060874489

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location.title(),
).droplevel(["location", "year_start", "year_end"])
maternal_abortion_miscarriage_incidence = maternal_abortion_miscarriage_incidence.mean(
    axis=1
)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# ________________________________________________________________________________
# [Memory] Calling vivarium_gbd_access.gbd.get_incidence_prevalence...
# get_incidence_prevalence(entity_id=c_id(995), location_id=[214], entity_type='cause', year_id=2021)
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_2026_maternal/.venv/lib/python3.11/site-packages/ihme_cc_rules_client/lib/rules_manager.py:224: UnrecognizedRuleWarning: Rules API returned unrecognized rule: EPI_PASS_GET_RESULTS_TO_GET_ESTIMATES. The installed ihme_cc_rules_client package (version 3.15.2) is likely outdated and should be upgraded. If you see this warning in a central environment, please submit a Help Desk ticket for Central Comp: https://helpdesk.ihme.washington.edu
#   warnings.warn(
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_2026_maternal/.venv/lib/python3.11/site-packages/ihme_cc_rules_client/lib/rules_manager.py:224: UnrecognizedRuleWarning: Rules API returned unrecognized rule: STGPR_PASS_GET_RESULTS_TO_GET_ESTIMATES. The installed ihme_cc_rules_client package (version 3.15.2) is likely outdated and should be upgraded. If you see this warning in a central environment, please submit a Help Desk ticket for Central Comp: https://helpdesk.ihme.washington.edu
#   warnings.warn(
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_2026_maternal/.venv/lib/python3.11/site-packages/get_draws/api.py:192: UserWarning: No version_id was specified, so get_draws will automatically determine a best version ID to use from the given parameters. If you want to retrieve a specific version please pass a version_id directly.
#   warnings.warn(
# 2025-04-29 22:46:07.867 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2025-04-29 22:46:07.873 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2025-04-29 22:46:07.874 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# 2025-04-29 22:46:07.989 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2025-04-29 22:46:07.994 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2025-04-29 22:46:07.995 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# _________________________________________get_incidence_prevalence - 8.2s, 0.1min
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_2026_maternal/.venv/lib/python3.11/site-packages/vivarium_inputs/utilities.py:492: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000253
#         15.0       20.0       0.016405
#         20.0       25.0       0.035427
#         25.0       30.0       0.038711
#         30.0       35.0       0.036710
#         35.0       40.0       0.024088
#         40.0       45.0       0.010925
#         45.0       50.0       0.002738
#         50.0       55.0       0.000259
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy, "incidence_rate", location.title()
).droplevel(["location", "year_start", "year_end"])
ectopic_pregnancy_incidence = ectopic_pregnancy_incidence.mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_2026_maternal/.venv/lib/python3.11/site-packages/get_draws/api.py:192: UserWarning: No version_id was specified, so get_draws will automatically determine a best version ID to use from the given parameters. If you want to retrieve a specific version please pass a version_id directly.
#   warnings.warn(
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_2026_maternal/.venv/lib/python3.11/site-packages/ihme_cc_rules_client/lib/rules_manager.py:224: UnrecognizedRuleWarning: Rules API returned unrecognized rule: EPI_PASS_GET_RESULTS_TO_GET_ESTIMATES. The installed ihme_cc_rules_client package (version 3.15.2) is likely outdated and should be upgraded. If you see this warning in a central environment, please submit a Help Desk ticket for Central Comp: https://helpdesk.ihme.washington.edu
#   warnings.warn(
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_2026_maternal/.venv/lib/python3.11/site-packages/ihme_cc_rules_client/lib/rules_manager.py:224: UnrecognizedRuleWarning: Rules API returned unrecognized rule: STGPR_PASS_GET_RESULTS_TO_GET_ESTIMATES. The installed ihme_cc_rules_client package (version 3.15.2) is likely outdated and should be upgraded. If you see this warning in a central environment, please submit a Help Desk ticket for Central Comp: https://helpdesk.ihme.washington.edu
#   warnings.warn(
# ________________________________________________________________________________
# [Memory] Calling vivarium_gbd_access.gbd.get_incidence_prevalence...
# get_incidence_prevalence(entity_id=c_id(374), location_id=[214], entity_type='cause', year_id=2021)
# 2025-04-29 22:46:12.173 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2025-04-29 22:46:12.179 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2025-04-29 22:46:12.179 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# 2025-04-29 22:46:12.307 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2025-04-29 22:46:12.311 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2025-04-29 22:46:12.312 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# _________________________________________get_incidence_prevalence - 3.9s, 0.1min
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_2026_maternal/.venv/lib/python3.11/site-packages/vivarium_inputs/utilities.py:492: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000084
#         15.0       20.0       0.004503
#         20.0       25.0       0.008187
#         25.0       30.0       0.010355
#         30.0       35.0       0.012122
#         35.0       40.0       0.009958
#         40.0       45.0       0.008123
#         45.0       50.0       0.004283
#         50.0       55.0       0.001283
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.003561
#         15.0       20.0       0.101503
#         20.0       25.0       0.254425
#         25.0       30.0       0.279048
#         30.0       35.0       0.258736
#         35.0       40.0       0.175028
#         40.0       45.0       0.092716
#         45.0       50.0       0.042148
#         50.0       55.0       0.004797
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/incidence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_incidence.rename("value").to_csv(path)

# %%
# https://github.com/ihmeuw/vivarium_gates_iv_iron/blob/862b057457cea2410e8d24c2c9c38c43419cd8b2/src/vivarium_gates_iv_iron/data/loader.py#L237C5-L240C6
PARTIAL_TERM: float = 24 / 52
FULL_TERM: float = 40 / 52
pregnancy_prevalence = FULL_TERM * (asfr + asfr * sbr) + PARTIAL_TERM * (
    maternal_abortion_miscarriage_incidence + ectopic_pregnancy_incidence
)
pregnancy_prevalence[pregnancy_prevalence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.002636
#         15.0       20.0       0.071646
#         20.0       25.0       0.182291
#         25.0       30.0       0.199555
#         30.0       35.0       0.184003
#         35.0       40.0       0.124161
#         40.0       45.0       0.065459
#         45.0       50.0       0.030261
#         50.0       55.0       0.003216
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/prevalence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_prevalence.rename("value").to_csv(path)

# %%
population_stratified = pd.concat(
    [
        (pregnancy_prevalence * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="pregnant")
        .set_index("pregnant", append=True)
        .value,
        ((1 - pregnancy_prevalence) * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="not_pregnant")
        .set_index("pregnant", append=True)
        .value,
    ]
).sort_index()
population_stratified
# Out:
# sex     age_start  age_end     pregnant
# Female  0.000000   0.019178    not_pregnant    7.684611e+04
#                                pregnant        0.000000e+00
#         0.019178   0.076712    not_pregnant    2.268013e+05
#                                pregnant        0.000000e+00
#         0.076712   0.500000    not_pregnant    1.653024e+06
#                                                    ...
# Male    85.000000  90.000000   pregnant        0.000000e+00
#         90.000000  95.000000   not_pregnant    4.395565e+04
#                                pregnant        0.000000e+00
#         95.000000  125.000000  not_pregnant    8.800781e+03
#                                pregnant        0.000000e+00
# Name: value, Length: 100, dtype: float64

# %%
assert np.isclose(population_stratified.sum(), total_population.sum())

# %%
population_age_groups = (
    total_population.reset_index()[["age_start", "age_end"]]
    .drop_duplicates()
    .sort_values("age_start")
)
population_age_groups
# Out:
#     age_start     age_end
# 0    0.000000    0.019178
# 1    0.019178    0.076712
# 2    0.076712    0.500000
# 3    0.500000    1.000000
# 4    1.000000    2.000000
# 5    2.000000    5.000000
# 6    5.000000   10.000000
# 7   10.000000   15.000000
# 8   15.000000   20.000000
# 9   20.000000   25.000000
# 10  25.000000   30.000000
# 11  30.000000   35.000000
# 12  35.000000   40.000000
# 13  40.000000   45.000000
# 14  45.000000   50.000000
# 15  50.000000   55.000000
# 16  55.000000   60.000000
# 17  60.000000   65.000000
# 18  65.000000   70.000000
# 19  70.000000   75.000000
# 20  75.000000   80.000000
# 21  80.000000   85.000000
# 22  85.000000   90.000000
# 23  90.000000   95.000000
# 24  95.000000  125.000000

# %%
def map_to_population_age_groups(df):
    return (
        population_age_groups.merge(df, how="cross", suffixes=("", "_orig"))
        .pipe(
            lambda df: df[
                (df.age_end <= df.age_end_orig) & (df.age_start >= df.age_start_orig)
            ]
        )
        .drop(columns=["age_start_orig", "age_end_orig"])
    )

# %%
wealth_quintile_probabilities = pd.read_csv(
    f"../results/wealth_quintile_probabilities/{location}.csv"
).set_index(["sex", "age_start", "age_end", "pregnant"])
wealth_quintile_probabilities.columns.name = "wealth_quintile"
wealth_quintile_probabilities = wealth_quintile_probabilities.stack()
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  1                  0.220707
#                                           2                  0.219801
#                                           3                  0.207518
#                                           4                  0.182416
#                                           5                  0.169557
#         5.0        15.0     not_pregnant  1                  0.222903
#                                           2                  0.211314
#                                           3                  0.200941
#                                           4                  0.189893
#                                           5                  0.174949
#         15.0       30.0     not_pregnant  1                  0.165248
#                                           2                  0.194708
#                                           3                  0.200403
#                                           4                  0.223650
#                                           5                  0.215992
#                             pregnant      1                  0.229568
#                                           2                  0.269087
#                                           3                  0.218290
#                                           4                  0.169175
#                                           5                  0.113880
#         30.0       50.0     not_pregnant  1                  0.167414
#                                           2                  0.176150
#                                           3                  0.188366
#                                           4                  0.214621
#                                           5                  0.253449
#                             pregnant      1                  0.247900
#                                           2                  0.197054
#                                           3                  0.182014
#                                           4                  0.163763
#                                           5                  0.209268
#         50.0       125.0    not_pregnant  1                  0.196077
#                                           2                  0.184902
#                                           3                  0.228885
#                                           4                  0.192974
#                                           5                  0.197161
# Male    0.0        5.0      not_pregnant  1                  0.214963
#                                           2                  0.223211
#                                           3                  0.203137
#                                           4                  0.188194
#                                           5                  0.170495
#         5.0        15.0     not_pregnant  1                  0.227134
#                                           2                  0.211917
#                                           3                  0.202795
#                                           4                  0.189340
#                                           5                  0.168813
#         15.0       30.0     not_pregnant  1                  0.194480
#                                           2                  0.197231
#                                           3                  0.196587
#                                           4                  0.211924
#                                           5                  0.199779
#         30.0       50.0     not_pregnant  1                  0.155586
#                                           2                  0.166481
#                                           3                  0.189007
#                                           4                  0.217201
#                                           5                  0.271724
#         50.0       125.0    not_pregnant  1                  0.209864
#                                           2                  0.183658
#                                           3                  0.188784
#                                           4                  0.202148
#                                           5                  0.215546
# dtype: float64

# %%
wealth_quintile_probabilities = (
    map_to_population_age_groups(
        wealth_quintile_probabilities.rename("value").reset_index()
    )
    .set_index(wealth_quintile_probabilities.index.names)
    .value
)
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  0.220707
#                                              2                  0.219801
#                                              3                  0.207518
#                                              4                  0.182416
#                                              5                  0.169557
#                                                                   ...
# Male    95.0       125.000000  not_pregnant  1                  0.209864
#                                              2                  0.183658
#                                              3                  0.188784
#                                              4                  0.202148
#                                              5                  0.215546
# Name: value, Length: 285, dtype: float64

# %%
assert np.allclose(
    wealth_quintile_probabilities.groupby(population_stratified.index.names).sum(), 1.0
)

# %%
population_stratified = population_stratified.mul(
    wealth_quintile_probabilities, axis=0
).dropna()
population_stratified
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  16960.496219
#                                              2                  16890.884668
#                                              3                  15946.960379
#                                              4                  14017.956071
#                                              5                  13029.810174
#                                                                     ...
# Male    95.0       125.000000  not_pregnant  1                   1846.968043
#                                              2                   1616.329970
#                                              3                   1661.447043
#                                              4                   1779.062429
#                                              5                   1896.973078
# Name: value, Length: 285, dtype: float64

# %%
population_stratified.sum()
# Out:
# 231112316.79920968

# %%
total_population.sum()
# Out:
# 231165679.26551884

# %%
assert np.isclose(population_stratified.sum(), total_population.sum(), rtol=0.01)

# %%
path = pathlib.Path(f"../results/population/stratified/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
population_stratified.rename("value").to_csv(path)
