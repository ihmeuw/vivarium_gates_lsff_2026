{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
total_population.rename("value").to_csv(path)

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location.title()
).droplevel(["location", "year_start", "year_end"])
asfr = (
    asfr[asfr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
asfr[asfr > 0]
# Out:
# 2026-09-13 18:18:41.423 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.424 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.430 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:41.455 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.457 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.463 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:41.472 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.475 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.489 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-13 18:18:41.494 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.496 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.509 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-09-13 18:18:41.518 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.520 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.524 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:41.532 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.534 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.539 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-13 18:18:41.564 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.567 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.571 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:41.584 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.586 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.589 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:41.594 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.596 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.599 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-13 18:18:41.620 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.622 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.625 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:41.630 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.631 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.634 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:41.640 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.642 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.645 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:41.658 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.660 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.663 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:41.670 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.672 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.677 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:41.707 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.710 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.715 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-13 18:18:41.734 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.737 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.741 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-13 18:18:41.755 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.757 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.761 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:41.772 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.774 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.777 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:41.792 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:41.793 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:41.796 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# sex     age_start  age_end
# Female  10.0       15.0       0.005714
#         15.0       20.0       0.070244
#         20.0       25.0       0.194484
#         25.0       30.0       0.208935
#         30.0       35.0       0.194076
#         35.0       40.0       0.127396
#         40.0       45.0       0.067482
#         45.0       50.0       0.031121
#         50.0       55.0       0.002821
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.stillbirth_28_weeks_to_live_birth_ratio, "estimate", location.title()
)
sbr = (
    sbr[sbr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
assert len(sbr) == 1
sbr = sbr.iloc[0]
sbr
# Out:
# 2026-09-13 18:18:42.098 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.099 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.103 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:42.113 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.116 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.131 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:42.146 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.147 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.171 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-13 18:18:42.175 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.175 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.188 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-09-13 18:18:42.196 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.197 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.199 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:42.203 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.203 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.206 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-13 18:18:42.235 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.236 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.239 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:42.243 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.243 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.246 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:42.251 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.252 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.255 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:42.259 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.260 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.262 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:42.277 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.278 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.281 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:42.291 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.292 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.294 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:42.305 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.307 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.320 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:42.376 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.377 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.382 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-13 18:18:42.387 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.389 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.394 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:42.405 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.407 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.410 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:42.419 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.430 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.433 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 0.0263411623194878

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location.title(),
).droplevel(["location", "year_start", "year_end"])
maternal_abortion_miscarriage_incidence = maternal_abortion_miscarriage_incidence.mean(
    axis=1
)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# 2026-09-13 18:18:42.562 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.563 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.571 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:42.598 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.606 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.619 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:42.636 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.651 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.662 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:42.691 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.693 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.698 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-13 18:18:42.702 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.703 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.720 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-13 18:18:42.732 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.733 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.736 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:42.740 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.741 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.743 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-13 18:18:42.755 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-13 18:18:42.758 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.760 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.764 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:42.770 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.773 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.777 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:42.797 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.800 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.816 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-13 18:18:42.829 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-13 18:18:42.833 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-13 18:18:42.905 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:42.913 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:42.920 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:43.057 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.061 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.074 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:43.091 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.094 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.099 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:43.115 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.120 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.126 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:43.158 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.162 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.173 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:43.186 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.193 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.209 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-13 18:18:43.216 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.221 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.231 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-13 18:18:43.248 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.252 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.274 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:43.288 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.291 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.306 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-13 18:18:43.329 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-13 18:18:43.336 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.338 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.343 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:43.362 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.366 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.378 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:43.385 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.387 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.391 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-13 18:18:43.417 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-13 18:18:43.421 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-13 18:18:43.471 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.480 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.491 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:43.677 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.680 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.685 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:43.694 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.696 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.715 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:43.739 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.740 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.743 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:43.772 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.773 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.776 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:43.784 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.784 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.787 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:43.816 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.817 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.820 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-13 18:18:43.840 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.841 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.844 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-13 18:18:43.855 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.856 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.859 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:43.878 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.883 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.889 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:43.905 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:43.906 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:43.924 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /mnt/team/simulation_science/priv/engineering/jenkins/shared_envs/vivarium_gates_lsff_2026_artifact_current/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.006976
#         15.0       20.0       0.074024
#         20.0       25.0       0.177579
#         25.0       30.0       0.164486
#         30.0       35.0       0.146138
#         35.0       40.0       0.103056
#         40.0       45.0       0.063297
#         45.0       50.0       0.035266
#         50.0       55.0       0.003660
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy, "incidence_rate", location.title()
).droplevel(["location", "year_start", "year_end"])
ectopic_pregnancy_incidence = ectopic_pregnancy_incidence.mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# 2026-09-13 18:18:44.203 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.204 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.208 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:44.227 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.229 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.241 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:44.266 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.273 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.284 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:44.302 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.305 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.311 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-13 18:18:44.318 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.320 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.338 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-13 18:18:44.367 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.370 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.380 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:44.387 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.389 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.394 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-13 18:18:44.416 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-13 18:18:44.421 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.423 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.428 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:44.445 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.447 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.450 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:44.454 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.456 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.464 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-13 18:18:44.473 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-13 18:18:44.475 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-13 18:18:44.515 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.525 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.532 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:44.790 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.791 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.794 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:44.798 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.800 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.810 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:44.825 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.829 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.834 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:44.894 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.904 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.913 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:44.933 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.937 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.947 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-13 18:18:44.952 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.954 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.968 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-13 18:18:44.978 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:44.980 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:44.983 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:45.000 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.003 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.013 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-13 18:18:45.042 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-13 18:18:45.065 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.069 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.087 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:45.094 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.097 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.105 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:45.121 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.123 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.127 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-13 18:18:45.135 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-13 18:18:45.136 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-13 18:18:45.195 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.196 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.199 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:45.313 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.315 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.319 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-13 18:18:45.326 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.330 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.336 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-13 18:18:45.357 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.359 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.375 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-13 18:18:45.397 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.399 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.410 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:45.435 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.448 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.455 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:45.501 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.503 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.508 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-13 18:18:45.529 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.537 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.568 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-13 18:18:45.573 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.574 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.577 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:45.585 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.586 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.589 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-13 18:18:45.600 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-09-13 18:18:45.601 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-09-13 18:18:45.612 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /mnt/team/simulation_science/priv/engineering/jenkins/shared_envs/vivarium_gates_lsff_2026_artifact_current/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000623
#         15.0       20.0       0.002269
#         20.0       25.0       0.003786
#         25.0       30.0       0.003659
#         30.0       35.0       0.003887
#         35.0       40.0       0.003440
#         40.0       45.0       0.003382
#         45.0       50.0       0.002765
#         50.0       55.0       0.000730
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.013464
#         15.0       20.0       0.148388
#         20.0       25.0       0.380972
#         25.0       30.0       0.382582
#         30.0       35.0       0.349213
#         35.0       40.0       0.237248
#         40.0       45.0       0.135939
#         45.0       50.0       0.069972
#         50.0       55.0       0.007286
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/incidence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_incidence.rename("value").to_csv(path)

# %%
# https://github.com/ihmeuw/vivarium_gates_iv_iron/blob/862b057457cea2410e8d24c2c9c38c43419cd8b2/src/vivarium_gates_iv_iron/data/loader.py#L237C5-L240C6
PARTIAL_TERM: float = 24 / 52
FULL_TERM: float = 40 / 52
pregnancy_prevalence = FULL_TERM * (asfr + asfr * sbr) + PARTIAL_TERM * (
    maternal_abortion_miscarriage_incidence + ectopic_pregnancy_incidence
)
pregnancy_prevalence[pregnancy_prevalence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.008019
#         15.0       20.0       0.090669
#         20.0       25.0       0.237251
#         25.0       30.0       0.242557
#         30.0       35.0       0.222464
#         35.0       40.0       0.149730
#         40.0       45.0       0.084052
#         45.0       50.0       0.042123
#         50.0       55.0       0.004254
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/prevalence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_prevalence.rename("value").to_csv(path)

# %%
population_stratified = pd.concat(
    [
        (pregnancy_prevalence * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="pregnant")
        .set_index("pregnant", append=True)
        .value,
        ((1 - pregnancy_prevalence) * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="not_pregnant")
        .set_index("pregnant", append=True)
        .value,
    ]
).sort_index()
population_stratified
# Out:
# sex     age_start  age_end     pregnant
# Female  0.000000   0.019178    not_pregnant    7.907591e+04
#                                pregnant        0.000000e+00
#         0.019178   0.076712    not_pregnant    2.337381e+05
#                                pregnant        0.000000e+00
#         0.076712   0.500000    not_pregnant    1.706685e+06
#                                                    ...
# Male    85.000000  90.000000   pregnant        0.000000e+00
#         90.000000  95.000000   not_pregnant    6.687309e+04
#                                pregnant        0.000000e+00
#         95.000000  125.000000  not_pregnant    2.409231e+04
#                                pregnant        0.000000e+00
# Name: value, Length: 100, dtype: float64

# %%
assert np.isclose(population_stratified.sum(), total_population.sum())

# %%
population_age_groups = (
    total_population.reset_index()[["age_start", "age_end"]]
    .drop_duplicates()
    .sort_values("age_start")
)
population_age_groups
# Out:
#     age_start     age_end
# 0    0.000000    0.019178
# 1    0.019178    0.076712
# 2    0.076712    0.500000
# 3    0.500000    1.000000
# 4    1.000000    2.000000
# 5    2.000000    5.000000
# 6    5.000000   10.000000
# 7   10.000000   15.000000
# 8   15.000000   20.000000
# 9   20.000000   25.000000
# 10  25.000000   30.000000
# 11  30.000000   35.000000
# 12  35.000000   40.000000
# 13  40.000000   45.000000
# 14  45.000000   50.000000
# 15  50.000000   55.000000
# 16  55.000000   60.000000
# 17  60.000000   65.000000
# 18  65.000000   70.000000
# 19  70.000000   75.000000
# 20  75.000000   80.000000
# 21  80.000000   85.000000
# 22  85.000000   90.000000
# 23  90.000000   95.000000
# 24  95.000000  125.000000

# %%
def map_to_population_age_groups(df):
    return (
        population_age_groups.merge(df, how="cross", suffixes=("", "_orig"))
        .pipe(
            lambda df: df[
                (df.age_end <= df.age_end_orig) & (df.age_start >= df.age_start_orig)
            ]
        )
        .drop(columns=["age_start_orig", "age_end_orig"])
    )

# %%
wealth_quintile_probabilities = pd.read_csv(
    f"../results/wealth_quintile_probabilities/{location}.csv"
).set_index(["sex", "age_start", "age_end", "pregnant"])
wealth_quintile_probabilities.columns.name = "wealth_quintile"
wealth_quintile_probabilities = wealth_quintile_probabilities.stack()
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  1                  0.237660
#                                           2                  0.225487
#                                           3                  0.203977
#                                           4                  0.178487
#                                           5                  0.154389
#         5.0        15.0     not_pregnant  1                  0.222657
#                                           2                  0.219831
#                                           3                  0.200573
#                                           4                  0.188057
#                                           5                  0.168882
#         15.0       30.0     not_pregnant  1                  0.165585
#                                           2                  0.191566
#                                           3                  0.209803
#                                           4                  0.226150
#                                           5                  0.206896
#                             pregnant      1                  0.228131
#                                           2                  0.261971
#                                           3                  0.225828
#                                           4                  0.174600
#                                           5                  0.109470
#         30.0       50.0     not_pregnant  1                  0.169298
#                                           2                  0.173463
#                                           3                  0.186056
#                                           4                  0.208814
#                                           5                  0.262369
#                             pregnant      1                  0.231282
#                                           2                  0.190765
#                                           3                  0.171661
#                                           4                  0.205521
#                                           5                  0.200770
#         50.0       125.0    not_pregnant  1                  0.183495
#                                           2                  0.183221
#                                           3                  0.202734
#                                           4                  0.200921
#                                           5                  0.229630
# Male    0.0        5.0      not_pregnant  1                  0.245259
#                                           2                  0.222780
#                                           3                  0.202629
#                                           4                  0.173367
#                                           5                  0.155965
#         5.0        15.0     not_pregnant  1                  0.227679
#                                           2                  0.210604
#                                           3                  0.201929
#                                           4                  0.192289
#                                           5                  0.167499
#         15.0       30.0     not_pregnant  1                  0.171533
#                                           2                  0.196784
#                                           3                  0.207765
#                                           4                  0.218414
#                                           5                  0.205504
#         30.0       50.0     not_pregnant  1                  0.155384
#                                           2                  0.167111
#                                           3                  0.188403
#                                           4                  0.219586
#                                           5                  0.269516
#         50.0       125.0    not_pregnant  1                  0.201294
#                                           2                  0.181435
#                                           3                  0.189684
#                                           4                  0.188895
#                                           5                  0.238693
# dtype: float64

# %%
wealth_quintile_probabilities = (
    map_to_population_age_groups(
        wealth_quintile_probabilities.rename("value").reset_index()
    )
    .set_index(wealth_quintile_probabilities.index.names)
    .value
)
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  0.237660
#                                              2                  0.225487
#                                              3                  0.203977
#                                              4                  0.178487
#                                              5                  0.154389
#                                                                   ...
# Male    95.0       125.000000  not_pregnant  1                  0.201294
#                                              2                  0.181435
#                                              3                  0.189684
#                                              4                  0.188895
#                                              5                  0.238693
# Name: value, Length: 285, dtype: float64

# %%
assert np.allclose(
    wealth_quintile_probabilities.groupby(population_stratified.index.names).sum(), 1.0
)

# %%
population_stratified = population_stratified.mul(
    wealth_quintile_probabilities, axis=0
).dropna()
population_stratified
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  18793.149621
#                                              2                  17830.620200
#                                              3                  16129.662368
#                                              4                  14114.028154
#                                              5                  12208.445301
#                                                                     ...
# Male    95.0       125.000000  not_pregnant  1                   4849.649774
#                                              2                   4371.181536
#                                              3                   4569.918352
#                                              4                   4550.906874
#                                              5                   5750.658068
# Name: value, Length: 285, dtype: float64

# %%
population_stratified.sum()
# Out:
# 244684507.26680964

# %%
total_population.sum()
# Out:
# 244833398.85833606

# %%
assert np.isclose(population_stratified.sum(), total_population.sum(), rtol=0.01)

# %%
path = pathlib.Path(f"../results/population/stratified/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
population_stratified.rename("value").to_csv(path)
