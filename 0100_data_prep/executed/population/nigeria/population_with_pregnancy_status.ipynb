{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
total_population.rename("value").to_csv(path)

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location.title()
).droplevel(["location", "year_start", "year_end"])
asfr = (
    asfr[asfr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
asfr[asfr > 0]
# Out:
# 2026-09-02 11:07:55.783 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.784 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.790 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:55.799 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.800 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.806 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:55.814 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.815 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.820 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-02 11:07:55.825 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.826 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.845 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-09-02 11:07:55.857 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.858 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.864 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:55.869 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.870 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.877 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-02 11:07:55.890 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.891 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.895 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:55.900 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.901 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.905 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:55.910 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.911 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.916 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-02 11:07:55.925 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.926 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.930 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:55.933 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.934 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.938 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:55.943 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.944 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.948 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:55.961 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.962 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.966 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:55.971 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.972 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.976 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:55.988 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:55.989 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:55.992 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-02 11:07:56.002 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.003 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.006 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-02 11:07:56.010 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.011 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.014 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.019 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.020 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.024 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.028 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.029 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.032 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# sex     age_start  age_end
# Female  10.0       15.0       0.005714
#         15.0       20.0       0.070244
#         20.0       25.0       0.194484
#         25.0       30.0       0.208935
#         30.0       35.0       0.194076
#         35.0       40.0       0.127396
#         40.0       45.0       0.067482
#         45.0       50.0       0.031121
#         50.0       55.0       0.002821
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.stillbirth_28_weeks_to_live_birth_ratio, "estimate", location.title()
)
sbr = (
    sbr[sbr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
assert len(sbr) == 1
sbr = sbr.iloc[0]
sbr
# Out:
# 2026-09-02 11:07:56.149 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.151 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.155 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.160 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.161 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.166 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.171 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.172 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.176 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-02 11:07:56.179 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.180 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.196 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-09-02 11:07:56.202 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.202 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.205 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:56.207 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.208 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.210 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-02 11:07:56.215 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.215 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.217 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:56.219 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.219 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.221 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:56.224 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.225 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.227 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:56.229 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.229 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.231 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:56.234 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.235 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.237 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:56.244 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.245 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.247 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.251 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.251 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.254 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.261 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.262 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.264 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-02 11:07:56.267 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.268 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.270 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.274 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.274 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.277 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.281 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.281 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.284 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 0.0263411623194878

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location.title(),
).droplevel(["location", "year_start", "year_end"])
maternal_abortion_miscarriage_incidence = maternal_abortion_miscarriage_incidence.mean(
    axis=1
)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# 2026-09-02 11:07:56.339 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.340 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.345 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.352 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.354 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.358 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.365 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.366 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.371 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.377 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.378 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.383 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-02 11:07:56.387 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.388 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.406 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-02 11:07:56.420 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.424 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.428 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:56.434 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.435 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.441 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-02 11:07:56.457 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-02 11:07:56.460 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.461 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.466 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:56.470 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.471 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.475 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:56.480 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.481 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.485 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-02 11:07:56.492 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-02 11:07:56.493 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-02 11:07:56.513 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.514 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.518 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:56.579 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.581 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.584 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:56.586 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.587 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.590 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:56.595 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.596 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.599 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:56.609 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.610 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.613 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.617 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.617 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.620 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-02 11:07:56.623 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.623 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.627 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-02 11:07:56.632 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.632 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.635 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:56.638 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.638 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.641 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-02 11:07:56.649 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-02 11:07:56.651 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.651 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.654 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:56.657 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.657 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.660 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:56.663 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.664 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.667 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-02 11:07:56.671 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-02 11:07:56.672 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-02 11:07:56.687 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.687 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.690 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:56.737 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.737 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.740 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:56.742 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.743 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.745 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:56.750 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.751 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.753 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:56.764 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.764 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.767 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.771 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.771 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.774 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.781 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.782 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.784 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-02 11:07:56.792 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.792 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.795 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-02 11:07:56.798 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.798 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.801 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.805 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.805 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.808 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.812 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.813 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.815 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/albrja/miniconda3/envs/vivarium_gates_lsff_2026_artifact/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.006976
#         15.0       20.0       0.074024
#         20.0       25.0       0.177579
#         25.0       30.0       0.164486
#         30.0       35.0       0.146138
#         35.0       40.0       0.103056
#         40.0       45.0       0.063297
#         45.0       50.0       0.035266
#         50.0       55.0       0.003660
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy, "incidence_rate", location.title()
).droplevel(["location", "year_start", "year_end"])
ectopic_pregnancy_incidence = ectopic_pregnancy_incidence.mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# 2026-09-02 11:07:56.892 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.893 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.898 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.905 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.906 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.910 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.915 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.916 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.920 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:56.926 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.926 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.931 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-02 11:07:56.934 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.935 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.952 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-02 11:07:56.966 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.968 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.973 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:56.979 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:56.980 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:56.986 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-02 11:07:57.001 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-02 11:07:57.005 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.006 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.011 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:57.015 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.016 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.020 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:57.025 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.026 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.030 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-02 11:07:57.037 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-02 11:07:57.038 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-02 11:07:57.061 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.062 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.066 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:57.130 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.130 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.133 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:57.136 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.137 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.139 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:57.145 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.145 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.148 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:57.159 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.160 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.163 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:57.167 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.168 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.171 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-02 11:07:57.173 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.174 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.177 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-09-02 11:07:57.183 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.183 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.186 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:57.189 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.189 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.192 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-09-02 11:07:57.200 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-09-02 11:07:57.202 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.203 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.206 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:57.210 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.210 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.214 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:57.217 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.218 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.222 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-02 11:07:57.228 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-09-02 11:07:57.229 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-09-02 11:07:57.248 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.249 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.252 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:57.306 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.307 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.310 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-09-02 11:07:57.312 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.313 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.316 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-09-02 11:07:57.321 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.321 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.325 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-09-02 11:07:57.337 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.337 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.340 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:57.344 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.345 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.348 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:57.356 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.357 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.360 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-09-02 11:07:57.367 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.368 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.371 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-09-02 11:07:57.374 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.375 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.377 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:57.381 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.382 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.385 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-09-02 11:07:57.388 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# 2026-09-02 11:07:57.389 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/share/scratch/users/albrja/cache'
# 2026-09-02 11:07:57.392 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/albrja/miniconda3/envs/vivarium_gates_lsff_2026_artifact/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000623
#         15.0       20.0       0.002269
#         20.0       25.0       0.003786
#         25.0       30.0       0.003659
#         30.0       35.0       0.003887
#         35.0       40.0       0.003440
#         40.0       45.0       0.003382
#         45.0       50.0       0.002765
#         50.0       55.0       0.000730
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.013464
#         15.0       20.0       0.148388
#         20.0       25.0       0.380972
#         25.0       30.0       0.382582
#         30.0       35.0       0.349213
#         35.0       40.0       0.237248
#         40.0       45.0       0.135939
#         45.0       50.0       0.069972
#         50.0       55.0       0.007286
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/incidence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_incidence.rename("value").to_csv(path)

# %%
# https://github.com/ihmeuw/vivarium_gates_iv_iron/blob/862b057457cea2410e8d24c2c9c38c43419cd8b2/src/vivarium_gates_iv_iron/data/loader.py#L237C5-L240C6
PARTIAL_TERM: float = 24 / 52
FULL_TERM: float = 40 / 52
pregnancy_prevalence = FULL_TERM * (asfr + asfr * sbr) + PARTIAL_TERM * (
    maternal_abortion_miscarriage_incidence + ectopic_pregnancy_incidence
)
pregnancy_prevalence[pregnancy_prevalence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.008019
#         15.0       20.0       0.090669
#         20.0       25.0       0.237251
#         25.0       30.0       0.242557
#         30.0       35.0       0.222464
#         35.0       40.0       0.149730
#         40.0       45.0       0.084052
#         45.0       50.0       0.042123
#         50.0       55.0       0.004254
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/prevalence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_prevalence.rename("value").to_csv(path)

# %%
population_stratified = pd.concat(
    [
        (pregnancy_prevalence * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="pregnant")
        .set_index("pregnant", append=True)
        .value,
        ((1 - pregnancy_prevalence) * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="not_pregnant")
        .set_index("pregnant", append=True)
        .value,
    ]
).sort_index()
population_stratified
# Out:
# sex     age_start  age_end     pregnant
# Female  0.000000   0.019178    not_pregnant    7.907591e+04
#                                pregnant        0.000000e+00
#         0.019178   0.076712    not_pregnant    2.337381e+05
#                                pregnant        0.000000e+00
#         0.076712   0.500000    not_pregnant    1.706685e+06
#                                                    ...
# Male    85.000000  90.000000   pregnant        0.000000e+00
#         90.000000  95.000000   not_pregnant    6.687309e+04
#                                pregnant        0.000000e+00
#         95.000000  125.000000  not_pregnant    2.409231e+04
#                                pregnant        0.000000e+00
# Name: value, Length: 100, dtype: float64

# %%
assert np.isclose(population_stratified.sum(), total_population.sum())

# %%
population_age_groups = (
    total_population.reset_index()[["age_start", "age_end"]]
    .drop_duplicates()
    .sort_values("age_start")
)
population_age_groups
# Out:
#     age_start     age_end
# 0    0.000000    0.019178
# 1    0.019178    0.076712
# 2    0.076712    0.500000
# 3    0.500000    1.000000
# 4    1.000000    2.000000
# 5    2.000000    5.000000
# 6    5.000000   10.000000
# 7   10.000000   15.000000
# 8   15.000000   20.000000
# 9   20.000000   25.000000
# 10  25.000000   30.000000
# 11  30.000000   35.000000
# 12  35.000000   40.000000
# 13  40.000000   45.000000
# 14  45.000000   50.000000
# 15  50.000000   55.000000
# 16  55.000000   60.000000
# 17  60.000000   65.000000
# 18  65.000000   70.000000
# 19  70.000000   75.000000
# 20  75.000000   80.000000
# 21  80.000000   85.000000
# 22  85.000000   90.000000
# 23  90.000000   95.000000
# 24  95.000000  125.000000

# %%
def map_to_population_age_groups(df):
    return (
        population_age_groups.merge(df, how="cross", suffixes=("", "_orig"))
        .pipe(
            lambda df: df[
                (df.age_end <= df.age_end_orig) & (df.age_start >= df.age_start_orig)
            ]
        )
        .drop(columns=["age_start_orig", "age_end_orig"])
    )

# %%
wealth_quintile_probabilities = pd.read_csv(
    f"../results/wealth_quintile_probabilities/{location}.csv"
).set_index(["sex", "age_start", "age_end", "pregnant"])
wealth_quintile_probabilities.columns.name = "wealth_quintile"
wealth_quintile_probabilities = wealth_quintile_probabilities.stack()
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  1                  0.220707
#                                           2                  0.219801
#                                           3                  0.207518
#                                           4                  0.182416
#                                           5                  0.169557
#         5.0        15.0     not_pregnant  1                  0.222903
#                                           2                  0.211314
#                                           3                  0.200941
#                                           4                  0.189893
#                                           5                  0.174949
#         15.0       30.0     not_pregnant  1                  0.165248
#                                           2                  0.194708
#                                           3                  0.200403
#                                           4                  0.223650
#                                           5                  0.215992
#                             pregnant      1                  0.229568
#                                           2                  0.269087
#                                           3                  0.218290
#                                           4                  0.169175
#                                           5                  0.113880
#         30.0       50.0     not_pregnant  1                  0.167414
#                                           2                  0.176150
#                                           3                  0.188366
#                                           4                  0.214621
#                                           5                  0.253449
#                             pregnant      1                  0.247900
#                                           2                  0.197054
#                                           3                  0.182014
#                                           4                  0.163763
#                                           5                  0.209268
#         50.0       125.0    not_pregnant  1                  0.196077
#                                           2                  0.184902
#                                           3                  0.228885
#                                           4                  0.192974
#                                           5                  0.197161
# Male    0.0        5.0      not_pregnant  1                  0.214963
#                                           2                  0.223211
#                                           3                  0.203137
#                                           4                  0.188194
#                                           5                  0.170495
#         5.0        15.0     not_pregnant  1                  0.227134
#                                           2                  0.211917
#                                           3                  0.202795
#                                           4                  0.189340
#                                           5                  0.168813
#         15.0       30.0     not_pregnant  1                  0.194480
#                                           2                  0.197231
#                                           3                  0.196587
#                                           4                  0.211924
#                                           5                  0.199779
#         30.0       50.0     not_pregnant  1                  0.155586
#                                           2                  0.166481
#                                           3                  0.189007
#                                           4                  0.217201
#                                           5                  0.271724
#         50.0       125.0    not_pregnant  1                  0.209864
#                                           2                  0.183658
#                                           3                  0.188784
#                                           4                  0.202148
#                                           5                  0.215546
# dtype: float64

# %%
wealth_quintile_probabilities = (
    map_to_population_age_groups(
        wealth_quintile_probabilities.rename("value").reset_index()
    )
    .set_index(wealth_quintile_probabilities.index.names)
    .value
)
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  0.220707
#                                              2                  0.219801
#                                              3                  0.207518
#                                              4                  0.182416
#                                              5                  0.169557
#                                                                   ...
# Male    95.0       125.000000  not_pregnant  1                  0.209864
#                                              2                  0.183658
#                                              3                  0.188784
#                                              4                  0.202148
#                                              5                  0.215546
# Name: value, Length: 285, dtype: float64

# %%
assert np.allclose(
    wealth_quintile_probabilities.groupby(population_stratified.index.names).sum(), 1.0
)

# %%
population_stratified = population_stratified.mul(
    wealth_quintile_probabilities, axis=0
).dropna()
population_stratified
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  17452.628925
#                                              2                  17380.997496
#                                              3                  16409.683914
#                                              4                  14424.706826
#                                              5                  13407.888483
#                                                                     ...
# Male    95.0       125.000000  not_pregnant  1                   5056.112334
#                                              2                   4424.735951
#                                              3                   4548.244848
#                                              4                   4870.219344
#                                              5                   5193.002126
# Name: value, Length: 285, dtype: float64

# %%
population_stratified.sum()
# Out:
# 244684507.26680964

# %%
total_population.sum()
# Out:
# 244833398.85833606

# %%
assert np.isclose(population_stratified.sum(), total_population.sum(), rtol=0.01)

# %%
path = pathlib.Path(f"../results/population/stratified/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
population_stratified.rename("value").to_csv(path)
