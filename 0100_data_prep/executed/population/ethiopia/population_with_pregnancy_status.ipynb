# %%
import vivarium_inputs
import gbd_mapping
import pathlib
import pandas as pd, numpy as np
# Out:
# Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# Cache Dir: '/share/scratch/users/zmbc/cache'

# %%
location = "india"

# %%
# Parameters
location = "ethiopia"

# %%
total_population = (
    vivarium_inputs.get_population_structure(location.title())
    .droplevel(["location", "year_start", "year_end"])
    .value
)
total_population
# Out:
# ________________________________________________________________________________
# [Memory] Calling vivarium_gbd_access.gbd.get_population...
# get_population([179], year_id=2021)
# ___________________________________________________get_population - 0.1s, 0.0min
# sex     age_start  age_end
# Female  0.000000   0.019178      3.212946e+04
#         0.019178   0.076712      9.536547e+04
#         0.076712   0.500000      6.969145e+05
#         0.500000   1.000000      8.069227e+05
#         1.000000   2.000000      1.588942e+06
#         2.000000   5.000000      4.570339e+06
#         5.000000   10.000000     7.086744e+06
#         10.000000  15.000000     6.753936e+06
#         15.000000  20.000000     6.312640e+06
#         20.000000  25.000000     5.498329e+06
#         25.000000  30.000000     4.610923e+06
#         30.000000  35.000000     3.775392e+06
#         35.000000  40.000000     3.162866e+06
#         40.000000  45.000000     2.535855e+06
#         45.000000  50.000000     1.823107e+06
#         50.000000  55.000000     1.317891e+06
#         55.000000  60.000000     1.005600e+06
#         60.000000  65.000000     7.821221e+05
#         65.000000  70.000000     6.265289e+05
#         70.000000  75.000000     4.023876e+05
#         75.000000  80.000000     2.886510e+05
#         80.000000  85.000000     1.627737e+05
#         85.000000  90.000000     7.026548e+04
#         90.000000  95.000000     2.081378e+04
#         95.000000  125.000000    4.509602e+03
# Male    0.000000   0.019178      3.402968e+04
#         0.019178   0.076712      1.004124e+05
#         0.076712   0.500000      7.330473e+05
#         0.500000   1.000000      8.480661e+05
#         1.000000   2.000000      1.666316e+06
#         2.000000   5.000000      4.792631e+06
#         5.000000   10.000000     7.438956e+06
#         10.000000  15.000000     7.105682e+06
#         15.000000  20.000000     6.534922e+06
#         20.000000  25.000000     5.515785e+06
#         25.000000  30.000000     4.467484e+06
#         30.000000  35.000000     3.554660e+06
#         35.000000  40.000000     2.921799e+06
#         40.000000  45.000000     2.434087e+06
#         45.000000  50.000000     1.887319e+06
#         50.000000  55.000000     1.388927e+06
#         55.000000  60.000000     1.043628e+06
#         60.000000  65.000000     7.902743e+05
#         65.000000  70.000000     6.258484e+05
#         70.000000  75.000000     4.456226e+05
#         75.000000  80.000000     3.135171e+05
#         80.000000  85.000000     1.697816e+05
#         85.000000  90.000000     7.010511e+04
#         90.000000  95.000000     1.965910e+04
#         95.000000  125.000000    3.488085e+03
# Name: value, dtype: float64

# %%
path = pathlib.Path(f"../results/population/total/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
total_population.rename("value").to_csv(path)

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location.title()
).droplevel(["location", "year_start", "year_end"])
asfr = (
    asfr[asfr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
asfr[asfr > 0]
# Out:
# ________________________________________________________________________________
# [Memory] Calling vivarium_gbd_access.gbd.get_covariate_estimate...
# get_covariate_estimate(13, [179], year_id=2021)
# ___________________________________________get_covariate_estimate - 0.2s, 0.0min
# sex     age_start  age_end
# Female  10.0       15.0       0.002573
#         15.0       20.0       0.045776
#         20.0       25.0       0.191993
#         25.0       30.0       0.184309
#         30.0       35.0       0.178496
#         35.0       40.0       0.126932
#         40.0       45.0       0.066364
#         45.0       50.0       0.021933
#         50.0       55.0       0.002033
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.stillbirth_to_live_birth_ratio, "estimate", location.title()
)
sbr = (
    sbr[sbr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
assert len(sbr) == 1
sbr = sbr.iloc[0]
sbr
# Out:
# ________________________________________________________________________________
# [Memory] Calling vivarium_gbd_access.gbd.get_covariate_estimate...
# get_covariate_estimate(2267, [179], year_id=2021)
# ___________________________________________get_covariate_estimate - 0.2s, 0.0min
# 0.0175716641363179

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location.title(),
).droplevel(["location", "year_start", "year_end"])
maternal_abortion_miscarriage_incidence = maternal_abortion_miscarriage_incidence.mean(
    axis=1
)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# ________________________________________________________________________________
# [Memory] Calling vivarium_gbd_access.gbd.get_incidence_prevalence...
# get_incidence_prevalence(entity_id=c_id(995), location_id=[179], entity_type='cause', year_id=2021)
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/ihme_cc_rules_client/lib/rules_manager.py:224: UnrecognizedRuleWarning: Rules API returned unrecognized rule: EPI_PASS_GET_RESULTS_TO_GET_ESTIMATES. The installed ihme_cc_rules_client package (version 3.15.2) is likely outdated and should be upgraded. If you see this warning in a central environment, please submit a Help Desk ticket for Central Comp: https://helpdesk.ihme.washington.edu
#   warnings.warn(
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/ihme_cc_rules_client/lib/rules_manager.py:224: UnrecognizedRuleWarning: Rules API returned unrecognized rule: STGPR_PASS_GET_RESULTS_TO_GET_ESTIMATES. The installed ihme_cc_rules_client package (version 3.15.2) is likely outdated and should be upgraded. If you see this warning in a central environment, please submit a Help Desk ticket for Central Comp: https://helpdesk.ihme.washington.edu
#   warnings.warn(
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/get_draws/api.py:192: UserWarning: No version_id was specified, so get_draws will automatically determine a best version ID to use from the given parameters. If you want to retrieve a specific version please pass a version_id directly.
#   warnings.warn(
# 2025-04-29 22:46:07.695 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2025-04-29 22:46:07.699 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2025-04-29 22:46:07.700 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# 2025-04-29 22:46:07.809 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2025-04-29 22:46:07.812 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2025-04-29 22:46:07.813 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# ________________________________________get_incidence_prevalence - 12.5s, 0.2min
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/vivarium_inputs/utilities.py:492: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000782
#         15.0       20.0       0.027543
#         20.0       25.0       0.105360
#         25.0       30.0       0.094651
#         30.0       35.0       0.088526
#         35.0       40.0       0.061951
#         40.0       45.0       0.027148
#         45.0       50.0       0.007389
#         50.0       55.0       0.000662
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy, "incidence_rate", location.title()
).droplevel(["location", "year_start", "year_end"])
ectopic_pregnancy_incidence = ectopic_pregnancy_incidence.mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/get_draws/api.py:192: UserWarning: No version_id was specified, so get_draws will automatically determine a best version ID to use from the given parameters. If you want to retrieve a specific version please pass a version_id directly.
#   warnings.warn(
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/ihme_cc_rules_client/lib/rules_manager.py:224: UnrecognizedRuleWarning: Rules API returned unrecognized rule: EPI_PASS_GET_RESULTS_TO_GET_ESTIMATES. The installed ihme_cc_rules_client package (version 3.15.2) is likely outdated and should be upgraded. If you see this warning in a central environment, please submit a Help Desk ticket for Central Comp: https://helpdesk.ihme.washington.edu
#   warnings.warn(
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/ihme_cc_rules_client/lib/rules_manager.py:224: UnrecognizedRuleWarning: Rules API returned unrecognized rule: STGPR_PASS_GET_RESULTS_TO_GET_ESTIMATES. The installed ihme_cc_rules_client package (version 3.15.2) is likely outdated and should be upgraded. If you see this warning in a central environment, please submit a Help Desk ticket for Central Comp: https://helpdesk.ihme.washington.edu
#   warnings.warn(
# ________________________________________________________________________________
# [Memory] Calling vivarium_gbd_access.gbd.get_incidence_prevalence...
# get_incidence_prevalence(entity_id=c_id(374), location_id=[179], entity_type='cause', year_id=2021)
# 2025-04-29 22:46:11.629 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2025-04-29 22:46:11.635 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2025-04-29 22:46:11.636 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# _________________________________________get_incidence_prevalence - 3.6s, 0.1min
# 2025-04-29 22:46:11.826 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2025-04-29 22:46:11.832 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2025-04-29 22:46:11.832 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/vivarium_inputs/utilities.py:492: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000105
#         15.0       20.0       0.002708
#         20.0       25.0       0.008810
#         25.0       30.0       0.009668
#         30.0       35.0       0.011650
#         35.0       40.0       0.010551
#         40.0       45.0       0.008400
#         45.0       50.0       0.004882
#         50.0       55.0       0.001458
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.003505
#         15.0       20.0       0.076832
#         20.0       25.0       0.309537
#         25.0       30.0       0.291867
#         30.0       35.0       0.281807
#         35.0       40.0       0.201665
#         40.0       45.0       0.103078
#         45.0       50.0       0.034589
#         50.0       55.0       0.004189
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/incidence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_incidence.rename("value").to_csv(path)

# %%
# https://github.com/ihmeuw/vivarium_gates_iv_iron/blob/862b057457cea2410e8d24c2c9c38c43419cd8b2/src/vivarium_gates_iv_iron/data/loader.py#L237C5-L240C6
PARTIAL_TERM: float = 24 / 52
FULL_TERM: float = 40 / 52
pregnancy_prevalence = FULL_TERM * (asfr + asfr * sbr) + PARTIAL_TERM * (
    maternal_abortion_miscarriage_incidence + ectopic_pregnancy_incidence
)
pregnancy_prevalence[pregnancy_prevalence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.002423
#         15.0       20.0       0.049793
#         20.0       25.0       0.202976
#         25.0       30.0       0.192415
#         30.0       35.0       0.185952
#         35.0       40.0       0.132818
#         40.0       45.0       0.068353
#         45.0       50.0       0.022831
#         50.0       55.0       0.002570
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/prevalence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_prevalence.rename("value").to_csv(path)

# %%
population_stratified = pd.concat(
    [
        (pregnancy_prevalence * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="pregnant")
        .set_index("pregnant", append=True)
        .value,
        ((1 - pregnancy_prevalence) * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="not_pregnant")
        .set_index("pregnant", append=True)
        .value,
    ]
).sort_index()
population_stratified
# Out:
# sex     age_start  age_end     pregnant
# Female  0.000000   0.019178    not_pregnant     32129.461362
#                                pregnant             0.000000
#         0.019178   0.076712    not_pregnant     95365.473841
#                                pregnant             0.000000
#         0.076712   0.500000    not_pregnant    696914.518216
#                                                    ...
# Male    85.000000  90.000000   pregnant             0.000000
#         90.000000  95.000000   not_pregnant     19659.103202
#                                pregnant             0.000000
#         95.000000  125.000000  not_pregnant      3488.084807
#                                pregnant             0.000000
# Name: value, Length: 100, dtype: float64

# %%
assert np.isclose(population_stratified.sum(), total_population.sum())

# %%
population_age_groups = (
    total_population.reset_index()[["age_start", "age_end"]]
    .drop_duplicates()
    .sort_values("age_start")
)
population_age_groups
# Out:
#     age_start     age_end
# 0    0.000000    0.019178
# 1    0.019178    0.076712
# 2    0.076712    0.500000
# 3    0.500000    1.000000
# 4    1.000000    2.000000
# 5    2.000000    5.000000
# 6    5.000000   10.000000
# 7   10.000000   15.000000
# 8   15.000000   20.000000
# 9   20.000000   25.000000
# 10  25.000000   30.000000
# 11  30.000000   35.000000
# 12  35.000000   40.000000
# 13  40.000000   45.000000
# 14  45.000000   50.000000
# 15  50.000000   55.000000
# 16  55.000000   60.000000
# 17  60.000000   65.000000
# 18  65.000000   70.000000
# 19  70.000000   75.000000
# 20  75.000000   80.000000
# 21  80.000000   85.000000
# 22  85.000000   90.000000
# 23  90.000000   95.000000
# 24  95.000000  125.000000

# %%
def map_to_population_age_groups(df):
    return (
        population_age_groups.merge(df, how="cross", suffixes=("", "_orig"))
        .pipe(
            lambda df: df[
                (df.age_end <= df.age_end_orig) & (df.age_start >= df.age_start_orig)
            ]
        )
        .drop(columns=["age_start_orig", "age_end_orig"])
    )

# %%
wealth_quintile_probabilities = pd.read_csv(
    f"../results/wealth_quintile_probabilities/{location}.csv"
).set_index(["sex", "age_start", "age_end", "pregnant"])
wealth_quintile_probabilities.columns.name = "wealth_quintile"
wealth_quintile_probabilities = wealth_quintile_probabilities.stack()
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  1                  0.240568
#                                           2                  0.218680
#                                           3                  0.206739
#                                           4                  0.185403
#                                           5                  0.148610
#         5.0        15.0     not_pregnant  1                  0.219482
#                                           2                  0.209157
#                                           3                  0.210067
#                                           4                  0.207411
#                                           5                  0.153883
#         15.0       30.0     not_pregnant  1                  0.154054
#                                           2                  0.173552
#                                           3                  0.180132
#                                           4                  0.193390
#                                           5                  0.298871
#                             pregnant      1                  0.214447
#                                           2                  0.257398
#                                           3                  0.173152
#                                           4                  0.167345
#                                           5                  0.187658
#         30.0       50.0     not_pregnant  1                  0.176930
#                                           2                  0.178372
#                                           3                  0.198273
#                                           4                  0.205845
#                                           5                  0.240580
#                             pregnant      1                  0.250120
#                                           2                  0.185543
#                                           3                  0.217769
#                                           4                  0.191428
#                                           5                  0.155140
#         50.0       125.0    not_pregnant  1                  0.205491
#                                           2                  0.204239
#                                           3                  0.195294
#                                           4                  0.199461
#                                           5                  0.195515
# Male    0.0        5.0      not_pregnant  1                  0.236076
#                                           2                  0.239462
#                                           3                  0.208587
#                                           4                  0.173674
#                                           5                  0.142200
#         5.0        15.0     not_pregnant  1                  0.226779
#                                           2                  0.210595
#                                           3                  0.205277
#                                           4                  0.206115
#                                           5                  0.151234
#         15.0       30.0     not_pregnant  1                  0.157551
#                                           2                  0.173962
#                                           3                  0.186354
#                                           4                  0.221764
#                                           5                  0.260370
#         30.0       50.0     not_pregnant  1                  0.167606
#                                           2                  0.192322
#                                           3                  0.201171
#                                           4                  0.194831
#                                           5                  0.244070
#         50.0       125.0    not_pregnant  1                  0.189095
#                                           2                  0.197845
#                                           3                  0.205353
#                                           4                  0.217282
#                                           5                  0.190425
# dtype: float64

# %%
wealth_quintile_probabilities = (
    map_to_population_age_groups(
        wealth_quintile_probabilities.rename("value").reset_index()
    )
    .set_index(wealth_quintile_probabilities.index.names)
    .value
)
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  0.240568
#                                              2                  0.218680
#                                              3                  0.206739
#                                              4                  0.185403
#                                              5                  0.148610
#                                                                   ...
# Male    95.0       125.000000  not_pregnant  1                  0.189095
#                                              2                  0.197845
#                                              3                  0.205353
#                                              4                  0.217282
#                                              5                  0.190425
# Name: value, Length: 285, dtype: float64

# %%
assert np.allclose(
    wealth_quintile_probabilities.groupby(population_stratified.index.names).sum(), 1.0
)

# %%
population_stratified = population_stratified.mul(
    wealth_quintile_probabilities, axis=0
).dropna()
population_stratified
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  7729.330504
#                                              2                  7026.085890
#                                              3                  6642.401601
#                                              4                  5956.884779
#                                              5                  4774.758589
#                                                                    ...
# Male    95.0       125.000000  not_pregnant  1                   659.578610
#                                              2                   690.099645
#                                              3                   716.289850
#                                              4                   757.897451
#                                              5                   664.219250
# Name: value, Length: 285, dtype: float64

# %%
population_stratified.sum()
# Out:
# 108918246.6738451

# %%
total_population.sum()
# Out:
# 108937999.59866266

# %%
assert np.isclose(population_stratified.sum(), total_population.sum(), rtol=0.01)

# %%
path = pathlib.Path(f"../results/population/stratified/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
population_stratified.rename("value").to_csv(path)
