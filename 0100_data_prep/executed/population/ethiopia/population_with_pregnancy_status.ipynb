# %%
import vivarium_inputs
from vivarium import gbd_mapping
import pathlib
import pandas as pd, numpy as np

# %%
location = "india"

# %%
# Parameters
location = "ethiopia"

# %%
total_population = (
    vivarium_inputs.get_population_structure(location.title())
    .droplevel(["location", "year_start", "year_end"])
    .value
)
total_population
# Out:
# 2026-08-24 16:26:55.229 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.310 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.334 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.393 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.400 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.408 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.416 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.417 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.420 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:55.427 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.428 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.443 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_population'
# 2026-08-24 16:26:55.470 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.472 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.475 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:55.482 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.483 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.486 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:55.499 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.502 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.505 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:55.510 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.511 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.518 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:55.523 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.523 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.529 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:55.543 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.545 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.549 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:55.554 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.555 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.559 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:55.566 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.568 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.574 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:55.583 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.585 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.588 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.595 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.596 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.600 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.613 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.614 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.618 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:55.633 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.635 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.638 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:55.646 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.647 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.654 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.662 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.664 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.668 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.674 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.675 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.683 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# sex     age_start  age_end
# Female  0.000000   0.019178      3.371454e+04
#         0.019178   0.076712      1.000574e+05
#         0.076712   0.500000      7.293232e+05
#         0.500000   1.000000      8.403075e+05
#         1.000000   2.000000      1.631963e+06
#         2.000000   5.000000      4.671137e+06
#         5.000000   10.000000     7.302317e+06
#         10.000000  15.000000     6.902023e+06
#         15.000000  20.000000     6.460198e+06
#         20.000000  25.000000     5.646205e+06
#         25.000000  30.000000     4.867631e+06
#         30.000000  35.000000     4.125113e+06
#         35.000000  40.000000     3.398171e+06
#         40.000000  45.000000     2.681692e+06
#         45.000000  50.000000     1.958185e+06
#         50.000000  55.000000     1.434762e+06
#         55.000000  60.000000     1.082598e+06
#         60.000000  65.000000     8.221871e+05
#         65.000000  70.000000     6.230418e+05
#         70.000000  75.000000     4.261645e+05
#         75.000000  80.000000     2.919381e+05
#         80.000000  85.000000     1.907093e+05
#         85.000000  90.000000     1.015240e+05
#         90.000000  95.000000     3.906658e+04
#         95.000000  125.000000    9.383728e+03
# Male    0.000000   0.019178      3.564021e+04
#         0.019178   0.076712      1.051762e+05
#         0.076712   0.500000      7.659129e+05
#         0.500000   1.000000      8.819035e+05
#         1.000000   2.000000      1.710804e+06
#         2.000000   5.000000      4.896096e+06
#         5.000000   10.000000     7.651277e+06
#         10.000000  15.000000     7.251332e+06
#         15.000000  20.000000     6.589635e+06
#         20.000000  25.000000     5.512694e+06
#         25.000000  30.000000     4.601896e+06
#         30.000000  35.000000     3.836341e+06
#         35.000000  40.000000     3.152001e+06
#         40.000000  45.000000     2.567004e+06
#         45.000000  50.000000     2.034746e+06
#         50.000000  55.000000     1.566298e+06
#         55.000000  60.000000     1.182644e+06
#         60.000000  65.000000     8.814496e+05
#         65.000000  70.000000     6.605545e+05
#         70.000000  75.000000     4.786068e+05
#         75.000000  80.000000     3.306058e+05
#         80.000000  85.000000     2.058456e+05
#         85.000000  90.000000     1.041768e+05
#         90.000000  95.000000     3.852194e+04
#         95.000000  125.000000    7.718538e+03
# Name: value, dtype: float64

# %%
path = pathlib.Path(f"../results/population/total/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
total_population.rename("value").to_csv(path)

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location.title()
).droplevel(["location", "year_start", "year_end"])
asfr = (
    asfr[asfr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
asfr[asfr > 0]
# Out:
# 2026-08-24 16:26:55.811 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.812 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.816 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.822 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.823 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.830 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:55.838 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.838 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.842 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:55.847 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.847 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.864 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-08-24 16:26:55.890 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.891 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.894 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:55.900 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.901 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.904 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:55.915 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.916 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.919 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:55.924 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.926 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.930 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:55.944 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.946 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.956 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:55.971 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.972 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:55.981 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:55.993 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:55.998 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.004 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:56.018 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.023 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.028 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:56.042 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.043 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.053 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.073 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.076 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.087 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.101 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.102 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.106 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:56.122 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.125 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.139 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:56.153 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.155 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.173 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.181 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.183 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.190 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.197 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.199 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.205 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# sex     age_start  age_end
# Female  10.0       15.0       0.002928
#         15.0       20.0       0.047716
#         20.0       25.0       0.185350
#         25.0       30.0       0.181771
#         30.0       35.0       0.181651
#         35.0       40.0       0.130724
#         40.0       45.0       0.062533
#         45.0       50.0       0.018075
#         50.0       55.0       0.001639
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(
    # Renamed from the retired stillbirth_to_live_birth_ratio when GBD split the covariate
    # by gestational-age definition; the sims use the 28-week definition
    # (see data_keys.PREGNANCY.SBR in the maternal package).
    gbd_mapping.covariates.stillbirth_28_weeks_to_live_birth_ratio,
    "estimate",
    location.title(),
)
sbr = (
    sbr[sbr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
assert len(sbr) == 1
sbr = sbr.iloc[0]
sbr
# Out:
# 2026-08-24 16:26:56.498 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.499 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.502 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.510 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.511 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.516 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.523 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.524 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.529 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:56.537 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.538 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.558 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-08-24 16:26:56.589 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.590 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.595 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:56.600 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.601 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.605 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:56.617 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.618 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.623 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:56.632 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.633 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.637 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:56.645 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.646 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.649 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:56.657 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.658 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.663 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:56.669 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.670 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.674 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:56.692 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.694 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.704 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.713 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.717 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.723 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.741 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.744 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.754 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:56.769 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.770 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.774 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.785 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.786 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.791 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.802 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.803 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.807 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 0.02307869896115

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location.title(),
).droplevel(["location", "year_start", "year_end"])
maternal_abortion_miscarriage_incidence = maternal_abortion_miscarriage_incidence.mean(
    axis=1
)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# 2026-08-24 16:26:56.919 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.920 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.923 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.930 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.931 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.935 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.945 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.945 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.950 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:56.960 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.962 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.966 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:56.973 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:56.975 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:56.996 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 16:26:57.037 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.038 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.042 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.048 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.050 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.054 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:57.064 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 16:26:57.073 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.075 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.078 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:57.085 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.086 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.090 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:57.096 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.097 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.103 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:57.110 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 16:26:57.112 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 16:26:57.147 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.149 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.158 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.303 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.306 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.314 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:57.320 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.322 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.329 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:57.342 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.344 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.350 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.374 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.378 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.399 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.410 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.413 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.418 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:57.430 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.433 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.456 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 16:26:57.471 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.473 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.477 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.482 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.484 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.487 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:57.521 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 16:26:57.526 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.530 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.540 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:57.545 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.546 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.548 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:57.554 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.554 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.557 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:57.562 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 16:26:57.563 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 16:26:57.596 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.598 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.603 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.716 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.724 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.731 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:57.740 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.741 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.748 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:57.760 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.761 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.768 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:57.811 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.811 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.818 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.824 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.825 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.834 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.849 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.851 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.864 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:57.875 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.875 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.880 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:57.887 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.889 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.893 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.903 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.904 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.908 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:57.915 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:57.917 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:57.922 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/abie/projects/2026/vivarium_gates_lsff_2026/.snakemake_envs/artifact/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.003571
#         15.0       20.0       0.050467
#         20.0       25.0       0.169702
#         25.0       30.0       0.142704
#         30.0       35.0       0.136502
#         35.0       40.0       0.105985
#         40.0       45.0       0.058865
#         45.0       50.0       0.020379
#         50.0       55.0       0.002113
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy, "incidence_rate", location.title()
).droplevel(["location", "year_start", "year_end"])
ectopic_pregnancy_incidence = ectopic_pregnancy_incidence.mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# 2026-08-24 16:26:58.031 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.032 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.039 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.046 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.047 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.051 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.062 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.063 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.067 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.075 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.076 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.079 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:58.084 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.085 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.098 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 16:26:58.141 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.143 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.148 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.154 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.159 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.163 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:58.179 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 16:26:58.183 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.184 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.188 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:58.194 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.195 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.201 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:58.210 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.211 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.215 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:58.223 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 16:26:58.224 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 16:26:58.244 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.246 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.250 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.340 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.341 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.346 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:58.353 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.354 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.361 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:58.375 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.376 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.381 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.418 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.421 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.429 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.447 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.448 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.453 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:58.459 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.460 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.464 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 16:26:58.476 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.480 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.490 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.496 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.501 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.507 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 16:26:58.519 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 16:26:58.523 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.524 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.530 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:58.536 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.538 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.542 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:58.548 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.549 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.555 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:58.561 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 16:26:58.570 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 16:26:58.590 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.591 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.596 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.671 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.673 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.678 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 16:26:58.687 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.689 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.692 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 16:26:58.703 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.705 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.710 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 16:26:58.742 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.744 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.748 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.756 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.758 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.765 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.787 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.788 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.792 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 16:26:58.805 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.806 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.810 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 16:26:58.815 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.816 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.821 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.826 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.827 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.835 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 16:26:58.845 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 16:26:58.846 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 16:26:58.850 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/abie/projects/2026/vivarium_gates_lsff_2026/.snakemake_envs/artifact/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000164
#         15.0       20.0       0.001079
#         20.0       25.0       0.002723
#         25.0       30.0       0.002313
#         30.0       35.0       0.002558
#         35.0       40.0       0.002447
#         40.0       45.0       0.001897
#         45.0       50.0       0.000872
#         50.0       55.0       0.000191
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.006730
#         15.0       20.0       0.100362
#         20.0       25.0       0.362053
#         25.0       30.0       0.330983
#         30.0       35.0       0.324903
#         35.0       40.0       0.242173
#         40.0       45.0       0.124738
#         45.0       50.0       0.039744
#         50.0       55.0       0.003980
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/incidence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_incidence.rename("value").to_csv(path)

# %%
# https://github.com/ihmeuw/vivarium_gates_iv_iron/blob/862b057457cea2410e8d24c2c9c38c43419cd8b2/src/vivarium_gates_iv_iron/data/loader.py#L237C5-L240C6
PARTIAL_TERM: float = 24 / 52
FULL_TERM: float = 40 / 52
pregnancy_prevalence = FULL_TERM * (asfr + asfr * sbr) + PARTIAL_TERM * (
    maternal_abortion_miscarriage_incidence + ectopic_pregnancy_incidence
)
pregnancy_prevalence[pregnancy_prevalence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.004028
#         15.0       20.0       0.061342
#         20.0       25.0       0.225448
#         25.0       30.0       0.209982
#         30.0       35.0       0.207138
#         35.0       40.0       0.152923
#         40.0       45.0       0.077257
#         45.0       50.0       0.024033
#         50.0       55.0       0.002353
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/prevalence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_prevalence.rename("value").to_csv(path)

# %%
population_stratified = pd.concat(
    [
        (pregnancy_prevalence * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="pregnant")
        .set_index("pregnant", append=True)
        .value,
        ((1 - pregnancy_prevalence) * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="not_pregnant")
        .set_index("pregnant", append=True)
        .value,
    ]
).sort_index()
population_stratified
# Out:
# sex     age_start  age_end     pregnant
# Female  0.000000   0.019178    not_pregnant     33714.537506
#                                pregnant             0.000000
#         0.019178   0.076712    not_pregnant    100057.354564
#                                pregnant             0.000000
#         0.076712   0.500000    not_pregnant    729323.197699
#                                                    ...
# Male    85.000000  90.000000   pregnant             0.000000
#         90.000000  95.000000   not_pregnant     38521.939804
#                                pregnant             0.000000
#         95.000000  125.000000  not_pregnant      7718.537588
#                                pregnant             0.000000
# Name: value, Length: 100, dtype: float64

# %%
assert np.isclose(population_stratified.sum(), total_population.sum())

# %%
population_age_groups = (
    total_population.reset_index()[["age_start", "age_end"]]
    .drop_duplicates()
    .sort_values("age_start")
)
population_age_groups
# Out:
#     age_start     age_end
# 0    0.000000    0.019178
# 1    0.019178    0.076712
# 2    0.076712    0.500000
# 3    0.500000    1.000000
# 4    1.000000    2.000000
# 5    2.000000    5.000000
# 6    5.000000   10.000000
# 7   10.000000   15.000000
# 8   15.000000   20.000000
# 9   20.000000   25.000000
# 10  25.000000   30.000000
# 11  30.000000   35.000000
# 12  35.000000   40.000000
# 13  40.000000   45.000000
# 14  45.000000   50.000000
# 15  50.000000   55.000000
# 16  55.000000   60.000000
# 17  60.000000   65.000000
# 18  65.000000   70.000000
# 19  70.000000   75.000000
# 20  75.000000   80.000000
# 21  80.000000   85.000000
# 22  85.000000   90.000000
# 23  90.000000   95.000000
# 24  95.000000  125.000000

# %%
def map_to_population_age_groups(df):
    return (
        population_age_groups.merge(df, how="cross", suffixes=("", "_orig"))
        .pipe(
            lambda df: df[
                (df.age_end <= df.age_end_orig) & (df.age_start >= df.age_start_orig)
            ]
        )
        .drop(columns=["age_start_orig", "age_end_orig"])
    )

# %%
wealth_quintile_probabilities = pd.read_csv(
    f"../results/wealth_quintile_probabilities/{location}.csv"
).set_index(["sex", "age_start", "age_end", "pregnant"])
wealth_quintile_probabilities.columns.name = "wealth_quintile"
wealth_quintile_probabilities = wealth_quintile_probabilities.stack()
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  1                  0.240568
#                                           2                  0.218680
#                                           3                  0.206739
#                                           4                  0.185403
#                                           5                  0.148610
#         5.0        15.0     not_pregnant  1                  0.219482
#                                           2                  0.209157
#                                           3                  0.210067
#                                           4                  0.207411
#                                           5                  0.153883
#         15.0       30.0     not_pregnant  1                  0.154054
#                                           2                  0.173552
#                                           3                  0.180132
#                                           4                  0.193390
#                                           5                  0.298871
#                             pregnant      1                  0.214447
#                                           2                  0.257398
#                                           3                  0.173152
#                                           4                  0.167345
#                                           5                  0.187658
#         30.0       50.0     not_pregnant  1                  0.176930
#                                           2                  0.178372
#                                           3                  0.198273
#                                           4                  0.205845
#                                           5                  0.240580
#                             pregnant      1                  0.250120
#                                           2                  0.185543
#                                           3                  0.217769
#                                           4                  0.191428
#                                           5                  0.155140
#         50.0       125.0    not_pregnant  1                  0.205491
#                                           2                  0.204239
#                                           3                  0.195294
#                                           4                  0.199461
#                                           5                  0.195515
# Male    0.0        5.0      not_pregnant  1                  0.236076
#                                           2                  0.239462
#                                           3                  0.208587
#                                           4                  0.173674
#                                           5                  0.142200
#         5.0        15.0     not_pregnant  1                  0.226779
#                                           2                  0.210595
#                                           3                  0.205277
#                                           4                  0.206115
#                                           5                  0.151234
#         15.0       30.0     not_pregnant  1                  0.157551
#                                           2                  0.173962
#                                           3                  0.186354
#                                           4                  0.221764
#                                           5                  0.260370
#         30.0       50.0     not_pregnant  1                  0.167606
#                                           2                  0.192322
#                                           3                  0.201171
#                                           4                  0.194831
#                                           5                  0.244070
#         50.0       125.0    not_pregnant  1                  0.189095
#                                           2                  0.197845
#                                           3                  0.205353
#                                           4                  0.217282
#                                           5                  0.190425
# dtype: float64

# %%
wealth_quintile_probabilities = (
    map_to_population_age_groups(
        wealth_quintile_probabilities.rename("value").reset_index()
    )
    .set_index(wealth_quintile_probabilities.index.names)
    .value
)
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  0.240568
#                                              2                  0.218680
#                                              3                  0.206739
#                                              4                  0.185403
#                                              5                  0.148610
#                                                                   ...
# Male    95.0       125.000000  not_pregnant  1                  0.189095
#                                              2                  0.197845
#                                              3                  0.205353
#                                              4                  0.217282
#                                              5                  0.190425
# Name: value, Length: 285, dtype: float64

# %%
assert np.allclose(
    wealth_quintile_probabilities.groupby(population_stratified.index.names).sum(), 1.0
)

# %%
population_stratified = population_stratified.mul(
    wealth_quintile_probabilities, axis=0
).dropna()
population_stratified
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  1                  8110.649607
#                                              2                  7372.711095
#                                              3                  6970.098109
#                                              4                  6250.761973
#                                              5                  5010.316721
#                                                                    ...
# Male    95.0       125.000000  not_pregnant  1                  1459.535125
#                                              2                  1527.072977
#                                              3                  1585.027440
#                                              4                  1677.097974
#                                              5                  1469.804071
# Name: value, Length: 285, dtype: float64

# %%
population_stratified.sum()
# Out:
# 113387117.63553315

# %%
total_population.sum()
# Out:
# 113418293.20491894

# %%
assert np.isclose(population_stratified.sum(), total_population.sum(), rtol=0.01)

# %%
path = pathlib.Path(f"../results/population/stratified/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
population_stratified.rename("value").to_csv(path)
