# %% [markdown]
# # Analyzing DHS microdata
#
# * India 2015-2016 - we use this because 2019-2021 data would have been heavily impacted by COVID, and 2023-2024 microdata is not yet available.
# * Nigeria 2023-2024
# * Ethiopia 2016 - none of the more recent surveys include hemoglobin data.
#
# ## Documentation
#
# DHS 7 recode manual for variable definitions: https://www.dhsprogram.com/pubs/pdf/DHSG4/Recode7_DHS_10Sep2018_DHSG4.pdf.
# However, it does not state which variables are in which file.
# The `.MAP` files alongside each data file list the variables in it and what they mean.
#
# Hemoglobin variables of interest:
# - HA53: Hemoglobin level in g/dl with 1 implied dcimal
# - HA54: Currently pregnant
# - HA55 Result of Hemoglobin measuring.
# - HA56 Hemoglobin level adjusted by altitude in g/dl with 1 implied decimal.
#
# Wealth index variables of interest:
# - HV270: The wealth index is a composite measure of a household's cumulative living standard.
# The wealth index is calculated using easy-to-collect data on a household’s ownership of
# selected assets, such as televisions and bicycles; materials used for housing construction; and
# types of water access and sanitation facilities.
# Generated with a statistical procedure known as principal components analysis, the wealth
# index places individual households on a continuous scale of relative wealth. DHS separates
# all interviewed households into five wealth quintiles to compare the influence of wealth on
# various population, health and nutrition indicators. The wealth index is presented in the DHS
# Final Reports and survey datasets as a background characteristic
# - HV271: Wealth index factor score (5 decimals)
#
# Pregnancy variables of interest:
# - HML18: Pregnancy status from individual questionnaire. For complete woman’s interviews this is
# taken from V213. For incomplete woman's interview with anemia testing the pregnancy
# status is taken from this section.
# BASE: Women with a completed individual questionnaire or when available information
# from the anemia testing section.
#
# List of datasets: https://www.dhsprogram.com/data/dataset/Nigeria_Standard-DHS_2018.cfm?flag=1
#
# Instructions on how to calculate everything can be found at: https://www.dhsprogram.com/pubs/pdf/DHSG1/Guide_to_DHS_Statistics_DHS-7_v2.pdf

# %%
import pandas as pd, numpy as np
from lsff_utils import data_processing

# %load_ext autoreload
# %autoreload 2

# !date
# Out:
# Fri 04 Sep 2026 12:25:38 PM PDT

# %%
location = "ethiopia"

# %%
# Parameters
location = "india"

# %% [markdown]
# ## Load data, name columns

# %%
directory = {
    "india": "/snfs1/DATA/DHS_PROG_DHS/IND/2015_2016/",
    "nigeria": "/snfs1/DATA/DHS_PROG_DHS/NGA/2023_2024/",
    "ethiopia": "/snfs1/DATA/DHS_PROG_DHS/ETH/2016/",
}[location]

# %% [markdown]
# ### WRA

# %%
# %%time

wra_data_file_name = {
    "india": "IND_DHS7_2015_2016_WN_IAIR74FL_Y2018M12D06.DTA",
    "nigeria": "NGA_DHS8_2023_2024_WN_NGIR8AFL_Y2025M10D30.DTA",
    "ethiopia": "ETH_DHS7_2016_WN_ETIR71FL_Y2019M12D11.DTA",
}[location]

wra_columns = {
    "v001": "cluster_number",
    "v002": "household_number",
    "v003": "line_number",
    "v005": "weight",
    "v008": "interview_date",
    "v011": "date_of_birth",
    "v190": "wealth_quintile",
    "v213": "currently_pregnant",
}
wra_data = pd.read_stata(
    directory + wra_data_file_name,
    columns=wra_columns.keys(),
)
# Out:
# CPU times: user 45.2 s, sys: 13.8 s, total: 59 s
# Wall time: 1min 8s

# %%
wra_data = wra_data[wra_columns.keys()].rename(columns=wra_columns)

# %%
wra_data["wealth_quintile"] = data_processing.recode_dhs_wealth_quintile(
    wra_data.wealth_quintile
)

# %%
wra_data["pregnant"] = wra_data.currently_pregnant.str.strip().map(
    {
        "not pregnant, don't know": "not_pregnant",
        "no or unsure": "not_pregnant",
        "pregnant": "pregnant",
        "yes": "pregnant",
    }
)

# %%
wra_data["weight"] = wra_data.weight / 1_000_000

# %% [markdown]
# ### Births

# %%
birth_data_file_name = {
    "india": "IND_DHS7_2015_2016_BR_IABR74FL_Y2018M12D06.DTA",
    "nigeria": "NGA_DHS8_2023_2024_BR_NGBR8AFL_Y2025M10D30.DTA",
    "ethiopia": "ETH_DHS7_2016_BR_ETBR71FL_Y2019M12D11.DTA",
}[location]

birth_columns = {
    "v005": "weight",
    "v008": "interview_date",
    "v190": "wealth_quintile",
    "b3": "birth_date",
    "m18": "size_of_child",
    "m19": "birth_weight_kilograms",
}
if location == "india":
    birth_columns["s220a"] = "duration_of_pregnancy"
else:
    birth_columns["b20"] = "duration_of_pregnancy"

birth_data = pd.read_stata(
    directory + birth_data_file_name,
    columns=birth_columns.keys(),
)
birth_data
# Out:
#             v005  v008    v190    b3         m18     m19  s220a
# 0         191760  1387  middle  1141         NaN     NaN    NaN
# 1         191760  1387  middle  1117         NaN     NaN    NaN
# 2         191760  1387  middle  1089         NaN     NaN    NaN
# 3         191760  1387  richer  1154         NaN     NaN    NaN
# 4         191760  1387  richer  1129         NaN     NaN    NaN
# ...          ...   ...     ...   ...         ...     ...    ...
# 1315612  2380715  1385  richer  1346  very large  3250.0    9.0
# 1315613  2380715  1385  middle  1100         NaN     NaN    NaN
# 1315614  2380715  1385  middle  1059         NaN     NaN    NaN
# 1315615  2380715  1385  middle  1027         NaN     NaN    NaN
# 1315616  2380715  1385  middle   989         NaN     NaN    NaN
#
# [1315617 rows x 7 columns]

# %%
birth_data = birth_data[birth_columns.keys()].rename(columns=birth_columns)
birth_data["wealth_quintile"] = data_processing.recode_dhs_wealth_quintile(
    birth_data.wealth_quintile
)
birth_data["weight"] = birth_data.weight / 1_000_000
birth_data
# Out:
#            weight  interview_date wealth_quintile  birth_date size_of_child  \
# 0        0.191760            1387               3        1141           NaN
# 1        0.191760            1387               3        1117           NaN
# 2        0.191760            1387               3        1089           NaN
# 3        0.191760            1387               4        1154           NaN
# 4        0.191760            1387               4        1129           NaN
# ...           ...             ...             ...         ...           ...
# 1315612  2.380715            1385               4        1346    very large
# 1315613  2.380715            1385               3        1100           NaN
# 1315614  2.380715            1385               3        1059           NaN
# 1315615  2.380715            1385               3        1027           NaN
# 1315616  2.380715            1385               3         989           NaN
#
#         birth_weight_kilograms  duration_of_pregnancy
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
# ...                        ...                    ...
# 1315612                 3250.0                    9.0
# 1315613                    NaN                    NaN
# 1315614                    NaN                    NaN
# 1315615                    NaN                    NaN
# 1315616                    NaN                    NaN
#
# [1315617 rows x 7 columns]

# %% [markdown]
# ### Household members

# %%
# %%time

hhm_data_file_name = {
    "india": "IND_DHS7_2015_2016_HHM_IAPR74FL_Y2018M12D06.DTA",
    "nigeria": "NGA_DHS8_2023_2024_HHM_NGPR8AFL_Y2025M10D30.DTA",
    "ethiopia": "ETH_DHS7_2016_HHM_ETPR71FL_Y2019M12D11.DTA",
}[location]

hhm_columns = {
    "hv001": "cluster_number",
    "hv002": "household_number",
    "hv005": "weight",
    "hv008": "date_of_interview",
    "hvidx": "line_number",
    "hv105": "age",
    "hv104": "sex",
    "ha0": "index_to_household",
    "ha1": "age_hemoglobin",
    "hv270": "wealth_quintile",
    "ha53": "hemoglobin_raw_adult",
    "ha56": "hemoglobin_adjusted_adult",
    "ha57": "anemia_adult",
    "hc53": "hemoglobin_raw_child",
    "hc56": "hemoglobin_adjusted_child",
    "hc57": "anemia_child",
}
hhm_data = pd.read_stata(
    directory + hhm_data_file_name,
    columns=hhm_columns.keys(),
)
hhm_data
# Out:
# CPU times: user 10.8 s, sys: 3.91 s, total: 14.7 s
# Wall time: 17.6 s
#           hv001  hv002    hv005  hv008  hvidx hv105   hv104  ha0   ha1  \
# 0         10001      1   191072   1387      1    51    male  NaN   NaN
# 1         10001      1   191072   1387      2    46  female  2.0  46.0
# 2         10001      1   191072   1387      3    22    male  NaN   NaN
# 3         10001      1   191072   1387      4    20  female  4.0  20.0
# 4         10001      9   191072   1387      1    40  female  1.0  40.0
# ...         ...    ...      ...    ...    ...   ...     ...  ...   ...
# 2869038  360482     85  2270734   1385      1    60    male  NaN   NaN
# 2869039  360482     85  2270734   1385      2    50  female  NaN   NaN
# 2869040  360482     96  2270734   1385      1    66    male  NaN   NaN
# 2869041  360482     96  2270734   1385      2    46  female  2.0  46.0
# 2869042  360482     96  2270734   1385      3    26    male  NaN   NaN
#
#           hv270   ha53   ha56      ha57 hc53 hc56 hc57
# 0        middle    NaN    NaN       NaN  NaN  NaN  NaN
# 1        middle   81.0   81.0  moderate  NaN  NaN  NaN
# 2        middle    NaN    NaN       NaN  NaN  NaN  NaN
# 3        middle  113.0  113.0      mild  NaN  NaN  NaN
# 4        richer  116.0  116.0      mild  NaN  NaN  NaN
# ...         ...    ...    ...       ...  ...  ...  ...
# 2869038  middle    NaN    NaN       NaN  NaN  NaN  NaN
# 2869039  middle    NaN    NaN       NaN  NaN  NaN  NaN
# 2869040  middle    NaN    NaN       NaN  NaN  NaN  NaN
# 2869041  middle  119.0  119.0      mild  NaN  NaN  NaN
# 2869042  middle    NaN    NaN       NaN  NaN  NaN  NaN
#
# [2869043 rows x 16 columns]

# %%
hhm_data = hhm_data[hhm_columns.keys()].rename(columns=hhm_columns)

# %%
id_columns = ["cluster_number", "household_number", "line_number"]
hhm_data = hhm_data.merge(
    wra_data[id_columns + ["pregnant"]],
    on=id_columns,
    how="left",
)
hhm_data["pregnant"] = hhm_data.pregnant.fillna("not_pregnant")

# %%
hhm_data["age"] = hhm_data.age.replace({"95+": 95, "don't know": np.nan}).astype(float)

# %%
hhm_data["sex"] = hhm_data.sex.str.title()

# %%
# Interesting -- sometimes age is quite off between hemoglobin and base.
hhm_data.loc[(hhm_data.age - hhm_data.age_hemoglobin).sort_values().index]
# Out:
#          cluster_number  household_number   weight  date_of_interview  \
# 2476814          332896                13   469645               1399
# 791387           140281                68   892170               1395
# 845590           140822                66   241894               1394
# 1062670          160904                16  2105279               1384
# 2709355          340097                79   339513               1382
# ...                 ...               ...      ...                ...
# 2869037          360482                75  2270734               1385
# 2869038          360482                85  2270734               1385
# 2869039          360482                85  2270734               1385
# 2869040          360482                96  2270734               1385
# 2869042          360482                96  2270734               1385
#
#          line_number   age     sex  index_to_household  age_hemoglobin  \
# 2476814            4  17.0  Female                 4.0            48.0
# 791387             4  19.0  Female                 4.0            49.0
# 845590             4  20.0  Female                 4.0            49.0
# 1062670            3  19.0  Female                 3.0            48.0
# 2709355            3  16.0  Female                 3.0            44.0
# ...              ...   ...     ...                 ...             ...
# 2869037            4   2.0    Male                 NaN             NaN
# 2869038            1  60.0    Male                 NaN             NaN
# 2869039            2  50.0  Female                 NaN             NaN
# 2869040            1  66.0    Male                 NaN             NaN
# 2869042            3  26.0    Male                 NaN             NaN
#
#         wealth_quintile hemoglobin_raw_adult hemoglobin_adjusted_adult  \
# 2476814         richest              refused                       NaN
# 791387           middle                109.0                     109.0
# 845590           poorer                119.0                     108.0
# 1062670         richest                132.0                     132.0
# 2709355         richest                142.0                     142.0
# ...                 ...                  ...                       ...
# 2869037          richer                  NaN                       NaN
# 2869038          middle                  NaN                       NaN
# 2869039          middle                  NaN                       NaN
# 2869040          middle                  NaN                       NaN
# 2869042          middle                  NaN                       NaN
#
#         anemia_adult hemoglobin_raw_child hemoglobin_adjusted_child  \
# 2476814          NaN                  NaN                       NaN
# 791387          mild                  NaN                       NaN
# 845590          mild                  NaN                       NaN
# 1062670   not anemic                  NaN                       NaN
# 2709355   not anemic                  NaN                       NaN
# ...              ...                  ...                       ...
# 2869037          NaN                 91.0                      91.0
# 2869038          NaN                  NaN                       NaN
# 2869039          NaN                  NaN                       NaN
# 2869040          NaN                  NaN                       NaN
# 2869042          NaN                  NaN                       NaN
#
#         anemia_child      pregnant
# 2476814          NaN  not_pregnant
# 791387           NaN  not_pregnant
# 845590           NaN  not_pregnant
# 1062670          NaN  not_pregnant
# 2709355          NaN  not_pregnant
# ...              ...           ...
# 2869037     moderate  not_pregnant
# 2869038          NaN  not_pregnant
# 2869039          NaN  not_pregnant
# 2869040          NaN  not_pregnant
# 2869042          NaN  not_pregnant
#
# [2869043 rows x 17 columns]

# %%
(hhm_data.age - hhm_data.age_hemoglobin).describe()
# Out:
# count    749344.000000
# mean         -0.041664
# std           0.841376
# min         -31.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          31.000000
# dtype: float64

# %%
age_bin_edges = [0, 5, 15, 30, 50, 125]
age_group = pd.IntervalIndex(
    pd.cut(hhm_data.age, age_bin_edges, right=False, include_lowest=True)
)
hhm_data["age_start"] = age_group.left
hhm_data["age_end"] = age_group.right

# %%
hhm_data["wealth_quintile"] = data_processing.recode_dhs_wealth_quintile(
    hhm_data.wealth_quintile
)
hhm_data["weight"] = hhm_data.weight / 1_000_000

# %%
for type in ["child", "adult"]:
    for base_col in ["hemoglobin_raw", "hemoglobin_adjusted"]:
        col = f"{base_col}_{type}"
        hhm_data[col] = (
            hhm_data[col]
            .astype(str)
            .replace(
                {
                    "not tested": np.nan,
                    "not present": np.nan,
                    "refused": np.nan,
                    "other": np.nan,
                }
            )
            .astype(float)
        )

# %%
for base_col in ["hemoglobin_raw", "hemoglobin_adjusted", "anemia"]:
    assert (hhm_data.filter(like=base_col).notnull().sum(axis=1) <= 1).all()
    hhm_data[base_col] = np.nan
    # Could use bfill instead of this loop, but it was incredibly slow for me
    for col in hhm_data.filter(like=base_col).columns:
        hhm_data[base_col] = hhm_data[base_col].fillna(hhm_data[col])

# %%
assert (
    hhm_data[(hhm_data.sex == "male") & (hhm_data.age > 5)]
    .hemoglobin_raw.isnull()
    .all()
)

# %% [markdown]
# ## Hemoglobin

# %%
other_overlapping_columns = (
    (set(wra_data.columns) & set(hhm_data.columns)) - set(id_columns) - {"weight"}
)
other_overlapping_columns
# Out:
# {'pregnant', 'wealth_quintile'}

# %%
wra_hhm_joined = wra_data.merge(
    hhm_data.drop(columns=["weight"]),
    on=id_columns,
    suffixes=("_wra", "_hhm"),
    how="left",
)
wra_hhm_joined
# Out:
#         cluster_number  household_number  line_number    weight  \
# 0                10001                 1            2  0.191760
# 1                10001                 1            4  0.191760
# 2                10001                 9            1  0.191760
# 3                10001                 9            2  0.191760
# 4                10001                 9            3  0.191760
# ...                ...               ...          ...       ...
# 699681          360482                61            5  2.380715
# 699682          360482                61            7  2.380715
# 699683          360482                62            1  2.380715
# 699684          360482                75            2  2.380715
# 699685          360482                96            2  2.380715
#
#         interview_date  date_of_birth wealth_quintile_wra currently_pregnant  \
# 0                 1387            835                   3       no or unsure
# 1                 1387           1141                   3       no or unsure
# 2                 1387            903                   4       no or unsure
# 3                 1387           1129                   4       no or unsure
# 4                 1387           1154                   4       no or unsure
# ...                ...            ...                 ...                ...
# 699681            1385           1023                   4       no or unsure
# 699682            1385           1149                   4       no or unsure
# 699683            1385            817                   1       no or unsure
# 699684            1385           1105                   4       no or unsure
# 699685            1385            824                   3       no or unsure
#
#         pregnant_wra  date_of_interview  ...  anemia_adult  \
# 0       not_pregnant               1387  ...      moderate
# 1       not_pregnant               1387  ...          mild
# 2       not_pregnant               1387  ...          mild
# 3       not_pregnant               1387  ...    not anemic
# 4       not_pregnant               1387  ...    not anemic
# ...              ...                ...  ...           ...
# 699681  not_pregnant               1385  ...    not anemic
# 699682  not_pregnant               1385  ...          mild
# 699683  not_pregnant               1385  ...          mild
# 699684  not_pregnant               1385  ...          mild
# 699685  not_pregnant               1385  ...          mild
#
#        hemoglobin_raw_child  hemoglobin_adjusted_child  anemia_child  \
# 0                       NaN                        NaN           NaN
# 1                       NaN                        NaN           NaN
# 2                       NaN                        NaN           NaN
# 3                       NaN                        NaN           NaN
# 4                       NaN                        NaN           NaN
# ...                     ...                        ...           ...
# 699681                  NaN                        NaN           NaN
# 699682                  NaN                        NaN           NaN
# 699683                  NaN                        NaN           NaN
# 699684                  NaN                        NaN           NaN
# 699685                  NaN                        NaN           NaN
#
#         pregnant_hhm  age_start  age_end hemoglobin_raw  hemoglobin_adjusted  \
# 0       not_pregnant       30.0     50.0           81.0                 81.0
# 1       not_pregnant       15.0     30.0          113.0                113.0
# 2       not_pregnant       30.0     50.0          116.0                116.0
# 3       not_pregnant       15.0     30.0          137.0                137.0
# 4       not_pregnant       15.0     30.0          137.0                137.0
# ...              ...        ...      ...            ...                  ...
# 699681  not_pregnant       30.0     50.0          125.0                125.0
# 699682  not_pregnant       15.0     30.0          112.0                112.0
# 699683  not_pregnant       30.0     50.0          106.0                103.0
# 699684  not_pregnant       15.0     30.0          103.0                103.0
# 699685  not_pregnant       30.0     50.0          119.0                119.0
#
#             anemia
# 0         moderate
# 1             mild
# 2             mild
# 3       not anemic
# 4       not anemic
# ...            ...
# 699681  not anemic
# 699682        mild
# 699683        mild
# 699684        mild
# 699685        mild
#
# [699686 rows x 27 columns]

# %%
for col in other_overlapping_columns:
    assert (wra_hhm_joined[f"{col}_wra"] == wra_hhm_joined[f"{col}_hhm"]).all()
    wra_hhm_joined[col] = wra_hhm_joined[f"{col}_wra"]
    wra_hhm_joined = wra_hhm_joined.drop(columns=[f"{col}_wra", f"{col}_hhm"])

# %%
# https://stackoverflow.com/a/2415343/ with some tweaks
def weighted_avg_and_std(values, weights):
    """
    Return the weighted average and standard deviation.

    They weights are in effect first normalized so that they
    sum to 1 (and so they must not all be 0).

    values, weights -- NumPy ndarrays with the same shape.
    """
    is_nan = np.isnan(values)
    values = values[~is_nan]
    weights = weights[~is_nan]
    average = np.average(values, weights=weights)
    # Fast and numerically precise:
    variance = np.average((values - average) ** 2, weights=weights)
    return pd.Series(
        {
            "mean": average,
            "sd": np.sqrt(variance),
            # https://ngreifer.github.io/WeightIt/reference/ESS.html
            "effective_sample_size": (weights.sum() ** 2) / (weights**2).sum(),
        }
    )

# %%
pregnant_with_anemia_status = wra_hhm_joined[
    (wra_hhm_joined.pregnant == "pregnant") & wra_hhm_joined.anemia.notnull()
]

# %%
# Matches table 10.21.1
pregnant_with_anemia_status.weight.sum()
# Out:
# 30325.760056

# %%
# Within rounding error of table 10.21.1 value
weighted_avg_and_std(
    pregnant_with_anemia_status.anemia == "severe",
    pregnant_with_anemia_status.weight,
)
# Out:
# mean                         0.012959
# sd                           0.113096
# effective_sample_size    14669.827307
# dtype: float64

# %%
# Within rounding error of table 10.21.1 value for any anemia
weighted_avg_and_std(
    pregnant_with_anemia_status.anemia.isin(["severe", "moderate", "mild"]),
    pregnant_with_anemia_status.weight,
)
# Out:
# mean                         0.503902
# sd                           0.499985
# effective_sample_size    14669.827307
# dtype: float64

# %%
assert (
    (pregnant_with_anemia_status.anemia == "severe")
    == (pregnant_with_anemia_status.hemoglobin_adjusted < 70)
).all()

# %%
assert (
    (pregnant_with_anemia_status.anemia.isin(["severe", "moderate", "mild"]))
    == (pregnant_with_anemia_status.hemoglobin_adjusted < 110)
).all()

# %%
adult_hemoglobin_disparities = (
    wra_hhm_joined.groupby(["wealth_quintile", "pregnant"])
    .apply(lambda df: weighted_avg_and_std(df.hemoglobin_adjusted, weights=df.weight))
    .sort_index()
)
adult_hemoglobin_disparities
# Out:
#                                     mean         sd  effective_sample_size
# wealth_quintile pregnant
# 1               not_pregnant  115.022635  16.135241           75400.465764
#                 pregnant      106.029126  16.025948            4689.833328
# 2               not_pregnant  116.108207  16.281235           71860.385099
#                 pregnant      107.167072  16.209312            4047.784565
# 3               not_pregnant  116.488978  16.559569           63288.980815
#                 pregnant      108.455303  15.571656            2576.743299
# 4               not_pregnant  117.310740  16.266386           52818.826999
#                 pregnant      110.079442  15.559339            2115.822472
# 5               not_pregnant  118.402649  15.538198           44871.372481
#                 pregnant      113.156279  14.858555            2014.207825

# %%
adult_hemoglobin_disparities = adult_hemoglobin_disparities.reset_index()
adult_hemoglobin_disparities = pd.concat(
    [
        adult_hemoglobin_disparities.assign(sex="Female", age_start=15, age_end=125),
        # Assumption: males are like non-pregnant WRA
        adult_hemoglobin_disparities[
            adult_hemoglobin_disparities.pregnant == "not_pregnant"
        ].assign(sex="Male", age_start=15, age_end=125),
    ]
)
adult_hemoglobin_disparities = adult_hemoglobin_disparities.set_index(
    ["sex", "age_start", "age_end", "pregnant", "wealth_quintile"]
)
adult_hemoglobin_disparities
# Out:
#                                                              mean         sd  \
# sex    age_start age_end pregnant     wealth_quintile
# Female 15        125     not_pregnant 1                115.022635  16.135241
#                          pregnant     1                106.029126  16.025948
#                          not_pregnant 2                116.108207  16.281235
#                          pregnant     2                107.167072  16.209312
#                          not_pregnant 3                116.488978  16.559569
#                          pregnant     3                108.455303  15.571656
#                          not_pregnant 4                117.310740  16.266386
#                          pregnant     4                110.079442  15.559339
#                          not_pregnant 5                118.402649  15.538198
#                          pregnant     5                113.156279  14.858555
# Male   15        125     not_pregnant 1                115.022635  16.135241
#                                       2                116.108207  16.281235
#                                       3                116.488978  16.559569
#                                       4                117.310740  16.266386
#                                       5                118.402649  15.538198
#
#                                                        effective_sample_size
# sex    age_start age_end pregnant     wealth_quintile
# Female 15        125     not_pregnant 1                         75400.465764
#                          pregnant     1                          4689.833328
#                          not_pregnant 2                         71860.385099
#                          pregnant     2                          4047.784565
#                          not_pregnant 3                         63288.980815
#                          pregnant     3                          2576.743299
#                          not_pregnant 4                         52818.826999
#                          pregnant     4                          2115.822472
#                          not_pregnant 5                         44871.372481
#                          pregnant     5                          2014.207825
# Male   15        125     not_pregnant 1                         75400.465764
#                                       2                         71860.385099
#                                       3                         63288.980815
#                                       4                         52818.826999
#                                       5                         44871.372481

# %%
child_hemoglobin_disparities = (
    hhm_data[(hhm_data.age <= 5)]
    .assign(age_start=0, age_end=5, pregnant="not_pregnant")
    .groupby(["sex", "age_start", "age_end", "pregnant", "wealth_quintile"])
    .apply(lambda df: weighted_avg_and_std(df.hemoglobin_adjusted, weights=df.weight))
    .sort_index()
)
child_hemoglobin_disparities
# Out:
#                                                              mean         sd  \
# sex    age_start age_end pregnant     wealth_quintile
# Female 0         5       not_pregnant 1                103.655561  14.697789
#                                       2                105.257986  14.743958
#                                       3                105.397530  15.145306
#                                       4                106.765336  15.145327
#                                       5                107.989017  14.592007
# Male   0         5       not_pregnant 1                104.012048  14.808158
#                                       2                105.163293  15.071596
#                                       3                105.230938  15.340462
#                                       4                106.561686  15.281601
#                                       5                107.259027  15.014856
#
#                                                        effective_sample_size
# sex    age_start age_end pregnant     wealth_quintile
# Female 0         5       not_pregnant 1                         17649.049628
#                                       2                         13006.358921
#                                       3                         10054.395946
#                                       4                          7636.224243
#                                       5                          5219.711658
# Male   0         5       not_pregnant 1                         18810.904211
#                                       2                         13982.547262
#                                       3                         10536.774976
#                                       4                          7778.376485
#                                       5                          6278.526164

# %%
adolescent_hemoglobin_disparities = pd.DataFrame(
    columns=child_hemoglobin_disparities.columns,
    index=child_hemoglobin_disparities.index,
).droplevel(["age_start", "age_end"])
for group in adolescent_hemoglobin_disparities.index:
    child_values = child_hemoglobin_disparities.droplevel(["age_start", "age_end"]).loc[
        group
    ]
    adult_values = adult_hemoglobin_disparities.droplevel(["age_start", "age_end"]).loc[
        group
    ]
    adolescent_hemoglobin_disparities.loc[group] = (
        child_values * 0.5 + adult_values * 0.5
    ).T

# %%
assert adolescent_hemoglobin_disparities.notnull().all().all()
adolescent_hemoglobin_disparities = (
    adolescent_hemoglobin_disparities.reset_index()
    .assign(age_start=5, age_end=15)
    .set_index(list(child_hemoglobin_disparities.index.names))
)

# %%
hemoglobin_disparities = pd.concat(
    [
        child_hemoglobin_disparities,
        adolescent_hemoglobin_disparities,
        adult_hemoglobin_disparities,
    ]
)
hemoglobin_disparities
# Out:
#                                                              mean         sd  \
# sex    age_start age_end pregnant     wealth_quintile
# Female 0         5       not_pregnant 1                103.655561  14.697789
#                                       2                105.257986  14.743958
#                                       3                 105.39753  15.145306
#                                       4                106.765336  15.145327
#                                       5                107.989017  14.592007
# Male   0         5       not_pregnant 1                104.012048  14.808158
#                                       2                105.163293  15.071596
#                                       3                105.230938  15.340462
#                                       4                106.561686  15.281601
#                                       5                107.259027  15.014856
# Female 5         15      not_pregnant 1                109.339098  15.416515
#                                       2                110.683097  15.512596
#                                       3                110.943254  15.852438
#                                       4                112.038038  15.705857
#                                       5                113.195833  15.065103
# Male   5         15      not_pregnant 1                109.517341  15.471699
#                                       2                 110.63575  15.676415
#                                       3                110.859958  15.950016
#                                       4                111.936213  15.773994
#                                       5                112.830838  15.276527
# Female 15        125     not_pregnant 1                115.022635  16.135241
#                          pregnant     1                106.029126  16.025948
#                          not_pregnant 2                116.108207  16.281235
#                          pregnant     2                107.167072  16.209312
#                          not_pregnant 3                116.488978  16.559569
#                          pregnant     3                108.455303  15.571656
#                          not_pregnant 4                 117.31074  16.266386
#                          pregnant     4                110.079442  15.559339
#                          not_pregnant 5                118.402649  15.538198
#                          pregnant     5                113.156279  14.858555
# Male   15        125     not_pregnant 1                115.022635  16.135241
#                                       2                116.108207  16.281235
#                                       3                116.488978  16.559569
#                                       4                 117.31074  16.266386
#                                       5                118.402649  15.538198
#
#                                                       effective_sample_size
# sex    age_start age_end pregnant     wealth_quintile
# Female 0         5       not_pregnant 1                        17649.049628
#                                       2                        13006.358921
#                                       3                        10054.395946
#                                       4                         7636.224243
#                                       5                         5219.711658
# Male   0         5       not_pregnant 1                        18810.904211
#                                       2                        13982.547262
#                                       3                        10536.774976
#                                       4                         7778.376485
#                                       5                         6278.526164
# Female 5         15      not_pregnant 1                        46524.757696
#                                       2                         42433.37201
#                                       3                         36671.68838
#                                       4                        30227.525621
#                                       5                        25045.542069
# Male   5         15      not_pregnant 1                        47105.684988
#                                       2                         42921.46618
#                                       3                        36912.877895
#                                       4                        30298.601742
#                                       5                        25574.949322
# Female 15        125     not_pregnant 1                        75400.465764
#                          pregnant     1                         4689.833328
#                          not_pregnant 2                        71860.385099
#                          pregnant     2                         4047.784565
#                          not_pregnant 3                        63288.980815
#                          pregnant     3                         2576.743299
#                          not_pregnant 4                        52818.826999
#                          pregnant     4                         2115.822472
#                          not_pregnant 5                        44871.372481
#                          pregnant     5                         2014.207825
# Male   15        125     not_pregnant 1                        75400.465764
#                                       2                        71860.385099
#                                       3                        63288.980815
#                                       4                        52818.826999
#                                       5                        44871.372481

# %%
results_dir = "../results"

# %%
hemoglobin_disparities["mean"].rename("value").to_csv(
    f"{results_dir}/hemoglobin/mean_disparities/{location}.csv"
)

# %%
hemoglobin_disparities["sd"].rename("value").to_csv(
    f"{results_dir}/hemoglobin/sd_disparities/{location}.csv"
)

# %% [markdown]
# ## Wealth quintile probabilities
#
# Intuitively, you might think these would be equal; but we are looking at subpopulations which can skew.

# %%
group_variables = ["sex", "age_start", "age_end", "pregnant"]

# %%
wealth_quintile_probabilities = (
    hhm_data.groupby(group_variables + ["wealth_quintile"], observed=True).weight.sum()
    / hhm_data.groupby(group_variables, observed=True).weight.sum()
)
assert np.allclose(
    wealth_quintile_probabilities.groupby(group_variables, observed=True).sum(), 1.0
)
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  1                  0.251317
#                                           2                  0.220571
#                                           3                  0.195838
#                                           4                  0.184456
#                                           5                  0.147818
#         5.0        15.0     not_pregnant  1                  0.269038
#                                           2                  0.219459
#                                           3                  0.193766
#                                           4                  0.172569
#                                           5                  0.145167
#         15.0       30.0     not_pregnant  1                  0.177853
#                                           2                  0.202279
#                                           3                  0.211418
#                                           4                  0.210441
#                                           5                  0.198009
#                             pregnant      1                  0.221117
#                                           2                  0.222530
#                                           3                  0.215087
#                                           4                  0.182296
#                                           5                  0.158970
#         30.0       50.0     not_pregnant  1                  0.172597
#                                           2                  0.187138
#                                           3                  0.199031
#                                           4                  0.213495
#                                           5                  0.227738
#                             pregnant      1                  0.316131
#                                           2                  0.181401
#                                           3                  0.129805
#                                           4                  0.169147
#                                           5                  0.203517
#         50.0       125.0    not_pregnant  1                  0.188708
#                                           2                  0.187540
#                                           3                  0.191253
#                                           4                  0.199636
#                                           5                  0.232863
# Male    0.0        5.0      not_pregnant  1                  0.242600
#                                           2                  0.215610
#                                           3                  0.200229
#                                           4                  0.183923
#                                           5                  0.157639
#         5.0        15.0     not_pregnant  1                  0.261604
#                                           2                  0.217675
#                                           3                  0.190718
#                                           4                  0.176545
#                                           5                  0.153458
#         15.0       30.0     not_pregnant  1                  0.169172
#                                           2                  0.205794
#                                           3                  0.214029
#                                           4                  0.208330
#                                           5                  0.202675
#         30.0       50.0     not_pregnant  1                  0.167563
#                                           2                  0.183939
#                                           3                  0.203419
#                                           4                  0.219906
#                                           5                  0.225173
#         50.0       125.0    not_pregnant  1                  0.176575
#                                           2                  0.184392
#                                           3                  0.190461
#                                           4                  0.200876
#                                           5                  0.247696
# Name: weight, dtype: float64

# %%
wealth_quintile_probabilities = wealth_quintile_probabilities.unstack()
wealth_quintile_probabilities
# Out:
# wealth_quintile                               1         2         3         4  \
# sex    age_start age_end pregnant
# Female 0.0       5.0     not_pregnant  0.251317  0.220571  0.195838  0.184456
#        5.0       15.0    not_pregnant  0.269038  0.219459  0.193766  0.172569
#        15.0      30.0    not_pregnant  0.177853  0.202279  0.211418  0.210441
#                          pregnant      0.221117  0.222530  0.215087  0.182296
#        30.0      50.0    not_pregnant  0.172597  0.187138  0.199031  0.213495
#                          pregnant      0.316131  0.181401  0.129805  0.169147
#        50.0      125.0   not_pregnant  0.188708  0.187540  0.191253  0.199636
# Male   0.0       5.0     not_pregnant  0.242600  0.215610  0.200229  0.183923
#        5.0       15.0    not_pregnant  0.261604  0.217675  0.190718  0.176545
#        15.0      30.0    not_pregnant  0.169172  0.205794  0.214029  0.208330
#        30.0      50.0    not_pregnant  0.167563  0.183939  0.203419  0.219906
#        50.0      125.0   not_pregnant  0.176575  0.184392  0.190461  0.200876
#
# wealth_quintile                               5
# sex    age_start age_end pregnant
# Female 0.0       5.0     not_pregnant  0.147818
#        5.0       15.0    not_pregnant  0.145167
#        15.0      30.0    not_pregnant  0.198009
#                          pregnant      0.158970
#        30.0      50.0    not_pregnant  0.227738
#                          pregnant      0.203517
#        50.0      125.0   not_pregnant  0.232863
# Male   0.0       5.0     not_pregnant  0.157639
#        5.0       15.0    not_pregnant  0.153458
#        15.0      30.0    not_pregnant  0.202675
#        30.0      50.0    not_pregnant  0.225173
#        50.0      125.0   not_pregnant  0.247696

# %%
ax = wealth_quintile_probabilities.loc[("Female", 15.0, 30.0, "pregnant")].plot(
    kind="bar"
)
ax.set_title(
    f"Wealth quintile probabilities for pregnancies in females 15-30 in {location.title()} DHS"
)
# Out:
# Text(0.5, 1.0, 'Wealth quintile probabilities for pregnancies in females 15-30 in India DHS')

# %%
wealth_quintile_probabilities.to_csv(
    f"{results_dir}/wealth_quintile_probabilities/{location}.csv",
)

# %% [markdown]
# ## LBWSG

# %% [markdown]
# ### Birth weight

# %%
birth_data["birth_weight_kilograms"] = birth_data.birth_weight_kilograms.replace(
    {"not weighed at birth": np.nan, "don't know": np.nan}
).astype(float)

# %%
weighted_avg_and_std(birth_data.birth_weight_kilograms, birth_data.weight)
# Out:
# mean                      2799.392719
# sd                         604.338123
# effective_sample_size    86484.148885
# dtype: float64

# %%
birth_weight_disparities = birth_data.groupby("wealth_quintile").apply(
    lambda df: weighted_avg_and_std(df.birth_weight_kilograms, df.weight)
)
birth_weight_disparities
# Out:
#                         mean          sd  effective_sample_size
# wealth_quintile
# 1                2767.050071  647.661212           23969.631404
# 2                2769.538275  608.623042           22126.156274
# 3                2793.091464  594.535582           18888.148937
# 4                2811.885429  596.065203           14336.624949
# 5                2861.478555  567.034576           12220.438182

# %%
birth_weight_disparities = (
    birth_weight_disparities["mean"].rename("value").reset_index()
)
birth_weight_disparities
# Out:
#   wealth_quintile        value
# 0               1  2767.050071
# 1               2  2769.538275
# 2               3  2793.091464
# 3               4  2811.885429
# 4               5  2861.478555

# %%
birth_weight_disparities.to_csv(
    f"{results_dir}/birth_weight_disparities/{location}.csv", index=False
)

# %% [markdown]
# ### Short gestation
#
# All we have here is a self-reported duration of pregnancy.

# %%
# Basically no difference in mean
birth_data.groupby("wealth_quintile").apply(
    lambda df: weighted_avg_and_std(df.duration_of_pregnancy, df.weight)
)
# Out:
#                      mean        sd  effective_sample_size
# wealth_quintile
# 1                8.984584  0.506989           46757.969967
# 2                9.015559  0.518205           34263.878995
# 3                9.050525  0.525370           25463.538749
# 4                9.051636  0.531054           18054.353166
# 5                9.042706  0.535222           13759.568526

# %%
birth_data["short_gestation"] = np.where(
    birth_data.duration_of_pregnancy.isnull(),
    np.nan,
    birth_data.duration_of_pregnancy < 9.0,
)

# %%
weighted_avg_and_std(birth_data.short_gestation, birth_data.weight)
# Out:
# mean                          0.073412
# sd                            0.260812
# effective_sample_size    129817.319675
# dtype: float64

# %%
birth_data.groupby("wealth_quintile").apply(
    lambda df: weighted_avg_and_std(df.short_gestation, df.weight)
)
# Out:
#                      mean        sd  effective_sample_size
# wealth_quintile
# 1                0.078308  0.268655           46757.969967
# 2                0.070505  0.255996           34263.878995
# 3                0.067307  0.250553           25463.538749
# 4                0.072144  0.258726           18054.353166
# 5                0.079073  0.269852           13759.568526

# %% [markdown]
# The trends in short gestation don't make intuitive sense (?), so we do not plan to use them in the sim.
