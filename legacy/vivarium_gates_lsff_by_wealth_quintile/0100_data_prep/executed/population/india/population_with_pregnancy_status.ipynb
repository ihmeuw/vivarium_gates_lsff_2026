# %%
import vivarium_inputs
import gbd_mapping
import pathlib
import pandas as pd, numpy as np
# Out:
# Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# Cache Dir: '/share/scratch/users/zmbc/cache'

# %%
location = "india"

# %%
# Parameters
location = "india"

# %%
total_population = (
    vivarium_inputs.get_population_structure(location.title())
    .droplevel(["location", "year_start", "year_end"])
    .value
)
total_population
# Out:
# sex     age_start  age_end
# Female  0.000000   0.019178      1.975581e+05
#         0.019178   0.076712      5.872100e+05
#         0.076712   0.500000      4.326738e+06
#         0.500000   1.000000      5.085507e+06
#         1.000000   2.000000      1.035319e+07
#         2.000000   5.000000      3.244181e+07
#         5.000000   10.000000     5.860247e+07
#         10.000000  15.000000     6.308955e+07
#         15.000000  20.000000     6.421417e+07
#         20.000000  25.000000     6.367111e+07
#         25.000000  30.000000     5.987495e+07
#         30.000000  35.000000     5.583203e+07
#         35.000000  40.000000     5.170871e+07
#         40.000000  45.000000     4.450696e+07
#         45.000000  50.000000     3.848132e+07
#         50.000000  55.000000     3.339169e+07
#         55.000000  60.000000     2.815693e+07
#         60.000000  65.000000     2.433074e+07
#         65.000000  70.000000     1.946945e+07
#         70.000000  75.000000     1.409918e+07
#         75.000000  80.000000     8.932557e+06
#         80.000000  85.000000     5.492330e+06
#         85.000000  90.000000     2.456616e+06
#         90.000000  95.000000     7.686868e+05
#         95.000000  125.000000    1.882352e+05
# Male    0.000000   0.019178      2.183097e+05
#         0.019178   0.076712      6.478743e+05
#         0.076712   0.500000      4.773409e+06
#         0.500000   1.000000      5.610299e+06
#         1.000000   2.000000      1.141420e+07
#         2.000000   5.000000      3.568017e+07
#         5.000000   10.000000     6.416716e+07
#         10.000000  15.000000     6.920361e+07
#         15.000000  20.000000     6.995908e+07
#         20.000000  25.000000     6.769160e+07
#         25.000000  30.000000     6.286953e+07
#         30.000000  35.000000     5.907718e+07
#         35.000000  40.000000     5.455634e+07
#         40.000000  45.000000     4.685963e+07
#         45.000000  50.000000     4.037186e+07
#         50.000000  55.000000     3.398440e+07
#         55.000000  60.000000     2.776971e+07
#         60.000000  65.000000     2.329699e+07
#         65.000000  70.000000     1.843765e+07
#         70.000000  75.000000     1.308670e+07
#         75.000000  80.000000     8.006173e+06
#         80.000000  85.000000     4.245347e+06
#         85.000000  90.000000     1.733384e+06
#         90.000000  95.000000     4.887364e+05
#         95.000000  125.000000    8.595017e+04
# Name: value, dtype: float64

# %%
path = pathlib.Path(f"../results/population/total/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
total_population.rename("value").to_csv(path)

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location.title()
).droplevel(["location", "year_start", "year_end"])
asfr = (
    asfr[asfr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
asfr[asfr > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.000377
#         15.0       20.0       0.009704
#         20.0       25.0       0.106397
#         25.0       30.0       0.132412
#         30.0       35.0       0.083041
#         35.0       40.0       0.034256
#         40.0       45.0       0.011210
#         45.0       50.0       0.003300
#         50.0       55.0       0.000306
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.stillbirth_to_live_birth_ratio, "estimate", location.title()
)
sbr = (
    sbr[sbr.index.get_level_values("parameter") == "mean_value"]
    .droplevel("parameter")
    .value
)
assert len(sbr) == 1
sbr = sbr.iloc[0]
sbr
# Out:
# 0.0171185109037416

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location.title(),
).droplevel(["location", "year_start", "year_end"])
maternal_abortion_miscarriage_incidence = maternal_abortion_miscarriage_incidence.mean(
    axis=1
)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# 2024-08-09 15:29:15.533 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-08-09 15:29:15.539 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-08-09 15:29:15.540 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# 2024-08-09 15:29:15.739 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-08-09 15:29:15.747 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-08-09 15:29:15.749 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/vivarium_inputs/utilities.py:492: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000011
#         15.0       20.0       0.005012
#         20.0       25.0       0.046109
#         25.0       30.0       0.037998
#         30.0       35.0       0.016195
#         35.0       40.0       0.005648
#         40.0       45.0       0.001498
#         45.0       50.0       0.000417
#         50.0       55.0       0.000042
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy, "incidence_rate", location.title()
).droplevel(["location", "year_start", "year_end"])
ectopic_pregnancy_incidence = ectopic_pregnancy_incidence.mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# 2024-08-09 15:29:16.310 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-08-09 15:29:16.319 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-08-09 15:29:16.321 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# 2024-08-09 15:29:16.618 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-08-09 15:29:16.625 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-08-09 15:29:16.627 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/vivarium_inputs/utilities.py:492: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       9.963372e-07
#         15.0       20.0       4.684112e-04
#         20.0       25.0       5.677795e-03
#         25.0       30.0       8.453703e-03
#         30.0       35.0       5.886407e-03
#         35.0       40.0       2.652823e-03
#         40.0       45.0       1.167778e-03
#         45.0       50.0       5.819037e-04
#         50.0       55.0       1.188261e-04
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.000395
#         15.0       20.0       0.015350
#         20.0       25.0       0.160005
#         25.0       30.0       0.181130
#         30.0       35.0       0.106544
#         35.0       40.0       0.043143
#         40.0       45.0       0.014067
#         45.0       50.0       0.004355
#         50.0       55.0       0.000471
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/incidence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_incidence.rename("value").to_csv(path)

# %%
# https://github.com/ihmeuw/vivarium_gates_iv_iron/blob/862b057457cea2410e8d24c2c9c38c43419cd8b2/src/vivarium_gates_iv_iron/data/loader.py#L237C5-L240C6
PARTIAL_TERM: float = 24 / 52
FULL_TERM: float = 40 / 52
pregnancy_prevalence = FULL_TERM * (asfr + asfr * sbr) + PARTIAL_TERM * (
    maternal_abortion_miscarriage_incidence + ectopic_pregnancy_incidence
)
pregnancy_prevalence[pregnancy_prevalence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.000300
#         15.0       20.0       0.010122
#         20.0       25.0       0.107146
#         25.0       30.0       0.125038
#         30.0       35.0       0.075162
#         35.0       40.0       0.030633
#         40.0       45.0       0.010001
#         45.0       50.0       0.003042
#         50.0       55.0       0.000313
# dtype: float64

# %%
path = pathlib.Path(f"../results/pregnancy/prevalence/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_prevalence.rename("value").to_csv(path)

# %%
population_stratified = pd.concat(
    [
        (pregnancy_prevalence * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="pregnant")
        .set_index("pregnant", append=True)
        .value,
        ((1 - pregnancy_prevalence) * total_population)
        .rename("value")
        .to_frame()
        .assign(pregnant="not_pregnant")
        .set_index("pregnant", append=True)
        .value,
    ]
).sort_index()
population_stratified
# Out:
# sex     age_start  age_end     pregnant
# Female  0.000000   0.019178    not_pregnant    1.975581e+05
#                                pregnant        0.000000e+00
#         0.019178   0.076712    not_pregnant    5.872100e+05
#                                pregnant        0.000000e+00
#         0.076712   0.500000    not_pregnant    4.326738e+06
#                                                    ...
# Male    85.000000  90.000000   pregnant        0.000000e+00
#         90.000000  95.000000   not_pregnant    4.887364e+05
#                                pregnant        0.000000e+00
#         95.000000  125.000000  not_pregnant    8.595017e+04
#                                pregnant        0.000000e+00
# Name: value, Length: 100, dtype: float64

# %%
assert np.isclose(population_stratified.sum(), total_population.sum())

# %%
population_age_groups = (
    total_population.reset_index()[["age_start", "age_end"]]
    .drop_duplicates()
    .sort_values("age_start")
)
population_age_groups
# Out:
#     age_start     age_end
# 0    0.000000    0.019178
# 1    0.019178    0.076712
# 2    0.076712    0.500000
# 3    0.500000    1.000000
# 4    1.000000    2.000000
# 5    2.000000    5.000000
# 6    5.000000   10.000000
# 7   10.000000   15.000000
# 8   15.000000   20.000000
# 9   20.000000   25.000000
# 10  25.000000   30.000000
# 11  30.000000   35.000000
# 12  35.000000   40.000000
# 13  40.000000   45.000000
# 14  45.000000   50.000000
# 15  50.000000   55.000000
# 16  55.000000   60.000000
# 17  60.000000   65.000000
# 18  65.000000   70.000000
# 19  70.000000   75.000000
# 20  75.000000   80.000000
# 21  80.000000   85.000000
# 22  85.000000   90.000000
# 23  90.000000   95.000000
# 24  95.000000  125.000000

# %%
def map_to_population_age_groups(df):
    return (
        population_age_groups.merge(df, how="cross", suffixes=("", "_orig"))
        .pipe(
            lambda df: df[
                (df.age_end <= df.age_end_orig) & (df.age_start >= df.age_start_orig)
            ]
        )
        .drop(columns=["age_start_orig", "age_end_orig"])
    )

# %%
wealth_quintile_probabilities = pd.read_csv(
    f"../results/wealth_quintile_probabilities/{location}.csv"
).set_index(["sex", "age_start", "age_end", "pregnant"])
wealth_quintile_probabilities.columns.name = "wealth_quintile"
wealth_quintile_probabilities = wealth_quintile_probabilities.stack()
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  lowest             0.251317
#                                           second             0.220571
#                                           middle             0.195838
#                                           fourth             0.184456
#                                           highest            0.147818
#         5.0        15.0     not_pregnant  lowest             0.269038
#                                           second             0.219459
#                                           middle             0.193766
#                                           fourth             0.172569
#                                           highest            0.145167
#         15.0       30.0     not_pregnant  lowest             0.177853
#                                           second             0.202279
#                                           middle             0.211418
#                                           fourth             0.210441
#                                           highest            0.198009
#                             pregnant      lowest             0.221117
#                                           second             0.222530
#                                           middle             0.215087
#                                           fourth             0.182296
#                                           highest            0.158970
#         30.0       50.0     not_pregnant  lowest             0.172597
#                                           second             0.187138
#                                           middle             0.199031
#                                           fourth             0.213495
#                                           highest            0.227738
#                             pregnant      lowest             0.316131
#                                           second             0.181401
#                                           middle             0.129805
#                                           fourth             0.169147
#                                           highest            0.203517
#         50.0       125.0    not_pregnant  lowest             0.188708
#                                           second             0.187540
#                                           middle             0.191253
#                                           fourth             0.199636
#                                           highest            0.232863
# Male    0.0        5.0      not_pregnant  lowest             0.242600
#                                           second             0.215610
#                                           middle             0.200229
#                                           fourth             0.183923
#                                           highest            0.157639
#         5.0        15.0     not_pregnant  lowest             0.261604
#                                           second             0.217675
#                                           middle             0.190718
#                                           fourth             0.176545
#                                           highest            0.153458
#         15.0       30.0     not_pregnant  lowest             0.169172
#                                           second             0.205794
#                                           middle             0.214029
#                                           fourth             0.208330
#                                           highest            0.202675
#         30.0       50.0     not_pregnant  lowest             0.167563
#                                           second             0.183939
#                                           middle             0.203419
#                                           fourth             0.219906
#                                           highest            0.225173
#         50.0       125.0    not_pregnant  lowest             0.176575
#                                           second             0.184392
#                                           middle             0.190461
#                                           fourth             0.200876
#                                           highest            0.247696
# dtype: float64

# %%
wealth_quintile_probabilities = (
    map_to_population_age_groups(
        wealth_quintile_probabilities.rename("value").reset_index()
    )
    .set_index(wealth_quintile_probabilities.index.names)
    .value
)
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  lowest             0.251317
#                                              second             0.220571
#                                              middle             0.195838
#                                              fourth             0.184456
#                                              highest            0.147818
#                                                                   ...
# Male    95.0       125.000000  not_pregnant  lowest             0.176575
#                                              second             0.184392
#                                              middle             0.190461
#                                              fourth             0.200876
#                                              highest            0.247696
# Name: value, Length: 285, dtype: float64

# %%
assert np.allclose(
    wealth_quintile_probabilities.groupby(population_stratified.index.names).sum(), 1.0
)

# %%
population_stratified = population_stratified.mul(
    wealth_quintile_probabilities, axis=0
).dropna()
population_stratified
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  lowest             49649.700497
#                                              second             43575.622144
#                                              middle             38689.356750
#                                              fourth             36440.833935
#                                              highest            29202.585338
#                                                                     ...
# Male    95.0       125.000000  not_pregnant  lowest             15176.692284
#                                              second             15848.509818
#                                              middle             16370.176208
#                                              fourth             17265.313670
#                                              highest            21289.473456
# Name: value, Length: 285, dtype: float64

# %%
population_stratified.sum()
# Out:
# 1414465588.7354188

# %%
total_population.sum()
# Out:
# 1414494974.7598393

# %%
assert np.isclose(population_stratified.sum(), total_population.sum(), rtol=0.01)

# %%
path = pathlib.Path(f"../results/population/stratified/{location}.csv")
path.parent.mkdir(exist_ok=True, parents=True)
population_stratified.rename("value").to_csv(path)
