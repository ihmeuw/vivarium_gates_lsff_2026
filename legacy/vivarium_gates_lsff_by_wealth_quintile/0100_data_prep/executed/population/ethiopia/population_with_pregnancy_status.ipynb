# %%
import vivarium_inputs
import gbd_mapping
import pathlib
import pandas as pd, numpy as np
# Out:
# Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# Cache Dir: '/share/scratch/users/zmbc/cache'

# %%
location = "india"

# %%
# Parameters
location = "ethiopia"

# %%
total_population = vivarium_inputs.get_population_structure(location.title()).droplevel(["location", "year_start", "year_end"]).value
total_population
# Out:
# sex     age_start  age_end
# Female  0.000000   0.019178      3.212946e+04
#         0.019178   0.076712      9.536547e+04
#         0.076712   0.500000      6.969145e+05
#         0.500000   1.000000      8.069227e+05
#         1.000000   2.000000      1.588942e+06
#         2.000000   5.000000      4.570339e+06
#         5.000000   10.000000     7.086744e+06
#         10.000000  15.000000     6.753936e+06
#         15.000000  20.000000     6.312640e+06
#         20.000000  25.000000     5.498329e+06
#         25.000000  30.000000     4.610923e+06
#         30.000000  35.000000     3.775392e+06
#         35.000000  40.000000     3.162866e+06
#         40.000000  45.000000     2.535855e+06
#         45.000000  50.000000     1.823107e+06
#         50.000000  55.000000     1.317891e+06
#         55.000000  60.000000     1.005600e+06
#         60.000000  65.000000     7.821221e+05
#         65.000000  70.000000     6.265289e+05
#         70.000000  75.000000     4.023876e+05
#         75.000000  80.000000     2.886510e+05
#         80.000000  85.000000     1.627737e+05
#         85.000000  90.000000     7.026548e+04
#         90.000000  95.000000     2.081378e+04
#         95.000000  125.000000    4.509602e+03
# Male    0.000000   0.019178      3.402968e+04
#         0.019178   0.076712      1.004124e+05
#         0.076712   0.500000      7.330473e+05
#         0.500000   1.000000      8.480661e+05
#         1.000000   2.000000      1.666316e+06
#         2.000000   5.000000      4.792631e+06
#         5.000000   10.000000     7.438956e+06
#         10.000000  15.000000     7.105682e+06
#         15.000000  20.000000     6.534922e+06
#         20.000000  25.000000     5.515785e+06
#         25.000000  30.000000     4.467484e+06
#         30.000000  35.000000     3.554660e+06
#         35.000000  40.000000     2.921799e+06
#         40.000000  45.000000     2.434087e+06
#         45.000000  50.000000     1.887319e+06
#         50.000000  55.000000     1.388927e+06
#         55.000000  60.000000     1.043628e+06
#         60.000000  65.000000     7.902743e+05
#         65.000000  70.000000     6.258484e+05
#         70.000000  75.000000     4.456226e+05
#         75.000000  80.000000     3.135171e+05
#         80.000000  85.000000     1.697816e+05
#         85.000000  90.000000     7.010511e+04
#         90.000000  95.000000     1.965910e+04
#         95.000000  125.000000    3.488085e+03
# Name: value, dtype: float64

# %%
path = pathlib.Path(f'../results/population/total/{location}.csv')
path.parent.mkdir(exist_ok=True, parents=True)
total_population.rename("value").to_csv(path)

# %%
asfr = vivarium_inputs.get_measure(gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location.title()).droplevel(["location", "year_start", "year_end"])
asfr = asfr[asfr.index.get_level_values('parameter') == 'mean_value'].droplevel("parameter").value
asfr[asfr > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.002573
#         15.0       20.0       0.045776
#         20.0       25.0       0.191993
#         25.0       30.0       0.184309
#         30.0       35.0       0.178496
#         35.0       40.0       0.126932
#         40.0       45.0       0.066364
#         45.0       50.0       0.021933
#         50.0       55.0       0.002033
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(gbd_mapping.covariates.stillbirth_to_live_birth_ratio, "estimate", location.title())
sbr = sbr[sbr.index.get_level_values('parameter') == 'mean_value'].droplevel("parameter").value
assert len(sbr) == 1
sbr = sbr.iloc[0]
sbr
# Out:
# 0.0175716641363179

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(gbd_mapping.causes.maternal_abortion_and_miscarriage, "incidence_rate", location.title()).droplevel(["location", "year_start", "year_end"])
maternal_abortion_miscarriage_incidence = maternal_abortion_miscarriage_incidence.mean(axis=1)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# 2024-08-07 19:01:05.293 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-08-07 19:01:05.301 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-08-07 19:01:05.302 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# 2024-08-07 19:01:05.519 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-08-07 19:01:05.535 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-08-07 19:01:05.536 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/vivarium_inputs/utilities.py:492: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000782
#         15.0       20.0       0.027543
#         20.0       25.0       0.105360
#         25.0       30.0       0.094651
#         30.0       35.0       0.088526
#         35.0       40.0       0.061951
#         40.0       45.0       0.027148
#         45.0       50.0       0.007389
#         50.0       55.0       0.000662
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(gbd_mapping.causes.ectopic_pregnancy, "incidence_rate", location.title()).droplevel(["location", "year_start", "year_end"])
ectopic_pregnancy_incidence = ectopic_pregnancy_incidence.mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# 2024-08-07 19:01:06.354 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-08-07 19:01:06.363 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-08-07 19:01:06.364 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# 2024-08-07 19:01:06.681 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-08-07 19:01:06.694 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-08-07 19:01:06.696 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/vivarium_inputs/utilities.py:492: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# sex     age_start  age_end
# Female  10.0       15.0       0.000105
#         15.0       20.0       0.002708
#         20.0       25.0       0.008810
#         25.0       30.0       0.009668
#         30.0       35.0       0.011650
#         35.0       40.0       0.010551
#         40.0       45.0       0.008400
#         45.0       50.0       0.004882
#         50.0       55.0       0.001458
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.003505
#         15.0       20.0       0.076832
#         20.0       25.0       0.309537
#         25.0       30.0       0.291867
#         30.0       35.0       0.281807
#         35.0       40.0       0.201665
#         40.0       45.0       0.103078
#         45.0       50.0       0.034589
#         50.0       55.0       0.004189
# dtype: float64

# %%
path = pathlib.Path(f'../results/pregnancy/incidence/{location}.csv')
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_incidence.rename("value").to_csv(path)

# %%
# https://github.com/ihmeuw/vivarium_gates_iv_iron/blob/862b057457cea2410e8d24c2c9c38c43419cd8b2/src/vivarium_gates_iv_iron/data/loader.py#L237C5-L240C6
PARTIAL_TERM: float = 24 / 52
FULL_TERM: float = 40 / 52
pregnancy_prevalence = (
    FULL_TERM * (asfr + asfr * sbr)
    + PARTIAL_TERM * (maternal_abortion_miscarriage_incidence + ectopic_pregnancy_incidence)
)
pregnancy_prevalence[pregnancy_prevalence > 0]
# Out:
# sex     age_start  age_end
# Female  10.0       15.0       0.002423
#         15.0       20.0       0.049793
#         20.0       25.0       0.202976
#         25.0       30.0       0.192415
#         30.0       35.0       0.185952
#         35.0       40.0       0.132818
#         40.0       45.0       0.068353
#         45.0       50.0       0.022831
#         50.0       55.0       0.002570
# dtype: float64

# %%
path = pathlib.Path(f'../results/pregnancy/prevalence/{location}.csv')
path.parent.mkdir(exist_ok=True, parents=True)
pregnancy_prevalence.rename("value").to_csv(path)

# %%
population_stratified = pd.concat([
    (pregnancy_prevalence * total_population).rename("value").to_frame().assign(pregnant="pregnant").set_index("pregnant", append=True).value,
    ((1 - pregnancy_prevalence) * total_population).rename("value").to_frame().assign(pregnant="not_pregnant").set_index("pregnant", append=True).value,
]).sort_index()
population_stratified
# Out:
# sex     age_start  age_end     pregnant
# Female  0.000000   0.019178    not_pregnant     32129.461362
#                                pregnant             0.000000
#         0.019178   0.076712    not_pregnant     95365.473841
#                                pregnant             0.000000
#         0.076712   0.500000    not_pregnant    696914.518216
#                                                    ...
# Male    85.000000  90.000000   pregnant             0.000000
#         90.000000  95.000000   not_pregnant     19659.103202
#                                pregnant             0.000000
#         95.000000  125.000000  not_pregnant      3488.084807
#                                pregnant             0.000000
# Name: value, Length: 100, dtype: float64

# %%
assert np.isclose(population_stratified.sum(), total_population.sum())

# %%
population_age_groups = total_population.reset_index()[["age_start", "age_end"]].drop_duplicates().sort_values("age_start")
population_age_groups
# Out:
#     age_start     age_end
# 0    0.000000    0.019178
# 1    0.019178    0.076712
# 2    0.076712    0.500000
# 3    0.500000    1.000000
# 4    1.000000    2.000000
# 5    2.000000    5.000000
# 6    5.000000   10.000000
# 7   10.000000   15.000000
# 8   15.000000   20.000000
# 9   20.000000   25.000000
# 10  25.000000   30.000000
# 11  30.000000   35.000000
# 12  35.000000   40.000000
# 13  40.000000   45.000000
# 14  45.000000   50.000000
# 15  50.000000   55.000000
# 16  55.000000   60.000000
# 17  60.000000   65.000000
# 18  65.000000   70.000000
# 19  70.000000   75.000000
# 20  75.000000   80.000000
# 21  80.000000   85.000000
# 22  85.000000   90.000000
# 23  90.000000   95.000000
# 24  95.000000  125.000000

# %%
def map_to_population_age_groups(df):
    return (
        population_age_groups.merge(df, how="cross", suffixes=("", "_orig"))
            .pipe(lambda df: df[(df.age_end <= df.age_end_orig) & (df.age_start >= df.age_start_orig)])
            .drop(columns=["age_start_orig", "age_end_orig"])
    )

# %%
wealth_quintile_probabilities = pd.read_csv(f'../results/wealth_quintile_probabilities/{location}.csv').set_index(["sex", "age_start", "age_end", "pregnant"])
wealth_quintile_probabilities.columns.name = "wealth_quintile"
wealth_quintile_probabilities = wealth_quintile_probabilities.stack()
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end  pregnant      wealth_quintile
# Female  0.0        5.0      not_pregnant  lowest             0.240568
#                                           second             0.218680
#                                           middle             0.206739
#                                           fourth             0.185403
#                                           highest            0.148610
#         5.0        15.0     not_pregnant  lowest             0.219482
#                                           second             0.209157
#                                           middle             0.210067
#                                           fourth             0.207411
#                                           highest            0.153883
#         15.0       30.0     not_pregnant  lowest             0.154054
#                                           second             0.173552
#                                           middle             0.180132
#                                           fourth             0.193390
#                                           highest            0.298871
#                             pregnant      lowest             0.214447
#                                           second             0.257398
#                                           middle             0.173152
#                                           fourth             0.167345
#                                           highest            0.187658
#         30.0       50.0     not_pregnant  lowest             0.176930
#                                           second             0.178372
#                                           middle             0.198273
#                                           fourth             0.205845
#                                           highest            0.240580
#                             pregnant      lowest             0.250120
#                                           second             0.185543
#                                           middle             0.217769
#                                           fourth             0.191428
#                                           highest            0.155140
#         50.0       125.0    not_pregnant  lowest             0.205491
#                                           second             0.204239
#                                           middle             0.195294
#                                           fourth             0.199461
#                                           highest            0.195515
# Male    0.0        5.0      not_pregnant  lowest             0.236076
#                                           second             0.239462
#                                           middle             0.208587
#                                           fourth             0.173674
#                                           highest            0.142200
#         5.0        15.0     not_pregnant  lowest             0.226779
#                                           second             0.210595
#                                           middle             0.205277
#                                           fourth             0.206115
#                                           highest            0.151234
#         15.0       30.0     not_pregnant  lowest             0.157551
#                                           second             0.173962
#                                           middle             0.186354
#                                           fourth             0.221764
#                                           highest            0.260370
#         30.0       50.0     not_pregnant  lowest             0.167606
#                                           second             0.192322
#                                           middle             0.201171
#                                           fourth             0.194831
#                                           highest            0.244070
#         50.0       125.0    not_pregnant  lowest             0.189095
#                                           second             0.197845
#                                           middle             0.205353
#                                           fourth             0.217282
#                                           highest            0.190425
# dtype: float64

# %%
wealth_quintile_probabilities = map_to_population_age_groups(wealth_quintile_probabilities.rename("value").reset_index()).set_index(wealth_quintile_probabilities.index.names).value
wealth_quintile_probabilities
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  lowest             0.240568
#                                              second             0.218680
#                                              middle             0.206739
#                                              fourth             0.185403
#                                              highest            0.148610
#                                                                   ...
# Male    95.0       125.000000  not_pregnant  lowest             0.189095
#                                              second             0.197845
#                                              middle             0.205353
#                                              fourth             0.217282
#                                              highest            0.190425
# Name: value, Length: 285, dtype: float64

# %%
assert np.allclose(wealth_quintile_probabilities.groupby(population_stratified.index.names).sum(), 1.0)

# %%
population_stratified = population_stratified.mul(wealth_quintile_probabilities, axis=0).dropna()
population_stratified
# Out:
# sex     age_start  age_end     pregnant      wealth_quintile
# Female  0.0        0.019178    not_pregnant  lowest             7729.330504
#                                              second             7026.085890
#                                              middle             6642.401601
#                                              fourth             5956.884779
#                                              highest            4774.758589
#                                                                    ...
# Male    95.0       125.000000  not_pregnant  lowest              659.578610
#                                              second              690.099645
#                                              middle              716.289850
#                                              fourth              757.897451
#                                              highest             664.219250
# Name: value, Length: 285, dtype: float64

# %%
population_stratified.sum()
# Out:
# 108918246.6738451

# %%
total_population.sum()
# Out:
# 108937999.59866266

# %%
assert np.isclose(population_stratified.sum(), total_population.sum(), rtol=0.01)

# %%
path = pathlib.Path(f'../results/population/stratified/{location}.csv')
path.parent.mkdir(exist_ok=True, parents=True)
population_stratified.rename("value").to_csv(path)
