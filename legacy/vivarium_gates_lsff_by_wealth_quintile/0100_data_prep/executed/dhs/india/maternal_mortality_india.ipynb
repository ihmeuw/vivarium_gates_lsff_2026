# %%
# %pdb on
# Out:
# Automatic pdb calling has been turned ON

# %%
import pandas as pd, numpy as np

# %%
location = "india"
directory = "/snfs1/DATA/DHS_PROG_DHS/IND/2015_2016/"
results_dir = (
    "../results"
)

# %% [markdown]
# ### WRA

# %%
# %%time

wra_columns = {
    "v001": "cluster_number",
    "v002": "household_number",
    "v003": "line_number",
    "v005": "weight",
    "v008": "interview_date",
    "v011": "date_of_birth",
    "v190": "wealth_quintile",
}
wra_data = pd.read_stata(
    directory + ("IND_DHS7_2015_2016_WN_IAIR74FL_Y2018M12D06.DTA" if location == "india" else "NGA_DHS7_2018_WN_NGIR7AFL_Y2019M11D05.DTA"),
    columns=wra_columns.keys(),
)
# Out:
# CPU times: user 1min, sys: 9.42 s, total: 1min 9s
# Wall time: 1min 9s

# %%
wra_data = wra_data[wra_columns.keys()].rename(columns=wra_columns)

# %%
def recode_wealth_quintile(df):
    return df.map(
        {
            "poorest": "lowest",
            "poorer": "second",
            "middle": "middle",
            "richer": "fourth",
            "richest": "highest",
        }
    )

# %%
wra_data["wealth_quintile"] = recode_wealth_quintile(wra_data.wealth_quintile)

# %%
wra_data["weight"] = wra_data.weight / 1_000_000

# %% [markdown]
# ### Adult mortality
#
# Adult mortality included in HH for India (recent household members who died).

# %%
# %%time

household_columns = {
    "hv005": "weight",
    "sh70": "any_died",
    "sh71": "num_died",
    "hv270": "wealth_quintile",
}
MAX_NUM_DEATHS = 5
death_columns = {
    "sh73": "sex",
    "sh74u": "age_at_death_unit",
    "sh74n": "age_at_death",
    "sh75m": "month_of_death",
    "sh75y": "year_of_death",
    "sh76": "death_violence_or_accident",
    "sh77": "death_during_pregnancy_or_childbirth",
}
columns = list(household_columns.keys())
for death_num in range(1, MAX_NUM_DEATHS + 1):
    columns += [c + "_" + str(death_num) for c in death_columns.keys()]

adult_mortality_data = pd.read_stata(
    directory + "IND_DHS7_2015_2016_HH_IAHR74FL_Y2018M12D06.DTA", columns=columns
)
adult_mortality_data
# Out:
# CPU times: user 1min 1s, sys: 9.83 s, total: 1min 11s
# Wall time: 1min 11s
#           hv005 sh70  sh71    hv270 sh73_1 sh74u_1 sh74n_1 sh75m_1 sh75y_1  \
# 0        191072   no   NaN   middle    NaN     NaN     NaN     NaN     NaN
# 1        191072   no   NaN   richer    NaN     NaN     NaN     NaN     NaN
# 2        191072   no   NaN   richer    NaN     NaN     NaN     NaN     NaN
# 3        191072   no   NaN   richer    NaN     NaN     NaN     NaN     NaN
# 4        191072   no   NaN   middle    NaN     NaN     NaN     NaN     NaN
# ...         ...  ...   ...      ...    ...     ...     ...     ...     ...
# 601504  2270734   no   NaN  poorest    NaN     NaN     NaN     NaN     NaN
# 601505  2270734   no   NaN   poorer    NaN     NaN     NaN     NaN     NaN
# 601506  2270734   no   NaN   richer    NaN     NaN     NaN     NaN     NaN
# 601507  2270734   no   NaN   middle    NaN     NaN     NaN     NaN     NaN
# 601508  2270734   no   NaN   middle    NaN     NaN     NaN     NaN     NaN
#
#        sh76_1  ... sh75y_4 sh76_4 sh77_4 sh73_5 sh74u_5 sh74n_5 sh75m_5  \
# 0         NaN  ...     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 1         NaN  ...     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 2         NaN  ...     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 3         NaN  ...     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 4         NaN  ...     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# ...       ...  ...     ...    ...    ...    ...     ...     ...     ...
# 601504    NaN  ...     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 601505    NaN  ...     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 601506    NaN  ...     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 601507    NaN  ...     NaN    NaN    NaN    NaN     NaN     NaN     NaN
# 601508    NaN  ...     NaN    NaN    NaN    NaN     NaN     NaN     NaN
#
#        sh75y_5 sh76_5 sh77_5
# 0          NaN    NaN    NaN
# 1          NaN    NaN    NaN
# 2          NaN    NaN    NaN
# 3          NaN    NaN    NaN
# 4          NaN    NaN    NaN
# ...        ...    ...    ...
# 601504     NaN    NaN    NaN
# 601505     NaN    NaN    NaN
# 601506     NaN    NaN    NaN
# 601507     NaN    NaN    NaN
# 601508     NaN    NaN    NaN
#
# [601509 rows x 39 columns]

# %%
# inspired by https://stackoverflow.com/a/67393747/
adult_mortality_data_reshaped = adult_mortality_data[
    [c for c in adult_mortality_data.columns if c.split("_")[0] in death_columns.keys()]
].copy()
adult_mortality_data_reshaped.columns = adult_mortality_data_reshaped.columns.str.split(
    "_", expand=True
)
adult_mortality_data_reshaped
# Out:
#        sh73 sh74u sh74n sh75m sh75y sh76 sh77 sh73 sh74u sh74n  ... sh75y  \
#           1     1     1     1     1    1    1    2     2     2  ...     4
# 0       NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 1       NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 2       NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 3       NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 4       NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# ...     ...   ...   ...   ...   ...  ...  ...  ...   ...   ...  ...   ...
# 601504  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 601505  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 601506  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 601507  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 601508  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
#
#        sh76 sh77 sh73 sh74u sh74n sh75m sh75y sh76 sh77
#           4    4    5     5     5     5     5    5    5
# 0       NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 1       NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 2       NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 3       NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 4       NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# ...     ...  ...  ...   ...   ...   ...   ...  ...  ...
# 601504  NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 601505  NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 601506  NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 601507  NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
# 601508  NaN  NaN  NaN   NaN   NaN   NaN   NaN  NaN  NaN
#
# [601509 rows x 35 columns]

# %%
adult_mortality_data_reshaped[list(household_columns.keys())] = adult_mortality_data[
    list(household_columns.keys())
]
adult_mortality_data_reshaped
# Out:
#        sh73 sh74u sh74n sh75m sh75y sh76 sh77 sh73 sh74u sh74n  ... sh74u  \
#           1     1     1     1     1    1    1    2     2     2  ...     5
# 0       NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 1       NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 2       NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 3       NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 4       NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# ...     ...   ...   ...   ...   ...  ...  ...  ...   ...   ...  ...   ...
# 601504  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 601505  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 601506  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 601507  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
# 601508  NaN   NaN   NaN   NaN   NaN  NaN  NaN  NaN   NaN   NaN  ...   NaN
#
#        sh74n sh75m sh75y sh76 sh77    hv005 sh70 sh71    hv270
#            5     5     5    5    5
# 0        NaN   NaN   NaN  NaN  NaN   191072   no  NaN   middle
# 1        NaN   NaN   NaN  NaN  NaN   191072   no  NaN   richer
# 2        NaN   NaN   NaN  NaN  NaN   191072   no  NaN   richer
# 3        NaN   NaN   NaN  NaN  NaN   191072   no  NaN   richer
# 4        NaN   NaN   NaN  NaN  NaN   191072   no  NaN   middle
# ...      ...   ...   ...  ...  ...      ...  ...  ...      ...
# 601504   NaN   NaN   NaN  NaN  NaN  2270734   no  NaN  poorest
# 601505   NaN   NaN   NaN  NaN  NaN  2270734   no  NaN   poorer
# 601506   NaN   NaN   NaN  NaN  NaN  2270734   no  NaN   richer
# 601507   NaN   NaN   NaN  NaN  NaN  2270734   no  NaN   middle
# 601508   NaN   NaN   NaN  NaN  NaN  2270734   no  NaN   middle
#
# [601509 rows x 39 columns]

# %%
# Get a row per death
adult_mortality_data_reshaped = (
    adult_mortality_data_reshaped.set_index(list(household_columns.keys()))
    .swaplevel(axis=1)
    .stack(0)
    .reset_index()
    .drop(columns=[f"level_{len(household_columns)}"])
)
adult_mortality_data_reshaped
# Out:
#          hv005 sh70  sh71   hv270    sh73 sh74n   sh74u      sh75m   sh75y  \
# 0         8939  yes   1.0  middle    male  51.0    year      april  2015.0
# 1         8939  yes   1.0  middle    male  56.0  months      april  2015.0
# 2         4495  yes   1.0  middle    male  45.0    year     august  2014.0
# 3         4495  yes   2.0  richer    male  35.0    year        may  2014.0
# 4         4495  yes   2.0  richer    male  40.0    year     august  2014.0
# ...        ...  ...   ...     ...     ...   ...     ...        ...     ...
# 74940  2463153  yes   2.0  poorer  female  21.0    year  september  2013.0
# 74941  2270734  yes   1.0  middle  female  80.0    year   november  2014.0
# 74942  2270734  yes   1.0  middle    male  50.0    year    january  2015.0
# 74943  2270734  yes   1.0  middle    male  45.0  months    january  2012.0
# 74944  2270734  yes   1.0  poorer  female  90.0    year    january  2012.0
#
#       sh76 sh77
# 0       no  NaN
# 1      yes  NaN
# 2       no  NaN
# 3       no  NaN
# 4       no  NaN
# ...    ...  ...
# 74940  yes  NaN
# 74941   no   no
# 74942   no  NaN
# 74943  yes  NaN
# 74944   no   no
#
# [74945 rows x 11 columns]

# %%
def recode_wealth_quintile(df):
    return df.map(
        {
            "poorest": "lowest",
            "poorer": "second",
            "middle": "middle",
            "richer": "fourth",
            "richest": "highest",
        }
    )

# %%
adult_mortality_data = (
    adult_mortality_data_reshaped[
        list(household_columns.keys()) + list(death_columns.keys())
    ]
    .rename(columns=household_columns)
    .rename(columns=death_columns)
)
adult_mortality_data["wealth_quintile"] = recode_wealth_quintile(
    adult_mortality_data.wealth_quintile
)
adult_mortality_data["weight"] = adult_mortality_data.weight / 1_000_000
adult_mortality_data
# Out:
#          weight any_died  num_died wealth_quintile     sex age_at_death_unit  \
# 0      0.008939      yes       1.0          middle    male              year
# 1      0.008939      yes       1.0          middle    male            months
# 2      0.004495      yes       1.0          middle    male              year
# 3      0.004495      yes       2.0          fourth    male              year
# 4      0.004495      yes       2.0          fourth    male              year
# ...         ...      ...       ...             ...     ...               ...
# 74940  2.463153      yes       2.0          second  female              year
# 74941  2.270734      yes       1.0          middle  female              year
# 74942  2.270734      yes       1.0          middle    male              year
# 74943  2.270734      yes       1.0          middle    male            months
# 74944  2.270734      yes       1.0          second  female              year
#
#       age_at_death month_of_death year_of_death death_violence_or_accident  \
# 0             51.0          april        2015.0                         no
# 1             56.0          april        2015.0                        yes
# 2             45.0         august        2014.0                         no
# 3             35.0            may        2014.0                         no
# 4             40.0         august        2014.0                         no
# ...            ...            ...           ...                        ...
# 74940         21.0      september        2013.0                        yes
# 74941         80.0       november        2014.0                         no
# 74942         50.0        january        2015.0                         no
# 74943         45.0        january        2012.0                        yes
# 74944         90.0        january        2012.0                         no
#
#       death_during_pregnancy_or_childbirth
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 74940                                  NaN
# 74941                                   no
# 74942                                  NaN
# 74943                                  NaN
# 74944                                   no
#
# [74945 rows x 11 columns]

# %% [markdown]
# ### Births

# %%
birth_columns = {
    "v005": "weight",
    "v008": "interview_date",
    "v190": "wealth_quintile",
    "b3": "birth_date",
    "m18": "size_of_child",
    "m19": "birth_weight_kilograms",
    
}
if location == "india":
    birth_columns["s220a"] = "duration_of_pregnancy"
else:
    birth_columns["b20"] = "duration_of_pregnancy"

birth_data = pd.read_stata(
    directory + ("IND_DHS7_2015_2016_BR_IABR74FL_Y2018M12D06.DTA" if location == "india" else "NGA_DHS7_2018_BR_NGBR7AFL_Y2019M11D05.DTA"),
    columns=birth_columns.keys(),
)
birth_data
# Out:
#             v005  v008    v190    b3         m18     m19  s220a
# 0         191760  1387  middle  1141         NaN     NaN    NaN
# 1         191760  1387  middle  1117         NaN     NaN    NaN
# 2         191760  1387  middle  1089         NaN     NaN    NaN
# 3         191760  1387  richer  1154         NaN     NaN    NaN
# 4         191760  1387  richer  1129         NaN     NaN    NaN
# ...          ...   ...     ...   ...         ...     ...    ...
# 1315612  2380715  1385  richer  1346  very large  3250.0    9.0
# 1315613  2380715  1385  middle  1100         NaN     NaN    NaN
# 1315614  2380715  1385  middle  1059         NaN     NaN    NaN
# 1315615  2380715  1385  middle  1027         NaN     NaN    NaN
# 1315616  2380715  1385  middle   989         NaN     NaN    NaN
#
# [1315617 rows x 7 columns]

# %%
birth_data = birth_data[birth_columns.keys()].rename(columns=birth_columns)
birth_data["wealth_quintile"] = recode_wealth_quintile(birth_data.wealth_quintile)
birth_data["weight"] = birth_data.weight / 1_000_000
birth_data
# Out:
#            weight  interview_date wealth_quintile  birth_date size_of_child  \
# 0        0.191760            1387          middle        1141           NaN
# 1        0.191760            1387          middle        1117           NaN
# 2        0.191760            1387          middle        1089           NaN
# 3        0.191760            1387          fourth        1154           NaN
# 4        0.191760            1387          fourth        1129           NaN
# ...           ...             ...             ...         ...           ...
# 1315612  2.380715            1385          fourth        1346    very large
# 1315613  2.380715            1385          middle        1100           NaN
# 1315614  2.380715            1385          middle        1059           NaN
# 1315615  2.380715            1385          middle        1027           NaN
# 1315616  2.380715            1385          middle         989           NaN
#
#         birth_weight_kilograms  duration_of_pregnancy
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
# ...                        ...                    ...
# 1315612                 3250.0                    9.0
# 1315613                    NaN                    NaN
# 1315614                    NaN                    NaN
# 1315615                    NaN                    NaN
# 1315616                    NaN                    NaN
#
# [1315617 rows x 7 columns]

# %% [markdown]
# ### Household members

# %%
# %%time

hhm_columns = {
    "hv001": "cluster_number",
    "hv002": "household_number",
    "hv005": "weight",
    "hv008": "date_of_interview",
    "hvidx": "line_number",
    "hml18": "currently_pregnant",
    "hv105": "age",
    "hv104": "sex",
    "ha0": "index_to_household",
    "ha1": "age_hemoglobin",
    "hv270": "wealth_quintile",
    "ha53": "hemoglobin_raw_adult",
    "ha56": "hemoglobin_adjusted_adult",
    "ha57": "anemia_adult",
    "hc53": "hemoglobin_raw_child",
    "hc56": "hemoglobin_adjusted_child",
    "hc57": "anemia_child", 
}
hhm_data = pd.read_stata(
    directory + ("IND_DHS7_2015_2016_HHM_IAPR74FL_Y2018M12D06.DTA" if location == "india" else "NGA_DHS7_2018_HHM_NGPR7AFL_Y2019M11D05.DTA"),
    columns=hhm_columns.keys(),
)
hhm_data
# Out:
# CPU times: user 18 s, sys: 4.87 s, total: 22.9 s
# Wall time: 22.9 s
#           hv001  hv002    hv005  hv008  hvidx                     hml18 hv105  \
# 0         10001      1   191072   1387      1                       NaN    51
# 1         10001      1   191072   1387      2  not pregnant, don't know    46
# 2         10001      1   191072   1387      3                       NaN    22
# 3         10001      1   191072   1387      4  not pregnant, don't know    20
# 4         10001      9   191072   1387      1  not pregnant, don't know    40
# ...         ...    ...      ...    ...    ...                       ...   ...
# 2869038  360482     85  2270734   1385      1                       NaN    60
# 2869039  360482     85  2270734   1385      2                       NaN    50
# 2869040  360482     96  2270734   1385      1                       NaN    66
# 2869041  360482     96  2270734   1385      2  not pregnant, don't know    46
# 2869042  360482     96  2270734   1385      3                       NaN    26
#
#           hv104  ha0   ha1   hv270   ha53   ha56      ha57 hc53 hc56 hc57
# 0          male  NaN   NaN  middle    NaN    NaN       NaN  NaN  NaN  NaN
# 1        female  2.0  46.0  middle   81.0   81.0  moderate  NaN  NaN  NaN
# 2          male  NaN   NaN  middle    NaN    NaN       NaN  NaN  NaN  NaN
# 3        female  4.0  20.0  middle  113.0  113.0      mild  NaN  NaN  NaN
# 4        female  1.0  40.0  richer  116.0  116.0      mild  NaN  NaN  NaN
# ...         ...  ...   ...     ...    ...    ...       ...  ...  ...  ...
# 2869038    male  NaN   NaN  middle    NaN    NaN       NaN  NaN  NaN  NaN
# 2869039  female  NaN   NaN  middle    NaN    NaN       NaN  NaN  NaN  NaN
# 2869040    male  NaN   NaN  middle    NaN    NaN       NaN  NaN  NaN  NaN
# 2869041  female  2.0  46.0  middle  119.0  119.0      mild  NaN  NaN  NaN
# 2869042    male  NaN   NaN  middle    NaN    NaN       NaN  NaN  NaN  NaN
#
# [2869043 rows x 17 columns]

# %%
hhm_data = hhm_data[hhm_columns.keys()].rename(columns=hhm_columns)

# %%
hhm_data["age"] = hhm_data.age.replace({"95+": 95, "don't know": np.nan}).astype(float)

# %%
hhm_data["sex"] = hhm_data.sex.str.title()

# %%
# Interesting -- sometimes age is quite off between hemoglobin and base.
hhm_data.loc[(hhm_data.age - hhm_data.age_hemoglobin).sort_values().index]
# Out:
#          cluster_number  household_number   weight  date_of_interview  \
# 2476814          332896                13   469645               1399
# 791387           140281                68   892170               1395
# 1062670          160904                16  2105279               1384
# 845590           140822                66   241894               1394
# 2709355          340097                79   339513               1382
# ...                 ...               ...      ...                ...
# 2869037          360482                75  2270734               1385
# 2869038          360482                85  2270734               1385
# 2869039          360482                85  2270734               1385
# 2869040          360482                96  2270734               1385
# 2869042          360482                96  2270734               1385
#
#          line_number        currently_pregnant   age     sex  \
# 2476814            4  not pregnant, don't know  17.0  Female
# 791387             4  not pregnant, don't know  19.0  Female
# 1062670            3  not pregnant, don't know  19.0  Female
# 845590             4  not pregnant, don't know  20.0  Female
# 2709355            3  not pregnant, don't know  16.0  Female
# ...              ...                       ...   ...     ...
# 2869037            4                       NaN   2.0    Male
# 2869038            1                       NaN  60.0    Male
# 2869039            2                       NaN  50.0  Female
# 2869040            1                       NaN  66.0    Male
# 2869042            3                       NaN  26.0    Male
#
#          index_to_household  age_hemoglobin wealth_quintile  \
# 2476814                 4.0            48.0         richest
# 791387                  4.0            49.0          middle
# 1062670                 3.0            48.0         richest
# 845590                  4.0            49.0          poorer
# 2709355                 3.0            44.0         richest
# ...                     ...             ...             ...
# 2869037                 NaN             NaN          richer
# 2869038                 NaN             NaN          middle
# 2869039                 NaN             NaN          middle
# 2869040                 NaN             NaN          middle
# 2869042                 NaN             NaN          middle
#
#         hemoglobin_raw_adult hemoglobin_adjusted_adult anemia_adult  \
# 2476814              refused                       NaN          NaN
# 791387                 109.0                     109.0         mild
# 1062670                132.0                     132.0   not anemic
# 845590                 119.0                     108.0         mild
# 2709355                142.0                     142.0   not anemic
# ...                      ...                       ...          ...
# 2869037                  NaN                       NaN          NaN
# 2869038                  NaN                       NaN          NaN
# 2869039                  NaN                       NaN          NaN
# 2869040                  NaN                       NaN          NaN
# 2869042                  NaN                       NaN          NaN
#
#         hemoglobin_raw_child hemoglobin_adjusted_child anemia_child
# 2476814                  NaN                       NaN          NaN
# 791387                   NaN                       NaN          NaN
# 1062670                  NaN                       NaN          NaN
# 845590                   NaN                       NaN          NaN
# 2709355                  NaN                       NaN          NaN
# ...                      ...                       ...          ...
# 2869037                 91.0                      91.0     moderate
# 2869038                  NaN                       NaN          NaN
# 2869039                  NaN                       NaN          NaN
# 2869040                  NaN                       NaN          NaN
# 2869042                  NaN                       NaN          NaN
#
# [2869043 rows x 17 columns]

# %%
(hhm_data.age - hhm_data.age_hemoglobin).describe()
# Out:
# count    749344.000000
# mean         -0.041664
# std           0.841376
# min         -31.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          31.000000
# dtype: float64

# %%
hhm_data["pregnant"] = hhm_data.currently_pregnant.map({"not pregnant, don't know": "not_pregnant", "pregnant": "pregnant"})
hhm_data.loc[hhm_data.sex != 'Female', "pregnant"] = "not_pregnant"
hhm_data.loc[(hhm_data.age < 15) | (hhm_data.age >= 50), "pregnant"] = "not_pregnant"
age_bin_edges = [0, 5, 15, 30, 50, 125]
age_group = pd.IntervalIndex(
    pd.cut(hhm_data.age, age_bin_edges, right=False, include_lowest=True)
)
hhm_data["age_start"] = age_group.left
hhm_data["age_end"] = age_group.right

# %%
hhm_data["wealth_quintile"] = recode_wealth_quintile(hhm_data.wealth_quintile)
hhm_data["weight"] = hhm_data.weight / 1_000_000

# %%
for type in ["child", "adult"]:
    for base_col in ["hemoglobin_raw", "hemoglobin_adjusted"]:
        col = f"{base_col}_{type}"
        hhm_data[col] = (
            hhm_data[col]
            .astype(str)
            .replace(
                {
                    "not tested": np.nan,
                    "not present": np.nan,
                    "refused": np.nan,
                    "other": np.nan,
                }
            )
            .astype(float)
        )

# %%
for base_col in ["hemoglobin_raw", "hemoglobin_adjusted", "anemia"]:
    assert (hhm_data.filter(like=base_col).notnull().sum(axis=1) <= 1).all()
    hhm_data[base_col] = np.nan
    # Could use bfill instead of this loop, but it was incredibly slow for me
    for col in hhm_data.filter(like=base_col).columns:
        hhm_data[base_col] = hhm_data[base_col].fillna(hhm_data[col])

# %%
assert (hhm_data[(hhm_data.sex == "male") & (hhm_data.age > 5)].hemoglobin_raw.isnull().all())

# %% [markdown]
# ### Maternal mortality ratio
#
# #### Maternal mortality rate
#
# Not reported anywhere for India DHS, so we need to be extra careful since we can't cross-check.

# %%
adult_mortality_data.death_during_pregnancy_or_childbirth.value_counts()
# Out:
# no     23283
# yes      615
# Name: death_during_pregnancy_or_childbirth, dtype: int64

# %%
adult_mortality_data.death_violence_or_accident.value_counts()
# Out:
# no            67183
# yes            7509
# don't know      253
# Name: death_violence_or_accident, dtype: int64

# %%
adult_mortality_data["age_at_death_years"] = (
    adult_mortality_data.age_at_death_unit.map(
        {"year": 1, "months": 1 / 12, "days": 1 / 365.25}
    )
    * adult_mortality_data.age_at_death
)

# %%
adult_mortality_data["adult_death"] = (
    adult_mortality_data.age_at_death_years >= 15
) & (adult_mortality_data.age_at_death_years < 50)

# %%
adult_mortality_data["date_of_death"] = adult_mortality_data.year_of_death.replace(
    {"don't know": np.nan}
).astype(float) + (
    adult_mortality_data.month_of_death.map(
        {
            "january": 1,
            "february": 2,
            "march": 3,
            "april": 4,
            "may": 5,
            "june": 6,
            "july": 7,
            "august": 8,
            "september": 9,
            "october": 10,
            "november": 11,
            "december": 12,
        }
    )
    - 0.5
) * (
    1 / 12
)

# %%
adult_mortality_data["date_of_birth"] = (
    adult_mortality_data.date_of_death - adult_mortality_data.age_at_death_years
)
adult_mortality_data["exposure_start"] = np.maximum(
    adult_mortality_data.date_of_birth + 15, 2011.0
)
adult_mortality_data["exposure_end"] = np.minimum(
    adult_mortality_data.date_of_birth + 50, adult_mortality_data.date_of_death
)
adult_mortality_data["exposure"] = np.maximum(
    adult_mortality_data.exposure_end - adult_mortality_data.exposure_start, 0
)
adult_mortality_data["weighted_exposure"] = (
    adult_mortality_data.weight * adult_mortality_data.exposure
)
adult_mortality_data
# Out:
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in maximum
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in minimum
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /mnt/share/homes/zmbc/src/vivarium_gates_lsff_by_wealth_quintile/.venv/lib/python3.11/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in maximum
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#          weight any_died  num_died wealth_quintile     sex age_at_death_unit  \
# 0      0.008939      yes       1.0          middle    male              year
# 1      0.008939      yes       1.0          middle    male            months
# 2      0.004495      yes       1.0          middle    male              year
# 3      0.004495      yes       2.0          fourth    male              year
# 4      0.004495      yes       2.0          fourth    male              year
# ...         ...      ...       ...             ...     ...               ...
# 74940  2.463153      yes       2.0          second  female              year
# 74941  2.270734      yes       1.0          middle  female              year
# 74942  2.270734      yes       1.0          middle    male              year
# 74943  2.270734      yes       1.0          middle    male            months
# 74944  2.270734      yes       1.0          second  female              year
#
#       age_at_death month_of_death year_of_death death_violence_or_accident  \
# 0             51.0          april        2015.0                         no
# 1             56.0          april        2015.0                        yes
# 2             45.0         august        2014.0                         no
# 3             35.0            may        2014.0                         no
# 4             40.0         august        2014.0                         no
# ...            ...            ...           ...                        ...
# 74940         21.0      september        2013.0                        yes
# 74941         80.0       november        2014.0                         no
# 74942         50.0        january        2015.0                         no
# 74943         45.0        january        2012.0                        yes
# 74944         90.0        january        2012.0                         no
#
#       death_during_pregnancy_or_childbirth age_at_death_years  adult_death  \
# 0                                      NaN               51.0        False
# 1                                      NaN           4.666667        False
# 2                                      NaN               45.0         True
# 3                                      NaN               35.0         True
# 4                                      NaN               40.0         True
# ...                                    ...                ...          ...
# 74940                                  NaN               21.0         True
# 74941                                   no               80.0        False
# 74942                                  NaN               50.0        False
# 74943                                  NaN               3.75        False
# 74944                                   no               90.0        False
#
#        date_of_death date_of_birth exposure_start exposure_end  exposure  \
# 0        2015.291667   1964.291667         2011.0  2014.291667  3.291667
# 1        2015.291667      2010.625       2025.625  2015.291667         0
# 2        2014.625000      1969.625         2011.0     2014.625     3.625
# 3        2014.375000      1979.375         2011.0     2014.375     3.375
# 4        2014.625000      1974.625         2011.0     2014.625     3.625
# ...              ...           ...            ...          ...       ...
# 74940    2013.708333   1992.708333         2011.0  2013.708333  2.708333
# 74941    2014.875000      1934.875         2011.0     1984.875         0
# 74942    2015.041667   1965.041667         2011.0  2015.041667  4.041667
# 74943    2012.041667   2008.291667    2023.291667  2012.041667         0
# 74944    2012.041667   1922.041667         2011.0  1972.041667         0
#
#       weighted_exposure
# 0              0.029424
# 1                   0.0
# 2              0.016294
# 3              0.015171
# 4              0.016294
# ...                 ...
# 74940          6.671039
# 74941               0.0
# 74942           9.17755
# 74943               0.0
# 74944               0.0
#
# [74945 rows x 19 columns]

# %%
living_exposure_data = hhm_data.copy()
living_exposure_data["date_of_birth"] = (
    (living_exposure_data.date_of_interview / 12) + 1900 - living_exposure_data.age
)
living_exposure_data["exposure_start"] = np.maximum(
    living_exposure_data.date_of_birth + 15, 2011.0
)
living_exposure_data["exposure_end"] = np.minimum(
    living_exposure_data.date_of_birth + 50,
    (living_exposure_data.date_of_interview / 12) + 1900,
)
living_exposure_data["exposure"] = np.maximum(
    living_exposure_data.exposure_end - living_exposure_data.exposure_start, 0
)
living_exposure_data["weighted_exposure"] = (
    living_exposure_data.weight * living_exposure_data.exposure
)
living_exposure_data
# Out:
#          cluster_number  household_number    weight  date_of_interview  \
# 0                 10001                 1  0.191072               1387
# 1                 10001                 1  0.191072               1387
# 2                 10001                 1  0.191072               1387
# 3                 10001                 1  0.191072               1387
# 4                 10001                 9  0.191072               1387
# ...                 ...               ...       ...                ...
# 2869038          360482                85  2.270734               1385
# 2869039          360482                85  2.270734               1385
# 2869040          360482                96  2.270734               1385
# 2869041          360482                96  2.270734               1385
# 2869042          360482                96  2.270734               1385
#
#          line_number        currently_pregnant   age     sex  \
# 0                  1                       NaN  51.0    Male
# 1                  2  not pregnant, don't know  46.0  Female
# 2                  3                       NaN  22.0    Male
# 3                  4  not pregnant, don't know  20.0  Female
# 4                  1  not pregnant, don't know  40.0  Female
# ...              ...                       ...   ...     ...
# 2869038            1                       NaN  60.0    Male
# 2869039            2                       NaN  50.0  Female
# 2869040            1                       NaN  66.0    Male
# 2869041            2  not pregnant, don't know  46.0  Female
# 2869042            3                       NaN  26.0    Male
#
#          index_to_household  age_hemoglobin  ... age_start  age_end  \
# 0                       NaN             NaN  ...      50.0    125.0
# 1                       2.0            46.0  ...      30.0     50.0
# 2                       NaN             NaN  ...      15.0     30.0
# 3                       4.0            20.0  ...      15.0     30.0
# 4                       1.0            40.0  ...      30.0     50.0
# ...                     ...             ...  ...       ...      ...
# 2869038                 NaN             NaN  ...      50.0    125.0
# 2869039                 NaN             NaN  ...      50.0    125.0
# 2869040                 NaN             NaN  ...      50.0    125.0
# 2869041                 2.0            46.0  ...      30.0     50.0
# 2869042                 NaN             NaN  ...      15.0     30.0
#
#          hemoglobin_raw hemoglobin_adjusted    anemia  date_of_birth  \
# 0                   NaN                 NaN       NaN    1964.583333
# 1                  81.0                81.0  moderate    1969.583333
# 2                   NaN                 NaN       NaN    1993.583333
# 3                 113.0               113.0      mild    1995.583333
# 4                 116.0               116.0      mild    1975.583333
# ...                 ...                 ...       ...            ...
# 2869038             NaN                 NaN       NaN    1955.416667
# 2869039             NaN                 NaN       NaN    1965.416667
# 2869040             NaN                 NaN       NaN    1949.416667
# 2869041           119.0               119.0      mild    1969.416667
# 2869042             NaN                 NaN       NaN    1989.416667
#
#         exposure_start exposure_end  exposure  weighted_exposure
# 0               2011.0  2014.583333  3.583333           0.684675
# 1               2011.0  2015.583333  4.583333           0.875747
# 2               2011.0  2015.583333  4.583333           0.875747
# 3               2011.0  2015.583333  4.583333           0.875747
# 4               2011.0  2015.583333  4.583333           0.875747
# ...                ...          ...       ...                ...
# 2869038         2011.0  2005.416667  0.000000           0.000000
# 2869039         2011.0  2015.416667  4.416667          10.029075
# 2869040         2011.0  1999.416667  0.000000           0.000000
# 2869041         2011.0  2015.416667  4.416667          10.029075
# 2869042         2011.0  2015.416667  4.416667          10.029075
#
# [2869043 rows x 28 columns]

# %%
(adult_mortality_data.adult_death * adult_mortality_data.weight).sum()
# Out:
# 11897.673413

# %%
adult_mortality_data.weighted_exposure.sum()
# Out:
# 42011.871167166595

# %%
((adult_mortality_data.adult_death * adult_mortality_data.weight).sum()) / (
    adult_mortality_data.weighted_exposure.sum()
    + living_exposure_data.weighted_exposure.sum()
)
# Out:
# 0.0017707888221588613

# %%
adult_mortality_data
# Out:
#          weight any_died  num_died wealth_quintile     sex age_at_death_unit  \
# 0      0.008939      yes       1.0          middle    male              year
# 1      0.008939      yes       1.0          middle    male            months
# 2      0.004495      yes       1.0          middle    male              year
# 3      0.004495      yes       2.0          fourth    male              year
# 4      0.004495      yes       2.0          fourth    male              year
# ...         ...      ...       ...             ...     ...               ...
# 74940  2.463153      yes       2.0          second  female              year
# 74941  2.270734      yes       1.0          middle  female              year
# 74942  2.270734      yes       1.0          middle    male              year
# 74943  2.270734      yes       1.0          middle    male            months
# 74944  2.270734      yes       1.0          second  female              year
#
#       age_at_death month_of_death year_of_death death_violence_or_accident  \
# 0             51.0          april        2015.0                         no
# 1             56.0          april        2015.0                        yes
# 2             45.0         august        2014.0                         no
# 3             35.0            may        2014.0                         no
# 4             40.0         august        2014.0                         no
# ...            ...            ...           ...                        ...
# 74940         21.0      september        2013.0                        yes
# 74941         80.0       november        2014.0                         no
# 74942         50.0        january        2015.0                         no
# 74943         45.0        january        2012.0                        yes
# 74944         90.0        january        2012.0                         no
#
#       death_during_pregnancy_or_childbirth age_at_death_years  adult_death  \
# 0                                      NaN               51.0        False
# 1                                      NaN           4.666667        False
# 2                                      NaN               45.0         True
# 3                                      NaN               35.0         True
# 4                                      NaN               40.0         True
# ...                                    ...                ...          ...
# 74940                                  NaN               21.0         True
# 74941                                   no               80.0        False
# 74942                                  NaN               50.0        False
# 74943                                  NaN               3.75        False
# 74944                                   no               90.0        False
#
#        date_of_death date_of_birth exposure_start exposure_end  exposure  \
# 0        2015.291667   1964.291667         2011.0  2014.291667  3.291667
# 1        2015.291667      2010.625       2025.625  2015.291667         0
# 2        2014.625000      1969.625         2011.0     2014.625     3.625
# 3        2014.375000      1979.375         2011.0     2014.375     3.375
# 4        2014.625000      1974.625         2011.0     2014.625     3.625
# ...              ...           ...            ...          ...       ...
# 74940    2013.708333   1992.708333         2011.0  2013.708333  2.708333
# 74941    2014.875000      1934.875         2011.0     1984.875         0
# 74942    2015.041667   1965.041667         2011.0  2015.041667  4.041667
# 74943    2012.041667   2008.291667    2023.291667  2012.041667         0
# 74944    2012.041667   1922.041667         2011.0  1972.041667         0
#
#       weighted_exposure
# 0              0.029424
# 1                   0.0
# 2              0.016294
# 3              0.015171
# 4              0.016294
# ...                 ...
# 74940          6.671039
# 74941               0.0
# 74942           9.17755
# 74943               0.0
# 74944               0.0
#
# [74945 rows x 19 columns]

# %%
adult_mortality_data["maternal_death"] = (
    adult_mortality_data.adult_death
    & (adult_mortality_data.death_during_pregnancy_or_childbirth == "yes")
    & (adult_mortality_data.death_violence_or_accident != "yes")
)

# %%
(adult_mortality_data.maternal_death * adult_mortality_data.weight).sum()
# Out:
# 405.651753

# %%
def maternal_mortality_rate(df):
    return ((df.maternal_death * df.weight).sum() * 1_000) / (
        df.weighted_exposure
    ).sum()

# %%
maternal_mortality_data = pd.concat(
    [
        adult_mortality_data[adult_mortality_data.sex == "female"][
            ["wealth_quintile", "maternal_death", "weight", "weighted_exposure"]
        ],
        living_exposure_data[living_exposure_data.sex == "female"][
            ["wealth_quintile", "weight", "weighted_exposure"]
        ].assign(maternal_death=False),
    ],
    ignore_index=True,
)

# %%
maternal_mortality_rate(maternal_mortality_data)
# Out:
# 24.949186747614135

# %%
maternal_mortality_rates = maternal_mortality_data.groupby("wealth_quintile").apply(
    maternal_mortality_rate
)
maternal_mortality_rates
# Out:
# wealth_quintile
# lowest     36.804365
# second     21.447157
# middle     27.064862
# fourth     21.697309
# highest    11.040954
# dtype: float64

# %% [markdown]
# #### General fertility rate

# %%
fertility_event_data = birth_data.copy()
fertility_event_data["birth_in_period"] = (
    (fertility_event_data.interview_date - fertility_event_data.birth_date) >= 1
) & ((fertility_event_data.interview_date - fertility_event_data.birth_date) <= 36)
fertility_event_data["weighted_birth_in_period"] = (
    fertility_event_data.birth_in_period * fertility_event_data.weight
)

# %%
fertility_event_data.weighted_birth_in_period.sum()
# Out:
# 150433.10539200003

# %%
fertility_event_data.groupby("wealth_quintile").weighted_birth_in_period.sum()
# Out:
# wealth_quintile
# lowest     37315.912347
# second     33131.370611
# middle     30243.631415
# fourth     27530.819389
# highest    22211.371630
# Name: weighted_birth_in_period, dtype: float64

# %%
fertility_exposure_data = wra_data.copy()
fertility_exposure_data["exposure_start"] = np.maximum(
    fertility_exposure_data.date_of_birth + 12 * 15,
    fertility_exposure_data.interview_date - 36,
)  # aka lowlim
# aka upplim
fertility_exposure_data["exposure_end"] = np.minimum(
    fertility_exposure_data.interview_date - 1,
    fertility_exposure_data.date_of_birth + 12 * 45,
)
fertility_exposure_data["exposure"] = (
    (fertility_exposure_data.exposure_end - fertility_exposure_data.exposure_start) + 1
).clip(lower=0)
fertility_exposure_data["weighted_exposure"] = (
    fertility_exposure_data.exposure * fertility_exposure_data.weight
)

# %%
gfr_by_wealth = (
    fertility_event_data.groupby("wealth_quintile").weighted_birth_in_period.sum()
    * 1_000
    / (fertility_exposure_data.groupby("wealth_quintile").weighted_exposure.sum() / 12)
)
gfr_by_wealth
# Out:
# wealth_quintile
# lowest     114.405014
# second      91.556480
# middle      79.049536
# fourth      69.588896
# highest     56.835044
# dtype: float64

# %%
maternal_disorders_incidence_disparities = (
    (maternal_mortality_rates / gfr_by_wealth)
    .rename("value")
    .rename_axis("wealth_quintile")
    .reset_index()
)
maternal_disorders_incidence_disparities.insert(0, "sex", "Female")
maternal_disorders_incidence_disparities
# Out:
#       sex wealth_quintile     value
# 0  Female          lowest  0.321702
# 1  Female          second  0.234251
# 2  Female          middle  0.342379
# 3  Female          fourth  0.311793
# 4  Female         highest  0.194263

# %%
maternal_disorders_incidence_disparities.to_csv(
    f"{results_dir}/maternal_disorders_incidence_disparities/india.csv",
    index=False,
)
