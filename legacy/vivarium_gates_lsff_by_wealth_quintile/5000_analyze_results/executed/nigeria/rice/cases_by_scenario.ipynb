# %%
import pandas as pd
import vivarium_inputs
import gbd_mapping
import pathlib
from lsff_utils import config_utils
from lsff_utils.results import expand_to_all_scenarios, aggregate_by_scenario
# Out:
# Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# Cache Dir: '/share/scratch/users/zmbc/cache'

# %%
location = "india"
vehicle = "rice"

# %%
# Parameters
location = "nigeria"
vehicle = "rice"

# %%
scenarios = list(
    config_utils.get_location_fortificant_vehicle_intervention_scenarios()
    .pipe(lambda df: df[(df.location == location) & (df.vehicle == vehicle)])
    .intervention_scenario.unique()
) + ["zero", "baseline"]
scenarios
# Out:
# ['intervention', 'zero', 'baseline']

# %%
path = f"results/rescaled_pregnancy_results/{vehicle}/{location}/person_time_anemia.parquet"
if pathlib.Path(path).is_file():
    pregnancy_person_time_anemia = pd.read_parquet(path)
else:
    pregnancy_person_time_anemia = expand_to_all_scenarios(
        pd.read_parquet(
            f"results/rescaled_pregnancy_results/rice/india/person_time_anemia.parquet"
        ).assign(value=0),
        scenarios,
    )
pregnancy_person_time_anemia
# Out:
#              measure entity_type  entity  sub_entity age_group  \
# 0        person_time  impairment  anemia  not_anemic  10_to_14
# 1        person_time  impairment  anemia  not_anemic  10_to_14
# 2        person_time  impairment  anemia  not_anemic  10_to_14
# 3        person_time  impairment  anemia  not_anemic  10_to_14
# 4        person_time  impairment  anemia  not_anemic  10_to_14
# ...              ...         ...     ...         ...       ...
# 1079995  person_time  impairment  anemia      severe   95_plus
# 1079996  person_time  impairment  anemia      severe   95_plus
# 1079997  person_time  impairment  anemia      severe   95_plus
# 1079998  person_time  impairment  anemia      severe   95_plus
# 1079999  person_time  impairment  anemia      severe   95_plus
#
#         anemia_status_at_birth  wealth_quintile  scenario  random_seed  \
# 0                      invalid                1      zero           82
# 1                      invalid                2      zero           82
# 2                      invalid                3      zero           82
# 3                      invalid                4      zero           82
# 4                      invalid                5      zero           82
# ...                        ...              ...       ...          ...
# 1079995                 severe                1  baseline           63
# 1079996                 severe                2  baseline           63
# 1079997                 severe                3  baseline           63
# 1079998                 severe                4  baseline           63
# 1079999                 severe                5  baseline           63
#
#          input_draw      value
# 0                 0   4.573202
# 1                 0  13.191147
# 2                 0  10.914709
# 3                 0   6.422808
# 4                 0   7.418750
# ...             ...        ...
# 1079995           0   0.000000
# 1079996           0   0.000000
# 1079997           0   0.000000
# 1079998           0   0.000000
# 1079999           0   0.000000
#
# [1080000 rows x 11 columns]

# %%
pregnancy_person_time_anemia.groupby("scenario").random_seed.nunique()
# Out:
# scenario
# baseline        200
# intervention    200
# zero            200
# Name: random_seed, dtype: int64

# %%
pregnancy_person_time_anemia.sub_entity.value_counts()
# Out:
# mild          270000
# moderate      270000
# not_anemic    270000
# severe        270000
# Name: sub_entity, dtype: int64

# %%
total_pregnant_person_time = aggregate_by_scenario(pregnancy_person_time_anemia)
total_pregnant_person_time
# Out:
# scenario      wealth_quintile
# baseline      1                  1.978799e+06
#               2                  2.046830e+06
#               3                  1.728272e+06
#               4                  1.407012e+06
#               5                  1.236648e+06
# intervention  1                  1.978803e+06
#               2                  2.046833e+06
#               3                  1.728277e+06
#               4                  1.407017e+06
#               5                  1.236653e+06
# zero          1                  1.978799e+06
#               2                  2.046830e+06
#               3                  1.728272e+06
#               4                  1.407012e+06
#               5                  1.236648e+06
# Name: value, dtype: float64

# %%
anemic_pregnant_person_time = aggregate_by_scenario(
    pregnancy_person_time_anemia[
        pregnancy_person_time_anemia.sub_entity != "not_anemic"
    ]
)
anemic_pregnant_person_time
# Out:
# scenario      wealth_quintile
# baseline      1                  1.169456e+06
#               2                  1.246315e+06
#               3                  9.534308e+05
#               4                  6.719241e+05
#               5                  5.540904e+05
# intervention  1                  1.156350e+06
#               2                  1.227594e+06
#               3                  9.329305e+05
#               4                  6.542476e+05
#               5                  5.367359e+05
# zero          1                  1.169456e+06
#               2                  1.246315e+06
#               3                  9.534308e+05
#               4                  6.719241e+05
#               5                  5.540904e+05
# Name: value, dtype: float64

# %%
pregnant_anemia_prevalence_by_scenario = (
    anemic_pregnant_person_time / total_pregnant_person_time
).fillna(0)
pregnant_anemia_prevalence_by_scenario
# Out:
# scenario      wealth_quintile
# baseline      1                  0.590993
#               2                  0.608900
#               3                  0.551667
#               4                  0.477554
#               5                  0.448058
# intervention  1                  0.584369
#               2                  0.599753
#               3                  0.539804
#               4                  0.464989
#               5                  0.434023
# zero          1                  0.590993
#               2                  0.608900
#               3                  0.551667
#               4                  0.477554
#               5                  0.448058
# Name: value, dtype: float64

# %%
path = f"./results/{location}/{vehicle}/pregnant_anemia_prevalence_by_scenario.csv"
pathlib.Path(path).parent.mkdir(exist_ok=True, parents=True)
pregnant_anemia_prevalence_by_scenario.to_csv(path)

# %%
pop = pd.read_csv(f"../0100_data_prep/results/population/stratified/{location}.csv")
pop
# Out:
#         sex  age_start     age_end      pregnant  wealth_quintile  \
# 0    Female        0.0    0.019178  not_pregnant                1
# 1    Female        0.0    0.019178  not_pregnant                2
# 2    Female        0.0    0.019178  not_pregnant                3
# 3    Female        0.0    0.019178  not_pregnant                4
# 4    Female        0.0    0.019178  not_pregnant                5
# ..      ...        ...         ...           ...              ...
# 280    Male       95.0  125.000000  not_pregnant                1
# 281    Male       95.0  125.000000  not_pregnant                2
# 282    Male       95.0  125.000000  not_pregnant                3
# 283    Male       95.0  125.000000  not_pregnant                4
# 284    Male       95.0  125.000000  not_pregnant                5
#
#             value
# 0    16960.496219
# 1    16890.884668
# 2    15946.960379
# 3    14017.956071
# 4    13029.810174
# ..            ...
# 280   1846.968043
# 281   1616.329970
# 282   1661.447043
# 283   1779.062429
# 284   1896.973078
#
# [285 rows x 6 columns]

# %%
pregnant_pop = pop[pop.pregnant == "pregnant"].groupby(["wealth_quintile"]).value.sum()
pregnant_pop
# Out:
# wealth_quintile
# 1    1.770625e+06
# 2    1.831699e+06
# 3    1.543670e+06
# 4    1.255512e+06
# 5    1.103242e+06
# Name: value, dtype: float64

# %%
pregnancy_prevalent_anemia_cases_by_scenario = (
    pregnant_anemia_prevalence_by_scenario * pregnant_pop
)
pregnancy_prevalent_anemia_cases_by_scenario
# Out:
# scenario      wealth_quintile
# baseline      1                  1.046426e+06
#               2                  1.115322e+06
#               3                  8.515916e+05
#               4                  5.995745e+05
#               5                  4.943167e+05
# intervention  1                  1.034698e+06
#               2                  1.098567e+06
#               3                  8.332788e+05
#               4                  5.837992e+05
#               5                  4.788325e+05
# zero          1                  1.046426e+06
#               2                  1.115322e+06
#               3                  8.515916e+05
#               4                  5.995745e+05
#               5                  4.943167e+05
# Name: value, dtype: float64

# %%
path = f"results/rescaled_pregnancy_results/{vehicle}/{location}/transition_count_maternal_disorders.parquet"
if pathlib.Path(path).is_file():
    maternal_disorders_transition_counts = pd.read_parquet(path)
else:
    maternal_disorders_transition_counts = expand_to_all_scenarios(
        pd.read_parquet(
            f"results/rescaled_pregnancy_results/rice/india/transition_count_maternal_disorders.parquet"
        ).assign(value=0),
        scenarios,
    )

maternal_disorders_transition_counts
# Out:
#                  measure entity_type              entity  \
# 0       transition_count       cause  maternal_disorders
# 1       transition_count       cause  maternal_disorders
# 2       transition_count       cause  maternal_disorders
# 3       transition_count       cause  maternal_disorders
# 4       transition_count       cause  maternal_disorders
# ...                  ...         ...                 ...
# 539995  transition_count       cause  maternal_disorders
# 539996  transition_count       cause  maternal_disorders
# 539997  transition_count       cause  maternal_disorders
# 539998  transition_count       cause  maternal_disorders
# 539999  transition_count       cause  maternal_disorders
#
#                                                sub_entity age_group  \
# 0       susceptible_to_maternal_disorders_to_maternal_...  10_to_14
# 1       susceptible_to_maternal_disorders_to_maternal_...  10_to_14
# 2       susceptible_to_maternal_disorders_to_maternal_...  10_to_14
# 3       susceptible_to_maternal_disorders_to_maternal_...  10_to_14
# 4       susceptible_to_maternal_disorders_to_maternal_...  10_to_14
# ...                                                   ...       ...
# 539995  maternal_disorders_to_recovered_from_maternal_...   95_plus
# 539996  maternal_disorders_to_recovered_from_maternal_...   95_plus
# 539997  maternal_disorders_to_recovered_from_maternal_...   95_plus
# 539998  maternal_disorders_to_recovered_from_maternal_...   95_plus
# 539999  maternal_disorders_to_recovered_from_maternal_...   95_plus
#
#        anemia_status_at_birth  wealth_quintile  scenario  random_seed  \
# 0                     invalid                1      zero           82
# 1                     invalid                2      zero           82
# 2                     invalid                3      zero           82
# 3                     invalid                4      zero           82
# 4                     invalid                5      zero           82
# ...                       ...              ...       ...          ...
# 539995                 severe                1  baseline           63
# 539996                 severe                2  baseline           63
# 539997                 severe                3  baseline           63
# 539998                 severe                4  baseline           63
# 539999                 severe                5  baseline           63
#
#         input_draw  value
# 0                0    0.0
# 1                0    0.0
# 2                0    0.0
# 3                0    0.0
# 4                0    0.0
# ...            ...    ...
# 539995           0    0.0
# 539996           0    0.0
# 539997           0    0.0
# 539998           0    0.0
# 539999           0    0.0
#
# [540000 rows x 11 columns]

# %%
maternal_disorders_transition_counts.sub_entity.cat.categories
# Out:
# Index(['maternal_disorders_to_recovered_from_maternal_disorders',
#        'no_transition',
#        'susceptible_to_maternal_disorders_to_maternal_disorders'],
#       dtype='object')

# %%
maternal_disorders_incident_cases_by_scenario = aggregate_by_scenario(
    maternal_disorders_transition_counts[
        maternal_disorders_transition_counts.sub_entity
        == "susceptible_to_maternal_disorders_to_maternal_disorders"
    ]
)
maternal_disorders_incident_cases_by_scenario
# Out:
# scenario      wealth_quintile
# baseline      1                  1.959206e+06
#               2                  2.033978e+06
#               3                  1.664124e+06
#               4                  1.291512e+06
#               5                  1.133183e+06
# intervention  1                  1.953193e+06
#               2                  2.025345e+06
#               3                  1.654845e+06
#               4                  1.283440e+06
#               5                  1.125424e+06
# zero          1                  1.959206e+06
#               2                  2.033978e+06
#               3                  1.664124e+06
#               4                  1.291512e+06
#               5                  1.133183e+06
# Name: value, dtype: float64

# %%
path = (
    f"./results/{location}/{vehicle}/maternal_disorders_incident_cases_by_scenario.csv"
)
pathlib.Path(path).parent.mkdir(exist_ok=True, parents=True)
maternal_disorders_incident_cases_by_scenario.to_csv(path)

# %%
path = f"results/rescaled_child_results/{vehicle}/{location}/deaths.parquet"
if pathlib.Path(path).is_file():
    neonatal_deaths = pd.read_parquet(path).rename(
        columns={"maternal_scenario": "scenario"}
    )
else:
    neonatal_deaths = expand_to_all_scenarios(
        pd.read_parquet(f"results/rescaled_child_results/rice/india/deaths.parquet")
        .assign(value=0)
        .rename(columns={"maternal_scenario": "scenario"}),
        scenarios,
    )

neonatal_deaths
# Out:
#       measure entity_type        entity    sub_entity        age_group  \
# 0      deaths       cause     stillborn     stillborn    0_to_6_months
# 1      deaths       cause     stillborn     stillborn    0_to_6_months
# 2      deaths       cause     stillborn     stillborn    0_to_6_months
# 3      deaths       cause     stillborn     stillborn    0_to_6_months
# 4      deaths       cause     stillborn     stillborn    0_to_6_months
# ...       ...         ...           ...           ...              ...
# 47995  deaths       cause  other_causes  other_causes  18_to_59_months
# 47996  deaths       cause  other_causes  other_causes  18_to_59_months
# 47997  deaths       cause  other_causes  other_causes  18_to_59_months
# 47998  deaths       cause  other_causes  other_causes  18_to_59_months
# 47999  deaths       cause  other_causes  other_causes  18_to_59_months
#
#           sex  wealth_quintile child_scenario  scenario  random_seed  \
# 0      Female                1       baseline  baseline           24
# 1      Female                2       baseline  baseline           24
# 2      Female                3       baseline  baseline           24
# 3      Female                4       baseline  baseline           24
# 4      Female                5       baseline  baseline           24
# ...       ...              ...            ...       ...          ...
# 47995    Male                1       baseline  baseline            4
# 47996    Male                2       baseline  baseline            4
# 47997    Male                3       baseline  baseline            4
# 47998    Male                4       baseline  baseline            4
# 47999    Male                5       baseline  baseline            4
#
#        input_draw       value
# 0               0    0.000000
# 1               0    0.000000
# 2               0    0.000000
# 3               0    0.000000
# 4               0    0.000000
# ...           ...         ...
# 47995           0  139.933614
# 47996           0  181.277636
# 47997           0  139.933614
# 47998           0   98.589592
# 47999           0   90.108766
#
# [48000 rows x 12 columns]

# %%
neonatal_deaths_by_scenario = aggregate_by_scenario(neonatal_deaths)
neonatal_deaths_by_scenario
# Out:
# scenario      wealth_quintile
# baseline      1                  205054.689281
#               2                  207305.288236
#               3                  172634.615209
#               4                  138538.518081
#               5                  120916.423670
# intervention  1                  205043.028146
#               2                  207286.206380
#               3                  172614.473250
#               4                  138530.037256
#               5                  120889.921092
# zero          1                  205054.689281
#               2                  207305.288236
#               3                  172634.615209
#               4                  138538.518081
#               5                  120916.423670
# Name: value, dtype: float64

# %%
path = f"./results/{location}/{vehicle}/neonatal_deaths_by_scenario.csv"
pathlib.Path(path).parent.mkdir(exist_ok=True, parents=True)
neonatal_deaths_by_scenario.to_csv(path)

# %%
path = f"../0400_non_pregnant_anemia_model/results/{vehicle}/{location}/anemia_cases.parquet"
if pathlib.Path(path).is_file():
    non_pregnancy_anemia_cases = pd.read_parquet(path)
else:
    non_pregnancy_anemia_cases = expand_to_all_scenarios(
        pd.read_parquet(
            f"../0400_non_pregnant_anemia_model/results/rice/india/anemia_cases.parquet"
        ).assign(value=0),
        scenarios,
    )

non_pregnancy_anemia_cases
# Out:
#         sex  age_start     age_end  wealth_quintile         value  \
# 0    Female        0.0    0.019178                1  15276.458404
# 1    Female        0.0    0.019178                2  14808.048479
# 2    Female        0.0    0.019178                3  13328.773023
# 3    Female        0.0    0.019178                4  11611.609394
# 4    Female        0.0    0.019178                5   9753.105130
# ..      ...        ...         ...              ...           ...
# 745    Male       95.0  125.000000                1   1677.509876
# 746    Male       95.0  125.000000                2   1448.477068
# 747    Male       95.0  125.000000                3   1473.456386
# 748    Male       95.0  125.000000                4   1577.945920
# 749    Male       95.0  125.000000                5   1659.565678
#
#          scenario
# 0            zero
# 1            zero
# 2            zero
# 3            zero
# 4            zero
# ..            ...
# 745  intervention
# 746  intervention
# 747  intervention
# 748  intervention
# 749  intervention
#
# [750 rows x 6 columns]

# %%
non_pregnancy_prevalent_anemia_cases_by_scenario = aggregate_by_scenario(
    non_pregnancy_anemia_cases.assign(entity="anemia", input_draw="draw_0")
)
non_pregnancy_prevalent_anemia_cases_by_scenario
# Out:
# scenario      wealth_quintile
# baseline      1                  2.465356e+07
#               2                  2.220715e+07
#               3                  2.031122e+07
#               4                  1.963280e+07
#               5                  1.575827e+07
# intervention  1                  2.443802e+07
#               2                  2.191646e+07
#               3                  1.996016e+07
#               4                  1.921805e+07
#               5                  1.534112e+07
# zero          1                  2.465356e+07
#               2                  2.220715e+07
#               3                  2.031122e+07
#               4                  1.963280e+07
#               5                  1.575827e+07
# Name: value, dtype: float64

# %%
prevalent_anemia_cases_by_scenario = (
    pregnancy_prevalent_anemia_cases_by_scenario
    + non_pregnancy_prevalent_anemia_cases_by_scenario
)
prevalent_anemia_cases_by_scenario
# Out:
# scenario      wealth_quintile
# baseline      1                  2.569999e+07
#               2                  2.332247e+07
#               3                  2.116281e+07
#               4                  2.023238e+07
#               5                  1.625258e+07
# intervention  1                  2.547271e+07
#               2                  2.301503e+07
#               3                  2.079344e+07
#               4                  1.980185e+07
#               5                  1.581995e+07
# zero          1                  2.569999e+07
#               2                  2.332247e+07
#               3                  2.116281e+07
#               4                  2.023238e+07
#               5                  1.625258e+07
# Name: value, dtype: float64

# %%
path = f"./results/{location}/{vehicle}/prevalent_anemia_cases_by_scenario.csv"
pathlib.Path(path).parent.mkdir(exist_ok=True, parents=True)
prevalent_anemia_cases_by_scenario.to_csv(path)

# %%
path = f"../0500_neural_tube_defects_model/results/{location}/{vehicle}/ntd_cases_by_scenario.csv"
if pathlib.Path(path).is_file():
    ntd_cases_by_scenario = pd.read_csv(path)
else:
    ntd_cases_by_scenario = expand_to_all_scenarios(
        pd.read_csv(
            f"../0500_neural_tube_defects_model/results/india/rice/ntd_cases_by_scenario.csv"
        ).assign(value=0),
        scenarios,
    )

ntd_cases_by_scenario = ntd_cases_by_scenario.set_index(
    ["scenario", "wealth_quintile"]
).value
ntd_cases_by_scenario
# Out:
# scenario      wealth_quintile
# zero          1                  4597.757468
#               2                  4701.493178
#               3                  4256.145042
#               4                  3772.641242
#               5                  3313.580913
# baseline      1                  4597.757468
#               2                  4701.493178
#               3                  4256.145042
#               4                  3772.641242
#               5                  3313.580913
# intervention  1                  4405.329397
#               2                  4329.628688
#               3                  3790.873761
#               4                  3226.926628
#               5                  2782.450283
# Name: value, dtype: float64

# %%
path = f"./results/{location}/{vehicle}/ntd_cases_by_scenario.csv"
pathlib.Path(path).parent.mkdir(exist_ok=True, parents=True)
ntd_cases_by_scenario.to_csv(path)
