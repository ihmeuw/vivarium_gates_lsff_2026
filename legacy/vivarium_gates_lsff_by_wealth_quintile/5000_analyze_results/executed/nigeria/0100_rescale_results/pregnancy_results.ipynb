# %%
import pandas as pd, numpy as np
import vivarium_inputs
import gbd_mapping
import pathlib
# Out:
# Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# Cache Dir: '/share/scratch/users/zmbc/cache'

# %%
location = "India"

# %%
# Parameters
location = "nigeria"

# %%
location = location.title()

# %%
pop = vivarium_inputs.get_population_structure(location).value
pop[pop > 0]
# Out:
# location  sex     age_start  age_end     year_start  year_end
# Nigeria   Female  0.000000   0.019178    2021        2022        7.684611e+04
#                   0.019178   0.076712    2021        2022        2.268013e+05
#                   0.076712   0.500000    2021        2022        1.653024e+06
#                   0.500000   1.000000    2021        2022        1.904590e+06
#                   1.000000   2.000000    2021        2022        3.736238e+06
#                   2.000000   5.000000    2021        2022        1.079625e+07
#                   5.000000   10.000000   2021        2022        1.693204e+07
#                   10.000000  15.000000   2021        2022        1.577085e+07
#                   15.000000  20.000000   2021        2022        1.379964e+07
#                   20.000000  25.000000   2021        2022        1.128166e+07
#                   25.000000  30.000000   2021        2022        9.287220e+06
# ...

# %%
asfr = vivarium_inputs.get_measure(gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location).value
asfr[asfr > 0]
# Out:
# location  sex     age_start  age_end  year_start  year_end  parameter
# Nigeria   Female  10.0       15.0     2021        2022      lower_value    0.001521
#                                                             mean_value     0.003104
#                                                             upper_value    0.006026
#                   15.0       20.0     2021        2022      lower_value    0.067972
#                                                             mean_value     0.077594
#                                                             upper_value    0.088759
#                   20.0       25.0     2021        2022      lower_value    0.181182
#                                                             mean_value     0.202959
#                                                             upper_value    0.223959
#                   25.0       30.0     2021        2022      lower_value    0.208116
# ...

# %%
asfr = asfr[asfr.index.get_level_values("parameter") == "mean_value"].droplevel("parameter")
asfr
# Out:
# location  sex     age_start  age_end     year_start  year_end
# Nigeria   Female  0.000000   0.019178    2021        2022        0.000000
#                   0.019178   0.076712    2021        2022        0.000000
#                   0.076712   0.500000    2021        2022        0.000000
#                   0.500000   1.000000    2021        2022        0.000000
#                   1.000000   2.000000    2021        2022        0.000000
#                   2.000000   5.000000    2021        2022        0.000000
#                   5.000000   10.000000   2021        2022        0.000000
#                   10.000000  15.000000   2021        2022        0.003104
#                   15.000000  20.000000   2021        2022        0.077594
#                   20.000000  25.000000   2021        2022        0.202959
#                   25.000000  30.000000   2021        2022        0.221416
#                   30.000000  35.000000   2021        2022        0.202088
# ...

# %%
sbr = vivarium_inputs.get_measure(gbd_mapping.covariates.stillbirth_to_live_birth_ratio, "estimate", location).value
sbr[sbr > 0]
# Out:
# location  year_start  year_end  parameter
# Nigeria   2021        2022      lower_value    0.038684
#                                 mean_value     0.038684
#                                 upper_value    0.038684
# Name: value, dtype: float64

# %%
sbr = sbr.iloc[0]
sbr
# Out:
# 0.0386836060874489

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location,
).mean(axis=1)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# 2024-07-31 18:58:47.870 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-07-31 18:58:47.875 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-07-31 18:58:47.876 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# 2024-07-31 18:58:47.991 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-07-31 18:58:47.996 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-07-31 18:58:47.997 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# ...

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy,
    "incidence_rate",
    location,
).mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# 2024-07-31 18:58:48.405 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-07-31 18:58:48.409 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-07-31 18:58:48.410 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# 2024-07-31 18:58:48.521 | WARNING  | vivarium_inputs.validation.raw:check_columns:2004 - Data returned extra columns: {'version_id'}.
# 2024-07-31 18:58:48.525 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2125 - Data contains additional age groups beyond those specified by restriction range.
# 2024-07-31 18:58:48.526 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2183 - Data is missing the following expected sex ids: {1}.
# ...

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# location  sex     age_start  age_end  year_start  year_end
# Nigeria   Female  10.0       15.0     2021        2022        0.003561
#                   15.0       20.0     2021        2022        0.101503
#                   20.0       25.0     2021        2022        0.254425
#                   25.0       30.0     2021        2022        0.279048
#                   30.0       35.0     2021        2022        0.258736
#                   35.0       40.0     2021        2022        0.175028
#                   40.0       45.0     2021        2022        0.092716
#                   45.0       50.0     2021        2022        0.042148
#                   50.0       55.0     2021        2022        0.004797
# dtype: float64

# %%
pregnancies = (pop * pregnancy_incidence)
pregnancies[pregnancies > 0]
# Out:
# location  sex     age_start  age_end  year_start  year_end
# Nigeria   Female  10.0       15.0     2021        2022        5.616702e+04
#                   15.0       20.0     2021        2022        1.400708e+06
#                   20.0       25.0     2021        2022        2.870330e+06
#                   25.0       30.0     2021        2022        2.591577e+06
#                   30.0       35.0     2021        2022        1.933037e+06
#                   35.0       40.0     2021        2022        1.082587e+06
#                   40.0       45.0     2021        2022        4.720416e+05
#                   45.0       50.0     2021        2022        1.814322e+05
#                   50.0       55.0     2021        2022        1.759300e+04
# dtype: float64

# %%
total_pregnancies = pregnancies.sum()
total_pregnancies
# Out:
# 10605473.348507233

# %%
sim_population = pd.read_parquet(f"../../0200_pregnancy_sim/sim_results/{location.lower()}/pregnancy_outcome_count.parquet").groupby("input_draw").value.sum().mean()
sim_population
# Out:
# 4000000.0

# %%
scalar = total_pregnancies / sim_population
scalar
# Out:
# 2.6513683371268084

# %%
for result in ["ylds", "ylls", "pregnancy_outcome_count"]:
    df = pd.read_parquet(f"../../0200_pregnancy_sim/sim_results/{location.lower()}/{result}.parquet")
    df.value *= scalar
    path = pathlib.Path(f'./pregnancy_results/{location.lower()}/{result}.parquet')
    path.parent.mkdir(exist_ok=True, parents=True)
    df.to_parquet(path)
