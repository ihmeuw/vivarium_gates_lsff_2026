# %%
import pandas as pd
import vivarium_inputs
import gbd_mapping
# Out:
# Config: 'input_data:
#     cache_data:
#         base: True
#     intermediary_data_cache_path:
#         base: /share/scratch/users/{username}/cache'
# Cache Dir: '/share/scratch/users/zmbc/cache'

# %%
location = "india"
vehicle = "rice" # TODO: Check!
scenario = "intervention"

# %%
# Parameters
location = "nigeria"
vehicle = "bouillon"
scenario = "intervention"

# %%
def aggregate_by_scenario(df):
    return df.groupby(["scenario", "input_draw", "wealth_quintile"]).value.sum().groupby(["scenario", "wealth_quintile"]).mean()

# %%
pregnancy_ylls = (
    pd.read_parquet(f"0100_rescale_results/pregnancy_results/{location}/ylls.parquet")
)
pregnancy_ylls
# Out:
#        measure entity_type              entity          sub_entity age_group  \
# 0         ylls       cause  maternal_disorders  maternal_disorders  10_to_14
# 1         ylls       cause        other_causes        other_causes  10_to_14
# 2         ylls       cause  maternal_disorders  maternal_disorders  10_to_14
# 3         ylls       cause        other_causes        other_causes  10_to_14
# 4         ylls       cause  maternal_disorders  maternal_disorders  10_to_14
# ...        ...         ...                 ...                 ...       ...
# 179995    ylls       cause        other_causes        other_causes   95_plus
# 179996    ylls       cause  maternal_disorders  maternal_disorders   95_plus
# 179997    ylls       cause        other_causes        other_causes   95_plus
# 179998    ylls       cause  maternal_disorders  maternal_disorders   95_plus
# 179999    ylls       cause        other_causes        other_causes   95_plus
#
#        anemia_status_at_birth wealth_quintile      scenario  random_seed  \
# 0                     invalid          lowest      baseline           32
# 1                     invalid          lowest      baseline           32
# 2                     invalid          second      baseline           32
# 3                     invalid          second      baseline           32
# 4                     invalid          middle      baseline           32
# ...                       ...             ...           ...          ...
# 179995                 severe          middle  intervention           60
# 179996                 severe          fourth  intervention           60
# 179997                 severe          fourth  intervention           60
# 179998                 severe         highest  intervention           60
# 179999                 severe         highest  intervention           60
#
#         input_draw  value
# 0                0    0.0
# 1                0    0.0
# 2                0    0.0
# 3                0    0.0
# 4                0    0.0
# ...            ...    ...
# 179995           0    0.0
# 179996           0    0.0
# 179997           0    0.0
# 179998           0    0.0
# 179999           0    0.0
#
# [180000 rows x 11 columns]

# %%
pregnancy_ylls.groupby("scenario").random_seed.nunique()
# Out:
# scenario
# baseline        100
# intervention    100
# Name: random_seed, dtype: int64

# %%
pregnancy_ylls_by_scenario = aggregate_by_scenario(pregnancy_ylls)
pregnancy_ylls_by_scenario
# Out:
# scenario      wealth_quintile
# baseline      fourth             159369.249825
#               highest            146485.741855
#               lowest             243575.766544
#               middle             194939.256420
#               second             223397.331792
# intervention  fourth             157851.246655
#               highest            145759.042072
#               lowest             239998.354605
#               middle             193513.721170
#               second             220001.680398
# Name: value, dtype: float64

# %%
pregnancy_ylls_averted = pregnancy_ylls_by_scenario.loc["baseline"] - pregnancy_ylls_by_scenario.loc[scenario]
pregnancy_ylls_averted
# Out:
# wealth_quintile
# fourth     1518.003170
# highest     726.699783
# lowest     3577.411939
# middle     1425.535250
# second     3395.651394
# Name: value, dtype: float64

# %%
pregnancy_ylds = pd.read_parquet(f"0100_rescale_results/pregnancy_results/{location}/ylds.parquet")
pregnancy_ylds
# Out:
#        measure entity_type               entity           sub_entity  \
# 0         ylds       cause           all_causes           all_causes
# 1         ylds       cause            pregnancy             pregnant
# 2         ylds       cause            pregnancy          parturition
# 3         ylds       cause            pregnancy           postpartum
# 4         ylds       cause   maternal_disorders   maternal_disorders
# ...        ...         ...                  ...                  ...
# 629995    ylds       cause            pregnancy          parturition
# 629996    ylds       cause            pregnancy           postpartum
# 629997    ylds       cause   maternal_disorders   maternal_disorders
# 629998    ylds       cause  maternal_hemorrhage  maternal_hemorrhage
# 629999    ylds       cause               anemia               anemia
#
#        age_group anemia_status_at_birth wealth_quintile      scenario  \
# 0       10_to_14                invalid          lowest      baseline
# 1       10_to_14                invalid          lowest      baseline
# 2       10_to_14                invalid          lowest      baseline
# 3       10_to_14                invalid          lowest      baseline
# 4       10_to_14                invalid          lowest      baseline
# ...          ...                    ...             ...           ...
# 629995   95_plus                 severe         highest  intervention
# 629996   95_plus                 severe         highest  intervention
# 629997   95_plus                 severe         highest  intervention
# 629998   95_plus                 severe         highest  intervention
# 629999   95_plus                 severe         highest  intervention
#
#         random_seed  input_draw     value
# 0                32           0  1.897676
# 1                32           0  0.000000
# 2                32           0  0.000000
# 3                32           0  0.000000
# 4                32           0  0.000000
# ...             ...         ...       ...
# 629995           60           0  0.000000
# 629996           60           0  0.000000
# 629997           60           0  0.000000
# 629998           60           0  0.000000
# 629999           60           0  0.000000
#
# [630000 rows x 11 columns]

# %%
pregnancy_ylds_by_scenario = aggregate_by_scenario(pregnancy_ylds)
pregnancy_ylds_by_scenario
# Out:
# scenario      wealth_quintile
# baseline      fourth             21034.559554
#               highest            15670.373751
#               lowest             36974.336987
#               middle             29964.217497
#               second             42958.465616
# intervention  fourth             20176.206435
#               highest            15094.625825
#               lowest             34780.402893
#               middle             28556.473265
#               second             40690.523208
# Name: value, dtype: float64

# %%
pregnancy_ylds_averted = pregnancy_ylds_by_scenario.loc["baseline"] - pregnancy_ylds_by_scenario.loc[scenario]
pregnancy_ylds_averted
# Out:
# wealth_quintile
# fourth      858.353120
# highest     575.747926
# lowest     2193.934094
# middle     1407.744232
# second     2267.942408
# Name: value, dtype: float64

# %%
pregnancy_dalys_averted = pregnancy_ylls_averted + pregnancy_ylds_averted
pregnancy_dalys_averted
# Out:
# wealth_quintile
# fourth     2376.356290
# highest    1302.447709
# lowest     5771.346033
# middle     2833.279482
# second     5663.593802
# Name: value, dtype: float64

# %%
assert len(pd.read_parquet(f"0100_rescale_results/child_results/{location}/ylds.parquet")) == 0

# %%
child_ylls = pd.read_parquet(f"0100_rescale_results/child_results/{location}/ylls.parquet").rename(columns={"maternal_scenario": "scenario"})
child_ylls
# Out:
#       measure entity_type        entity    sub_entity        age_group  \
# 0        ylls       cause     stillborn     stillborn    0_to_6_months
# 1        ylls       cause     stillborn     stillborn    0_to_6_months
# 2        ylls       cause     stillborn     stillborn    0_to_6_months
# 3        ylls       cause     stillborn     stillborn    0_to_6_months
# 4        ylls       cause     stillborn     stillborn    0_to_6_months
# ...       ...         ...           ...           ...              ...
# 15995    ylls       cause  other_causes  other_causes  18_to_59_months
# 15996    ylls       cause  other_causes  other_causes  18_to_59_months
# 15997    ylls       cause  other_causes  other_causes  18_to_59_months
# 15998    ylls       cause  other_causes  other_causes  18_to_59_months
# 15999    ylls       cause  other_causes  other_causes  18_to_59_months
#
#           sex wealth_quintile child_scenario      scenario  random_seed  \
# 0      Female          lowest       baseline  intervention           70
# 1      Female          second       baseline  intervention           70
# 2      Female          middle       baseline  intervention           70
# 3      Female          fourth       baseline  intervention           70
# 4      Female         highest       baseline  intervention           70
# ...       ...             ...            ...           ...          ...
# 15995    Male          lowest       baseline      baseline           17
# 15996    Male          second       baseline      baseline           17
# 15997    Male          middle       baseline      baseline           17
# 15998    Male          fourth       baseline      baseline           17
# 15999    Male         highest       baseline      baseline           17
#
#        input_draw          value
# 0               0       0.000000
# 1               0       0.000000
# 2               0       0.000000
# 3               0       0.000000
# 4               0       0.000000
# ...           ...            ...
# 15995           0  123371.091153
# 15996           0  127507.236963
# 15997           0   94708.895448
# 15998           0   90392.920045
# 15999           0   57785.435505
#
# [16000 rows x 12 columns]

# %%
child_ylls_by_scenario = aggregate_by_scenario(child_ylls)
child_ylls_by_scenario
# Out:
# scenario      wealth_quintile
# baseline      fourth             5.478970e+07
#               highest            4.813209e+07
#               lowest             8.153928e+07
#               middle             6.799934e+07
#               second             8.215571e+07
# intervention  fourth             5.457043e+07
#               highest            4.794673e+07
#               lowest             8.060490e+07
#               middle             6.757797e+07
#               second             8.144905e+07
# Name: value, dtype: float64

# %%
child_ylls_averted = child_ylls_by_scenario.loc["baseline"] - child_ylls_by_scenario.loc[scenario]
child_ylls_averted
# Out:
# wealth_quintile
# fourth     219278.544733
# highest    185360.093813
# lowest     934381.351475
# middle     421368.161545
# second     706661.086533
# Name: value, dtype: float64

# %%
f'{round(child_ylls_averted.sum()):,}'
# Out:
# '2,467,049'

# %%
child_days_averted = child_ylls_averted + 0

# %%
dalys_averted = pregnancy_dalys_averted + child_days_averted
dalys_averted
# Out:
# wealth_quintile
# fourth     221654.901023
# highest    186662.541522
# lowest     940152.697508
# middle     424201.441028
# second     712324.680335
# Name: value, dtype: float64

# %%
f'{round(dalys_averted.sum()):,}'
# Out:
# '2,484,996'
