 0]
# Out:
# location  sex     age_start  age_end  year_start  year_end
# Nigeria   Female  10.0       15.0     2021        2022        4.895440e+04
#                   15.0       20.0     2021        2022        1.070775e+06
#                   20.0       25.0     2021        2022        2.289711e+06
#                   25.0       30.0     2021        2022        2.056344e+06
#                   30.0       35.0     2021        2022        1.509810e+06
#                   35.0       40.0     2021        2022        8.395243e+05
#                   40.0       45.0     2021        2022        3.610966e+05
#                   45.0       50.0     2021        2022        1.455784e+05
#                   50.0       55.0     2021        2022        1.149517e+04
# Name: value, dtype: float64

# %%
births = births.sum()
f"{int(births):,}"
# Out:
# '8,333,288'

# %%
sim_baseline_births = pd.read_parquet(
    f"../../0200_pregnancy_sim/sim_results/{vehicle}/{location.lower()}/pregnancy_outcome_count.parquet"
)
sim_baseline_births
# Out:
#                         measure       entity_type               entity  \
# 0       pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 1       pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 2       pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 3       pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 4       pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# ...                         ...               ...                  ...
# 539995  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 539996  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 539997  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 539998  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 539999  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
#
#           sub_entity age_group anemia_status_at_birth wealth_quintile  \
# 0       partial_term  10_to_14                invalid          lowest
# 1       partial_term  10_to_14                invalid          second
# 2       partial_term  10_to_14                invalid          middle
# 3       partial_term  10_to_14                invalid          fourth
# 4       partial_term  10_to_14                invalid         highest
# ...              ...       ...                    ...             ...
# 539995    stillbirth   95_plus                 severe          lowest
# 539996    stillbirth   95_plus                 severe          second
# 539997    stillbirth   95_plus                 severe          middle
# 539998    stillbirth   95_plus                 severe          fourth
# 539999    stillbirth   95_plus                 severe         highest
#
#             scenario  random_seed  input_draw  value
# 0           baseline           56           0    1.0
# 1           baseline           56           0    4.0
# 2           baseline           56           0    1.0
# 3           baseline           56           0    2.0
# 4           baseline           56           0    0.0
# ...              ...          ...         ...    ...
# 539995  intervention          151           0    0.0
# 539996  intervention          151           0    0.0
# 539997  intervention          151           0    0.0
# 539998  intervention          151           0    0.0
# 539999  intervention          151           0    0.0
#
# [540000 rows x 11 columns]

# %%
sim_baseline_births = sim_baseline_births[
    (sim_baseline_births.scenario == "baseline")
    & (sim_baseline_births.sub_entity == "live_birth")
]
sim_baseline_births
# Out:
#                         measure       entity_type               entity  \
# 5       pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 6       pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 7       pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 8       pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 9       pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# ...                         ...               ...                  ...
# 538640  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 538641  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 538642  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 538643  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 538644  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
#
#         sub_entity age_group anemia_status_at_birth wealth_quintile  scenario  \
# 5       live_birth  10_to_14                invalid          lowest  baseline
# 6       live_birth  10_to_14                invalid          second  baseline
# 7       live_birth  10_to_14                invalid          middle  baseline
# 8       live_birth  10_to_14                invalid          fourth  baseline
# 9       live_birth  10_to_14                invalid         highest  baseline
# ...            ...       ...                    ...             ...       ...
# 538640  live_birth   95_plus                 severe          lowest  baseline
# 538641  live_birth   95_plus                 severe          second  baseline
# 538642  live_birth   95_plus                 severe          middle  baseline
# 538643  live_birth   95_plus                 severe          fourth  baseline
# 538644  live_birth   95_plus                 severe         highest  baseline
#
#         random_seed  input_draw  value
# 5                56           0   19.0
# 6                56           0   25.0
# 7                56           0   17.0
# 8                56           0   15.0
# 9                56           0   12.0
# ...             ...         ...    ...
# 538640           53           0    0.0
# 538641           53           0    0.0
# 538642           53           0    0.0
# 538643           53           0    0.0
# 538644           53           0    0.0
#
# [90000 rows x 11 columns]

# %%
sim_baseline_births = sim_baseline_births.groupby("input_draw").value.sum().mean()
sim_baseline_births
# Out:
# 3143823.0

# %%
births
# Out:
# 8333288.405715805

# %%
scalar = births / sim_baseline_births
scalar
# Out:
# 2.650686252284497

# %%
for result in ["ylds", "ylls", "deaths", "person_time"]:
    df = pd.read_parquet(
        f"../../0300_child_sim/sim_results/{vehicle}/{location.lower()}/{result}.parquet"
    )
    df.value *= scalar
    path = pathlib.Path(
        f"../results/rescaled_child_results/{vehicle}/{location.lower()}/{result}.parquet"
    )
    path.parent.mkdir(exist_ok=True, parents=True)
    df.to_parquet(path)
