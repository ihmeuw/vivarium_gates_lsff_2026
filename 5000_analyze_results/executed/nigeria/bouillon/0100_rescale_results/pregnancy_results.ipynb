# %%
import pandas as pd, numpy as np
import vivarium_inputs
import vivarium.gbd_mapping as gbd_mapping
import pathlib

# %%
location = "India"
vehicle = "rice"

# %%
# Parameters
location = "nigeria"
vehicle = "bouillon"

# %%
location = location.title()

# %%
pop = vivarium_inputs.get_population_structure(location).value
pop[pop > 0]
# Out:
# 2026-08-24 22:31:14.384 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.469 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.474 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:14.505 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.507 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.511 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:14.520 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.522 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.527 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:14.535 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.537 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.545 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_population'
# 2026-08-24 22:31:14.554 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.556 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.561 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:14.568 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.570 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.574 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 22:31:14.590 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.591 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.595 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:14.601 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.602 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.606 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:14.611 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.612 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.616 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:31:14.629 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.630 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.647 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:14.657 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.659 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.669 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:14.676 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.678 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.683 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:14.694 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.706 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.718 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:14.728 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.729 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.744 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:14.765 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.768 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.774 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:31:14.793 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.795 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.816 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:14.821 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.823 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.827 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:14.834 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.835 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.839 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:14.847 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.849 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.853 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# location  sex     age_start  age_end     year_start  year_end
# Nigeria   Female  0.000000   0.019178    2023        2024        7.907591e+04
#                   0.019178   0.076712    2023        2024        2.337381e+05
#                   0.076712   0.500000    2023        2024        1.706685e+06
#                   0.500000   1.000000    2023        2024        1.972513e+06
#                   1.000000   2.000000    2023        2024        3.899171e+06
#                   2.000000   5.000000    2023        2024        1.129739e+07
#                   5.000000   10.000000   2023        2024        1.766635e+07
#                   10.000000  15.000000   2023        2024        1.651034e+07
#                   15.000000  20.000000   2023        2024        1.483548e+07
#                   20.000000  25.000000   2023        2024        1.222554e+07
#                   25.000000  30.000000   2023        2024        9.984802e+06
#                   30.000000  35.000000   2023        2024        7.985380e+06
#                   35.000000  40.000000   2023        2024        6.543192e+06
#                   40.000000  45.000000   2023        2024        5.354753e+06
#                   45.000000  50.000000   2023        2024        4.526348e+06
#                   50.000000  55.000000   2023        2024        3.879312e+06
#                   55.000000  60.000000   2023        2024        3.140994e+06
#                   60.000000  65.000000   2023        2024        2.323845e+06
#                   65.000000  70.000000   2023        2024        1.548646e+06
#                   70.000000  75.000000   2023        2024        9.683218e+05
#                   75.000000  80.000000   2023        2024        5.332473e+05
#                   80.000000  85.000000   2023        2024        3.531309e+05
#                   85.000000  90.000000   2023        2024        1.641453e+05
#                   90.000000  95.000000   2023        2024        6.550405e+04
#                   95.000000  125.000000  2023        2024        3.642049e+04
#           Male    0.000000   0.019178    2023        2024        8.221097e+04
#                   0.019178   0.076712    2023        2024        2.419401e+05
#                   0.076712   0.500000    2023        2024        1.764433e+06
#                   0.500000   1.000000    2023        2024        2.037721e+06
#                   1.000000   2.000000    2023        2024        3.998065e+06
#                   2.000000   5.000000    2023        2024        1.146955e+07
#                   5.000000   10.000000   2023        2024        1.763943e+07
#                   10.000000  15.000000   2023        2024        1.575951e+07
#                   15.000000  20.000000   2023        2024        1.330167e+07
#                   20.000000  25.000000   2023        2024        1.051029e+07
#                   25.000000  30.000000   2023        2024        8.425754e+06
#                   30.000000  35.000000   2023        2024        6.802051e+06
#                   35.000000  40.000000   2023        2024        5.713455e+06
#                   40.000000  45.000000   2023        2024        4.874319e+06
#                   45.000000  50.000000   2023        2024        4.055535e+06
#                   50.000000  55.000000   2023        2024        3.219519e+06
#                   55.000000  60.000000   2023        2024        2.388975e+06
#                   60.000000  65.000000   2023        2024        1.654470e+06
#                   65.000000  70.000000   2023        2024        1.165358e+06
#                   70.000000  75.000000   2023        2024        8.009815e+05
#                   75.000000  80.000000   2023        2024        5.150650e+05
#                   80.000000  85.000000   2023        2024        3.261962e+05
#                   85.000000  90.000000   2023        2024        1.616087e+05
#                   90.000000  95.000000   2023        2024        6.687309e+04
#                   95.000000  125.000000  2023        2024        2.409231e+04
# Name: value, dtype: float64

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location
).value
asfr[asfr > 0]
# Out:
# 2026-08-24 22:31:14.951 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.952 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.957 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:14.966 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.970 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.975 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:14.983 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:14.988 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:14.993 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:15.002 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.004 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.025 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-08-24 22:31:15.032 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.033 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.049 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:15.054 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.055 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.060 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 22:31:15.072 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.073 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.078 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:15.085 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.090 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.094 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:15.101 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.102 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.106 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:31:15.116 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.117 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.121 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:15.125 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.125 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.129 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:15.134 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.135 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.147 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:15.182 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.185 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.194 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:15.206 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.208 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.215 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:15.240 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.242 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.251 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:31:15.263 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.264 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.269 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:15.278 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.280 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.284 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:15.291 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.293 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.298 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:15.307 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.310 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.315 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# location  sex     age_start  age_end  year_start  year_end  parameter
# Nigeria   Female  10.0       15.0     2023        2024      lower_value    0.002556
#                                                             mean_value     0.005714
#                                                             upper_value    0.011863
#                   15.0       20.0     2023        2024      lower_value    0.060154
#                                                             mean_value     0.070244
#                                                             upper_value    0.082133
#                   20.0       25.0     2023        2024      lower_value    0.171875
#                                                             mean_value     0.194484
#                                                             upper_value    0.219213
#                   25.0       30.0     2023        2024      lower_value    0.195823
#                                                             mean_value     0.208935
#                                                             upper_value    0.222267
#                   30.0       35.0     2023        2024      lower_value    0.176721
#                                                             mean_value     0.194076
#                                                             upper_value    0.210780
#                   35.0       40.0     2023        2024      lower_value    0.111019
#                                                             mean_value     0.127396
#                                                             upper_value    0.143440
#                   40.0       45.0     2023        2024      lower_value    0.057425
#                                                             mean_value     0.067482
#                                                             upper_value    0.077817
#                   45.0       50.0     2023        2024      lower_value    0.026053
#                                                             mean_value     0.031121
#                                                             upper_value    0.036547
#                   50.0       55.0     2023        2024      lower_value    0.002753
#                                                             mean_value     0.002821
#                                                             upper_value    0.002889
# Name: value, dtype: float64

# %%
asfr = asfr[asfr.index.get_level_values("parameter") == "mean_value"].droplevel(
    "parameter"
)
asfr
# Out:
# location  sex     age_start  age_end     year_start  year_end
# Nigeria   Female  0.000000   0.019178    2023        2024        0.000000
#                   0.019178   0.076712    2023        2024        0.000000
#                   0.076712   0.500000    2023        2024        0.000000
#                   0.500000   1.000000    2023        2024        0.000000
#                   1.000000   2.000000    2023        2024        0.000000
#                   2.000000   5.000000    2023        2024        0.000000
#                   5.000000   10.000000   2023        2024        0.000000
#                   10.000000  15.000000   2023        2024        0.005714
#                   15.000000  20.000000   2023        2024        0.070244
#                   20.000000  25.000000   2023        2024        0.194484
#                   25.000000  30.000000   2023        2024        0.208935
#                   30.000000  35.000000   2023        2024        0.194076
#                   35.000000  40.000000   2023        2024        0.127396
#                   40.000000  45.000000   2023        2024        0.067482
#                   45.000000  50.000000   2023        2024        0.031121
#                   50.000000  55.000000   2023        2024        0.002821
#                   55.000000  60.000000   2023        2024        0.000000
#                   60.000000  65.000000   2023        2024        0.000000
#                   65.000000  70.000000   2023        2024        0.000000
#                   70.000000  75.000000   2023        2024        0.000000
#                   75.000000  80.000000   2023        2024        0.000000
#                   80.000000  85.000000   2023        2024        0.000000
#                   85.000000  90.000000   2023        2024        0.000000
#                   90.000000  95.000000   2023        2024        0.000000
#                   95.000000  125.000000  2023        2024        0.000000
#           Male    0.000000   0.019178    2023        2024        0.000000
#                   0.019178   0.076712    2023        2024        0.000000
#                   0.076712   0.500000    2023        2024        0.000000
#                   0.500000   1.000000    2023        2024        0.000000
#                   1.000000   2.000000    2023        2024        0.000000
#                   2.000000   5.000000    2023        2024        0.000000
#                   5.000000   10.000000   2023        2024        0.000000
#                   10.000000  15.000000   2023        2024        0.000000
#                   15.000000  20.000000   2023        2024        0.000000
#                   20.000000  25.000000   2023        2024        0.000000
#                   25.000000  30.000000   2023        2024        0.000000
#                   30.000000  35.000000   2023        2024        0.000000
#                   35.000000  40.000000   2023        2024        0.000000
#                   40.000000  45.000000   2023        2024        0.000000
#                   45.000000  50.000000   2023        2024        0.000000
#                   50.000000  55.000000   2023        2024        0.000000
#                   55.000000  60.000000   2023        2024        0.000000
#                   60.000000  65.000000   2023        2024        0.000000
#                   65.000000  70.000000   2023        2024        0.000000
#                   70.000000  75.000000   2023        2024        0.000000
#                   75.000000  80.000000   2023        2024        0.000000
#                   80.000000  85.000000   2023        2024        0.000000
#                   85.000000  90.000000   2023        2024        0.000000
#                   90.000000  95.000000   2023        2024        0.000000
#                   95.000000  125.000000  2023        2024        0.000000
# Name: value, dtype: float64

# %%
sbr = vivarium_inputs.get_measure(
    # GBD 2023 split this into 20-week and 28-week variants; using 28 weeks to
    # match data_keys.SBR and 0500. See the note there -- this is NOT the
    # continuity-preserving choice and cuts the ratio ~32% vs GBD 2021.
    gbd_mapping.covariates.stillbirth_28_weeks_to_live_birth_ratio, "estimate", location
).value
sbr[sbr > 0]
# Out:
# 2026-08-24 22:31:15.667 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.667 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.672 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:15.678 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.679 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.681 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:15.687 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.688 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.692 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:15.705 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.706 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.723 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-08-24 22:31:15.732 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.735 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.739 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:15.746 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.749 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.757 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 22:31:15.769 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.769 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.775 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:15.786 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.787 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.803 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:15.809 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.809 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.813 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:15.817 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.818 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.821 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:15.826 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.826 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.829 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:15.841 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.842 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.846 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:15.854 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.856 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.860 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:15.877 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.880 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.884 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:15.891 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.893 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.896 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:15.906 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.907 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.911 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:15.917 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:15.918 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:15.921 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# location  year_start  year_end  parameter
# Nigeria   2023        2024      lower_value    0.020725
#                                 mean_value     0.026341
#                                 upper_value    0.032816
# Name: value, dtype: float64

# %%
sbr = sbr.iloc[0]
sbr
# Out:
# 0.0207252032270903

# %%
maternal_abortion_miscarriage_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.maternal_abortion_and_miscarriage,
    "incidence_rate",
    location,
).mean(axis=1)
maternal_abortion_miscarriage_incidence[maternal_abortion_miscarriage_incidence > 0]
# Out:
# 2026-08-24 22:31:16.080 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.081 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.084 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.091 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.092 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.095 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.101 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.102 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.105 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.111 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.111 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.120 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:16.124 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.125 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.132 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 22:31:16.139 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.140 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.143 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:16.147 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.148 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.151 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 22:31:16.160 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 22:31:16.173 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.173 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.176 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:16.181 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.181 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.184 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:16.189 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.189 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.192 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:31:16.197 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 22:31:16.197 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 22:31:16.225 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.225 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.228 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:16.348 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.349 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.353 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:16.358 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.359 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.363 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:16.371 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.373 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.378 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:16.407 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.409 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.413 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.420 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.421 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.424 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:16.429 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.430 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.434 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 22:31:16.442 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.443 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.447 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:16.452 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.452 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.455 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 22:31:16.464 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 22:31:16.472 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.472 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.475 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:16.481 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.482 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.485 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:16.492 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.493 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.496 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:31:16.507 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 22:31:16.507 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 22:31:16.539 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.540 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.543 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:16.610 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.611 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.620 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:16.625 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.625 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.628 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:16.645 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.646 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.650 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:16.665 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.667 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.671 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.685 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.686 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.690 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.702 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.704 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.707 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:31:16.718 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.719 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.723 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:16.729 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.732 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.740 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.748 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.750 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.757 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.763 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.765 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.768 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/abie/projects/2026/vivarium_gates_lsff_2026/.snakemake_envs/artifact/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# location  sex     age_start  age_end  year_start  year_end
# Nigeria   Female  10.0       15.0     2023        2024        0.006976
#                   15.0       20.0     2023        2024        0.074024
#                   20.0       25.0     2023        2024        0.177579
#                   25.0       30.0     2023        2024        0.164486
#                   30.0       35.0     2023        2024        0.146138
#                   35.0       40.0     2023        2024        0.103056
#                   40.0       45.0     2023        2024        0.063297
#                   45.0       50.0     2023        2024        0.035266
#                   50.0       55.0     2023        2024        0.003660
# dtype: float64

# %%
ectopic_pregnancy_incidence = vivarium_inputs.get_measure(
    gbd_mapping.causes.ectopic_pregnancy,
    "incidence_rate",
    location,
).mean(axis=1)
ectopic_pregnancy_incidence[ectopic_pregnancy_incidence > 0]
# Out:
# 2026-08-24 22:31:16.912 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.913 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.917 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.923 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.924 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.927 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.933 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.933 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.936 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:16.942 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.943 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.950 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:16.954 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.955 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.963 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 22:31:16.970 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.971 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.974 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:16.978 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.979 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:16.982 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 22:31:16.990 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 22:31:16.998 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:16.999 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.002 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:17.007 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.007 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.010 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:17.014 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.015 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.018 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:31:17.023 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 22:31:17.023 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 22:31:17.059 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.060 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.063 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:17.194 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.195 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.197 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:17.202 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.202 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.205 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:17.219 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.220 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.224 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:17.238 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.245 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.249 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:17.254 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.255 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.257 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:17.261 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.262 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.266 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_incidence_prevalence'
# 2026-08-24 22:31:17.273 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.273 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.276 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:17.281 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.282 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.285 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 22:31:17.293 | WARNING  | vivarium_inputs.validation.raw:check_columns:2156 - Data returned extra columns: {'version_id'}.
# 2026-08-24 22:31:17.298 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.299 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.302 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:17.308 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.308 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.311 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:17.316 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.316 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.319 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:31:17.324 | WARNING  | vivarium_inputs.validation.raw:check_age_group_ids:2274 - Data contains additional age groups beyond those specified by restriction range.
# 2026-08-24 22:31:17.325 | WARNING  | vivarium_inputs.validation.raw:check_sex_ids:2332 - Data is missing the following expected sex ids: {1}.
# 2026-08-24 22:31:17.349 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.351 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.355 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:17.425 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.427 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.435 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:31:17.440 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.441 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.445 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:31:17.454 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.455 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.463 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:31:17.486 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.488 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.496 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:17.505 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.507 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.511 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:17.549 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.552 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.556 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:31:17.569 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.571 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.580 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:31:17.586 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.587 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.591 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:17.598 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.599 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.603 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:31:17.609 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:31:17.610 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:31:17.614 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# /ihme/homes/abie/projects/2026/vivarium_gates_lsff_2026/.snakemake_envs/artifact/lib/python3.11/site-packages/vivarium_inputs/utilities.py:508: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f"{split_column_prefix}_end"] = [
# location  sex     age_start  age_end  year_start  year_end
# Nigeria   Female  10.0       15.0     2023        2024        0.000623
#                   15.0       20.0     2023        2024        0.002269
#                   20.0       25.0     2023        2024        0.003786
#                   25.0       30.0     2023        2024        0.003659
#                   30.0       35.0     2023        2024        0.003887
#                   35.0       40.0     2023        2024        0.003440
#                   40.0       45.0     2023        2024        0.003382
#                   45.0       50.0     2023        2024        0.002765
#                   50.0       55.0     2023        2024        0.000730
# dtype: float64

# %%
pregnancy_incidence = (
    asfr
    + (asfr * sbr)
    + maternal_abortion_miscarriage_incidence
    + ectopic_pregnancy_incidence
)
pregnancy_incidence[pregnancy_incidence > 0]
# Out:
# location  sex     age_start  age_end  year_start  year_end
# Nigeria   Female  10.0       15.0     2023        2024        0.013432
#                   15.0       20.0     2023        2024        0.147993
#                   20.0       25.0     2023        2024        0.379880
#                   25.0       30.0     2023        2024        0.381409
#                   30.0       35.0     2023        2024        0.348123
#                   35.0       40.0     2023        2024        0.236532
#                   40.0       45.0     2023        2024        0.135560
#                   45.0       50.0     2023        2024        0.069797
#                   50.0       55.0     2023        2024        0.007271
# dtype: float64

# %%
pregnancies = pop * pregnancy_incidence
pregnancies[pregnancies > 0]
# Out:
# location  sex     age_start  age_end  year_start  year_end
# Nigeria   Female  10.0       15.0     2023        2024        2.217623e+05
#                   15.0       20.0     2023        2024        2.195549e+06
#                   20.0       25.0     2023        2024        4.644232e+06
#                   25.0       30.0     2023        2024        3.808295e+06
#                   30.0       35.0     2023        2024        2.779893e+06
#                   35.0       40.0     2023        2024        1.547675e+06
#                   40.0       45.0     2023        2024        7.258899e+05
#                   45.0       50.0     2023        2024        3.159267e+05
#                   50.0       55.0     2023        2024        2.820465e+04
# dtype: float64

# %%
total_pregnancies = pregnancies.sum()
total_pregnancies
# Out:
# 16267427.202231383

# %%
sim_pregnancy_outcomes = pd.read_parquet(
    f"../../0200_pregnancy_sim/sim_results/{vehicle}/{location.lower()}/pregnancy_outcome_count.parquet"
)
n_random_seeds = sim_pregnancy_outcomes.random_seed.nunique()
sim_population = (
    sim_pregnancy_outcomes.groupby(["input_draw", "scenario"]).value.sum().mean()
)
sim_population
# Out:
# 500000.0

# %%
scalar = total_pregnancies / sim_population
scalar
# Out:
# 32.53485440446276

# %%
# `scalar` multiplies every pregnancy number this notebook writes, and until now nothing
# bounded it -- it was displayed and then applied. A zero simulated denominator makes it
# `inf`, which propagates silently into every rescaled parquet rather than failing.
assert np.isfinite(scalar) and scalar > 0, (
    f"rescaling factor is not a positive finite number: {scalar}. "
    f"GBD pregnancies={total_pregnancies:,.0f}, simulated pregnancy outcomes="
    f"{sim_population:,.0f} over {n_random_seeds} seeds. Every parquet below is "
    "multiplied by this."
)

# The scalar itself cannot be banded: it scales as 1/n_random_seeds, so it was 1.06-3.10
# for the published 200-seed run and 32.5-48.1 for a 10-seed one. What *is* seed
# independent is the simulated cohort size per seed. The band leaves ~25x margin either
# side of what both GBD vintages produce; its job is to catch a collapsed or missing
# denominator, not to pin epidemiology.
outcomes_per_seed = sim_population / n_random_seeds
assert 1_000 <= outcomes_per_seed <= 1_000_000, (
    f"{outcomes_per_seed:,.0f} simulated pregnancy outcomes per seed is outside the "
    f"plausible 1,000-1,000,000 range ({sim_population:,.0f} over {n_random_seeds} "
    "seeds). Either the simulation produced almost nothing, or "
    "pregnancy_outcome_count.parquet is not what this notebook expects."
)
f"scalar={scalar:,.4f} from {outcomes_per_seed:,.0f} outcomes/seed x {n_random_seeds} seeds"
# Out:
# 'scalar=32.5349 from 50,000 outcomes/seed x 10 seeds'

# %%
for result in [
    "ylds",
    "ylls",
    "pregnancy_outcome_count",
    "person_time_anemia",
    "transition_count_maternal_disorders",
]:
    df = pd.read_parquet(
        f"../../0200_pregnancy_sim/sim_results/{vehicle}/{location.lower()}/{result}.parquet"
    )
    df.value *= scalar
    path = pathlib.Path(
        f"../results/rescaled_pregnancy_results/{vehicle}/{location.lower()}/{result}.parquet"
    )
    path.parent.mkdir(exist_ok=True, parents=True)
    df.to_parquet(path)
