#                   45.000000  50.000000   2023        2024        4.055535e+06
#                   50.000000  55.000000   2023        2024        3.219519e+06
#                   55.000000  60.000000   2023        2024        2.388975e+06
#                   60.000000  65.000000   2023        2024        1.654470e+06
#                   65.000000  70.000000   2023        2024        1.165358e+06
#                   70.000000  75.000000   2023        2024        8.009815e+05
#                   75.000000  80.000000   2023        2024        5.150650e+05
#                   80.000000  85.000000   2023        2024        3.261962e+05
#                   85.000000  90.000000   2023        2024        1.616087e+05
#                   90.000000  95.000000   2023        2024        6.687309e+04
#                   95.000000  125.000000  2023        2024        2.409231e+04
# Name: value, dtype: float64

# %%
asfr = vivarium_inputs.get_measure(
    gbd_mapping.covariates.age_specific_fertility_rate, "estimate", location
).value
asfr[asfr > 0]
# Out:
# 2026-08-24 22:56:28.830 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.831 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.835 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:56:28.843 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.845 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.849 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:56:28.855 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.859 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.862 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:56:28.867 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.868 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.882 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_covariate_estimate'
# 2026-08-24 22:56:28.890 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.892 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.896 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:56:28.902 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.904 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.908 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_path_to_global'
# 2026-08-24 22:56:28.919 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.921 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.929 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:56:28.934 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.935 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.939 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:56:28.945 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.947 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.950 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:56:28.962 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.964 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.968 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_estimation_years'
# 2026-08-24 22:56:28.973 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.974 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.977 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_annual_years'
# 2026-08-24 22:56:28.988 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:28.990 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:28.993 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_group_id'
# 2026-08-24 22:56:29.013 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:29.014 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:29.018 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:56:29.024 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:29.026 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:29.029 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:56:29.045 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:29.046 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:29.050 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# 2026-08-24 22:56:29.071 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:29.074 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:29.083 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_most_recent_year'
# 2026-08-24 22:56:29.089 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:29.090 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:29.094 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:56:29.101 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:29.103 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:29.107 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_location_ids'
# 2026-08-24 22:56:29.114 | DEBUG    | vivarium_gbd_access.utilities:get_memory:61 - Config: 'input_data:
#     intermediary_data_cache_path:
#         user_configs: /mnt/team/simulation_science/costeffectiveness/vivarium_cache
#     cache_data:
#         base: True'
# 2026-08-24 22:56:29.116 | DEBUG    | vivarium_gbd_access.utilities:get_memory:66 - Cache Dir: '/mnt/team/simulation_science/costeffectiveness/vivarium_cache'
# 2026-08-24 22:56:29.119 | INFO     | vivarium_gbd_access.utilities:wrapper:47 - Using cached data for 'get_age_bins'
# location  sex     age_start  age_end  year_start  year_end  parameter
# Nigeria   Female  10.0       15.0     2023        2024      lower_value    0.002556
#                                                             mean_value     0.005714
#                                                             upper_value    0.011863
#                   15.0       20.0     2023        2024      lower_value    0.060154
#                                                             mean_value     0.070244
#                                                             upper_value    0.082133
#                   20.0       25.0     2023        2024      lower_value    0.171875
#                                                             mean_value     0.194484
#                                                             upper_value    0.219213
#                   25.0       30.0     2023        2024      lower_value    0.195823
#                                                             mean_value     0.208935
#                                                             upper_value    0.222267
#                   30.0       35.0     2023        2024      lower_value    0.176721
#                                                             mean_value     0.194076
#                                                             upper_value    0.210780
#                   35.0       40.0     2023        2024      lower_value    0.111019
#                                                             mean_value     0.127396
#                                                             upper_value    0.143440
#                   40.0       45.0     2023        2024      lower_value    0.057425
#                                                             mean_value     0.067482
#                                                             upper_value    0.077817
#                   45.0       50.0     2023        2024      lower_value    0.026053
#                                                             mean_value     0.031121
#                                                             upper_value    0.036547
#                   50.0       55.0     2023        2024      lower_value    0.002753
#                                                             mean_value     0.002821
#                                                             upper_value    0.002889
# Name: value, dtype: float64

# %%
asfr = asfr[asfr.index.get_level_values("parameter") == "mean_value"].droplevel(
    "parameter"
)
asfr
# Out:
# location  sex     age_start  age_end     year_start  year_end
# Nigeria   Female  0.000000   0.019178    2023        2024        0.000000
#                   0.019178   0.076712    2023        2024        0.000000
#                   0.076712   0.500000    2023        2024        0.000000
#                   0.500000   1.000000    2023        2024        0.000000
#                   1.000000   2.000000    2023        2024        0.000000
#                   2.000000   5.000000    2023        2024        0.000000
#                   5.000000   10.000000   2023        2024        0.000000
#                   10.000000  15.000000   2023        2024        0.005714
#                   15.000000  20.000000   2023        2024        0.070244
#                   20.000000  25.000000   2023        2024        0.194484
#                   25.000000  30.000000   2023        2024        0.208935
#                   30.000000  35.000000   2023        2024        0.194076
#                   35.000000  40.000000   2023        2024        0.127396
#                   40.000000  45.000000   2023        2024        0.067482
#                   45.000000  50.000000   2023        2024        0.031121
#                   50.000000  55.000000   2023        2024        0.002821
#                   55.000000  60.000000   2023        2024        0.000000
#                   60.000000  65.000000   2023        2024        0.000000
#                   65.000000  70.000000   2023        2024        0.000000
#                   70.000000  75.000000   2023        2024        0.000000
#                   75.000000  80.000000   2023        2024        0.000000
#                   80.000000  85.000000   2023        2024        0.000000
#                   85.000000  90.000000   2023        2024        0.000000
#                   90.000000  95.000000   2023        2024        0.000000
#                   95.000000  125.000000  2023        2024        0.000000
#           Male    0.000000   0.019178    2023        2024        0.000000
#                   0.019178   0.076712    2023        2024        0.000000
#                   0.076712   0.500000    2023        2024        0.000000
#                   0.500000   1.000000    2023        2024        0.000000
#                   1.000000   2.000000    2023        2024        0.000000
#                   2.000000   5.000000    2023        2024        0.000000
#                   5.000000   10.000000   2023        2024        0.000000
#                   10.000000  15.000000   2023        2024        0.000000
#                   15.000000  20.000000   2023        2024        0.000000
#                   20.000000  25.000000   2023        2024        0.000000
#                   25.000000  30.000000   2023        2024        0.000000
#                   30.000000  35.000000   2023        2024        0.000000
#                   35.000000  40.000000   2023        2024        0.000000
#                   40.000000  45.000000   2023        2024        0.000000
#                   45.000000  50.000000   2023        2024        0.000000
#                   50.000000  55.000000   2023        2024        0.000000
#                   55.000000  60.000000   2023        2024        0.000000
#                   60.000000  65.000000   2023        2024        0.000000
#                   65.000000  70.000000   2023        2024        0.000000
#                   70.000000  75.000000   2023        2024        0.000000
#                   75.000000  80.000000   2023        2024        0.000000
#                   80.000000  85.000000   2023        2024        0.000000
#                   85.000000  90.000000   2023        2024        0.000000
#                   90.000000  95.000000   2023        2024        0.000000
#                   95.000000  125.000000  2023        2024        0.000000
# Name: value, dtype: float64

# %%
births = pop * asfr
births[births > 0]
# Out:
# location  sex     age_start  age_end  year_start  year_end
# Nigeria   Female  10.0       15.0     2023        2024        9.434157e+04
#                   15.0       20.0     2023        2024        1.042096e+06
#                   20.0       25.0     2023        2024        2.377674e+06
#                   25.0       30.0     2023        2024        2.086170e+06
#                   30.0       35.0     2023        2024        1.549767e+06
#                   35.0       40.0     2023        2024        8.335776e+05
#                   40.0       45.0     2023        2024        3.613521e+05
#                   45.0       50.0     2023        2024        1.408638e+05
#                   50.0       55.0     2023        2024        1.094531e+04
# Name: value, dtype: float64

# %%
births = births.sum()
f"{int(births):,}"
# Out:
# '8,496,788'

# %%
sim_baseline_births = pd.read_parquet(
    f"../../0200_pregnancy_sim/sim_results/{vehicle}/{location.lower()}/pregnancy_outcome_count.parquet"
)
sim_baseline_births
# Out:
#                        measure       entity_type               entity  \
# 0      pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 1      pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 2      pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 3      pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 4      pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# ...                        ...               ...                  ...
# 40495  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 40496  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 40497  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 40498  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 40499  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
#
#          sub_entity age_group anemia_status_at_birth  wealth_quintile  \
# 0      partial_term  10_to_14                invalid                1
# 1      partial_term  10_to_14                invalid                2
# 2      partial_term  10_to_14                invalid                3
# 3      partial_term  10_to_14                invalid                4
# 4      partial_term  10_to_14                invalid                5
# ...             ...       ...                    ...              ...
# 40495    stillbirth   95_plus                 severe                1
# 40496    stillbirth   95_plus                 severe                2
# 40497    stillbirth   95_plus                 severe                3
# 40498    stillbirth   95_plus                 severe                4
# 40499    stillbirth   95_plus                 severe                5
#
#        scenario  input_draw  random_seed  value
# 0      baseline           0            2   91.0
# 1      baseline           0            2   80.0
# 2      baseline           0            2   84.0
# 3      baseline           0            2   77.0
# 4      baseline           0            2   68.0
# ...         ...         ...          ...    ...
# 40495  baseline           0            9    0.0
# 40496  baseline           0            9    0.0
# 40497  baseline           0            9    0.0
# 40498  baseline           0            9    0.0
# 40499  baseline           0            9    0.0
#
# [40500 rows x 11 columns]

# %%
sim_baseline_births = sim_baseline_births[
    (sim_baseline_births.scenario == "baseline")
    & (sim_baseline_births.sub_entity == "live_birth")
]
sim_baseline_births
# Out:
#                        measure       entity_type               entity  \
# 5      pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 6      pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 7      pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 8      pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 9      pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# ...                        ...               ...                  ...
# 40490  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 40491  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 40492  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 40493  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
# 40494  pregnancy_outcome_count  custom_fertility  pregnancy_countcome
#
#        sub_entity age_group anemia_status_at_birth  wealth_quintile  scenario  \
# 5      live_birth  10_to_14                invalid                1  baseline
# 6      live_birth  10_to_14                invalid                2  baseline
# 7      live_birth  10_to_14                invalid                3  baseline
# 8      live_birth  10_to_14                invalid                4  baseline
# 9      live_birth  10_to_14                invalid                5  baseline
# ...           ...       ...                    ...              ...       ...
# 40490  live_birth   95_plus                 severe                1  baseline
# 40491  live_birth   95_plus                 severe                2  baseline
# 40492  live_birth   95_plus                 severe                3  baseline
# 40493  live_birth   95_plus                 severe                4  baseline
# 40494  live_birth   95_plus                 severe                5  baseline
#
#        input_draw  random_seed  value
# 5               0            2   65.0
# 6               0            2   66.0
# 7               0            2   51.0
# 8               0            2   53.0
# 9               0            2   56.0
# ...           ...          ...    ...
# 40490           0            9    0.0
# 40491           0            9    0.0
# 40492           0            9    0.0
# 40493           0            9    0.0
# 40494           0            9    0.0
#
# [4500 rows x 11 columns]

# %%
n_random_seeds = sim_baseline_births.random_seed.nunique()
sim_baseline_births = sim_baseline_births.groupby("input_draw").value.sum().mean()
sim_baseline_births
# Out:
# 260362.0

# %%
births
# Out:
# 8496788.296585033

# %%
scalar = births / sim_baseline_births
scalar
# Out:
# 32.63451769684145

# %%
# `scalar` multiplies every child number this notebook writes, and until now nothing
# bounded it -- it was displayed and then applied. A zero simulated denominator makes it
# `inf`, which propagates silently into every rescaled parquet rather than failing.
assert np.isfinite(scalar) and scalar > 0, (
    f"rescaling factor is not a positive finite number: {scalar}. "
    f"GBD births={births:,.0f}, simulated baseline live births={sim_baseline_births:,.0f} "
    f"over {n_random_seeds} seeds. Every parquet below is multiplied by this."
)

# The scalar itself cannot be banded: it scales as 1/n_random_seeds, so it was 1.06-3.10
# for the published 200-seed run and 32.5-48.1 for a 10-seed one. What *is* seed
# independent is the simulated cohort size per seed, measured at 26k-44k live births
# across both GBD 2021 and GBD 2023. The band below leaves ~25x margin either side; its
# job is to catch a collapsed or missing denominator, not to pin epidemiology.
births_per_seed = sim_baseline_births / n_random_seeds
assert 1_000 <= births_per_seed <= 1_000_000, (
    f"{births_per_seed:,.0f} simulated live births per seed is outside the plausible "
    f"1,000-1,000,000 range ({sim_baseline_births:,.0f} over {n_random_seeds} seeds). "
    "Either the simulation produced almost nothing, or pregnancy_outcome_count.parquet "
    "is not what this notebook expects."
)
f"scalar={scalar:,.4f} from {births_per_seed:,.0f} live births/seed x {n_random_seeds} seeds"
# Out:
# 'scalar=32.6345 from 26,036 live births/seed x 10 seeds'

# %%
# NOTE: 'person_time' was renamed to 'person_time_population' when PersonTimeObserver
# became a PublicHealthObserver, so the automated V&V loader can discover it.
for result in ["ylds", "ylls", "deaths", "person_time_population"]:
    df = pd.read_parquet(
        f"../../0300_child_sim/sim_results/{vehicle}/{location.lower()}/{result}.parquet"
    )
    df.value *= scalar
    path = pathlib.Path(
        f"../results/rescaled_child_results/{vehicle}/{location.lower()}/{result}.parquet"
    )
    path.parent.mkdir(exist_ok=True, parents=True)
    df.to_parquet(path)
